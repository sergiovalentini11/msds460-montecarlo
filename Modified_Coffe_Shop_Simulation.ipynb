# %% [markdown]
# ## libraries used in this assignemnt

# %%
# initialize queue length
# queue_length = 0

import numpy as np # for random number distributions
import pandas as pd # for event_log data frame
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 10)
import queue # add FIFO queue data structure
from functools import partial, wraps

import simpy # discrete event simulation environment

# %% [markdown]
# ## Functions and methods

# %% [markdown]
# ### Modified Arrival - To represent people leaving the queue based on the patience measurement

# %%
def arrival(env, caseid, caseid_queue, event_log):
    # generates new customers... arrivals
    caseid = 0
    while True:  # infinite loop for generating arrivals
        # get the service process started
        # must have waiting customers to begin service
    
        # schedule the time of next customer arrival       
        # by waiting until the next arrival time from now
        # when the process yields an event, the process gets suspended
        inter_arrival_time = round(60*np.random.exponential(scale = mean_inter_arrival_time))
        print("NEXT ARRIVAL TIME: ", env.now + inter_arrival_time)

        yield env.timeout(inter_arrival_time)  # generator function waits
        # env.timeout does not advance the clock. when an event/process calls env.timeout, 
        # that process waits until the clock gets to that time, it does not block 
        # other agents from doing stuff. Other processes can still do stuff 
        # while the first process is waiting for env.timeout to finish.
        caseid += 1
        time = env.now
        activity = 'arrival'
        env.process(event_log_append(env, caseid, time, activity, event_log)) 
        yield env.timeout(0) 
        if caseid_queue.qsize() < balking_queue_length:
            caseid_queue.put(caseid)          
            print("Customer joins queue caseid =",caseid,'time = ',env.now,'queue_length =',caseid_queue.qsize())
            time = env.now
            activity = 'join_queue'
            env.process(event_log_append(env, caseid, time, activity, event_log)) 
            env.process(service_process(env,  caseid_queue, event_log))       
        else:
            print("Customer balks caseid =",caseid,'time = ',env.now,'queue_length =',caseid_queue.qsize()) 
            env.process(event_log_append(env, caseid, env.now, 'balk', event_log))

# %% [markdown]
# ### Serivce process

# %%
# user-defined function for random service time (modified exponential)
# returns real number of minutes
def random_service_time(minimum_service_time,mean_service_time,maximum_service_time) :
    try_service_time = np.random.exponential(scale = mean_service_time)
    if (try_service_time < minimum_service_time):
        return(minimum_service_time)
    if (try_service_time > maximum_service_time):
        return(maximum_service_time)
    if (try_service_time >= minimum_service_time) and (try_service_time <= maximum_service_time):
        return(try_service_time)
    


def service_process(env, caseid_queue, event_log):
    # must have baristas to provide service... freeze until request can be met
    with available_baristas.request() as req:
        yield req  # wait until the request can be met.. there must be an available barista
        queue_length_on_entering_service = caseid_queue.qsize()
        caseid = caseid_queue.get()
        print("Begin_service caseid =",caseid,'time = ',env.now,'queue_length =',queue_length_on_entering_service)
        env.process(event_log_append(env, caseid, env.now, 'begin_service', event_log)) 
        # schedule end_service event based on service_time
        service_time = round(60*random_service_time(minimum_service_time,mean_service_time,maximum_service_time))   
        yield env.timeout(service_time)  # sets begin_service as generator function
        queue_length_on_leaving_service = caseid_queue.qsize()
        print("End_service caseid =",caseid,'time = ',env.now,'queue_length =',queue_length_on_leaving_service)
        env.process(event_log_append(env, caseid, env.now, 'end_service', event_log))

# %% [markdown]
# ### Tracing of the simulation

# %%
'''        
---------------------------------------------------------
set up event tracing of all simulation program events 
controlled by the simulation environment
that is, all timeout and process events that begin with "env."
documentation at:
  https://simpy.readthedocs.io/en/latest/topical_guides/monitoring.html#event-tracing
  https://docs.python.org/3/library/functools.html#functools.partial
'''
def trace(env, callback):
     """Replace the ``step()`` method of *env* with a tracing function
     that calls *callbacks* with an events time, priority, ID and its
     instance just before it is processed.
     note: "event" here refers to simulaiton program events

     """
     def get_wrapper(env_step, callback):
         """Generate the wrapper for env.step()."""
         @wraps(env_step)
         def tracing_step():
             """Call *callback* for the next event if one exist before
             calling ``env.step()``."""
             if len(env._queue):
                 t, prio, eid, event = env._queue[0]
                 callback(t, prio, eid, event)
             return env_step()
         return tracing_step

     env.step = get_wrapper(env.step, callback)

def trace_monitor(data, t, prio, eid, event):
     data.append((t, eid, type(event)))

def test_process(env):
     yield env.timeout(1)

'''
---------------------------------------------------------
set up an event log for recording events
as defined for the discrete event simulation
we use a list of tuples for the event log
documentation at:
  https://simpy.readthedocs.io/en/latest/topical_guides/monitoring.html#event-tracing
'''     
def event_log_append(env, caseid, time, activity, event_log):
    event_log.append((caseid, time, activity))
    yield env.timeout(0)

# %% [markdown]
# ### Parameters to be changed for each simulation

# %%
# let the simulation time unit be one second, but set parameters in minutes
# set global variables that do not change throughout the course of the simulation

baristas = 3  # number of barista server resources... vary from 1 to 3

minimum_service_time = 1 # minutes (60 seconds)
mean_service_time = 2 # minutes (120 seconds)
maximum_service_time = 5 # minutes (300 seconds)

mean_inter_arrival_time = 1 # vary from 1 to 10 minutes (60 to 600 seconds)

balking_queue_length = 10  # longest queue length that customers will tolerate

# this binary toggle allows you to fix the random number seed
# so that every run of the program with specific parameter settings
# will yield the same results... setting to false will allow the
# program to obtain different results with each run
obtain_reproducible_results = True

# set length of simulation in simulation time units (assume seconds)
# run for similation_hours of simulation time
simulation_hours = 10
fixed_simulation_time =  simulation_hours*60*60   

parameter_string_list = [str(simulation_hours),'hours',
              str(baristas),str(minimum_service_time),
              str(mean_service_time),str(maximum_service_time),
              str(mean_inter_arrival_time),str(balking_queue_length)]
separator = '-'        
simulation_file_identifier = separator.join(parameter_string_list)

# initialize queue length
# queue_length = 0

# %% [markdown]
# ### Simulation

# %%
'''
---------------------------------------
set up the SimPy simulation environment
and run the simulation with monitoring
---------------------------------------
'''
if obtain_reproducible_results: 
    np.random.seed(9999)

# set up simulation trace monitoring for the simulation
data = []
# bind *data* as first argument to monitor()
this_trace_monitor = partial(trace_monitor, data)

env = simpy.Environment()
trace(env, this_trace_monitor)

env.process(test_process(env))

# implement FIFO queue to hold caseid values
caseid_queue = queue.Queue()

# set up limited server/baristas resource
available_baristas = simpy.Resource(env, capacity = baristas)
caseid = -1  # dummy caseid for beginning of simulation
# dummy caseid values will be omitted from the event_log
# prior to analyzing simulation results

# beginning record in event_log list of tuples of the form
# form of the event_log tuple item: (caseid, time, activity)
event_log = [(caseid,0,'null_start_simulation')]
# event_monitor = partial(event_monitor, event_log)
env.process(event_log_append(env, caseid, env.now, 'start_simulation', event_log))
 
# call customer arrival process/generator to begin the simulation
env.process(arrival(env, caseid, caseid_queue, event_log))  

env.run(until = fixed_simulation_time)  # start simulation with monitoring and fixed end-time
# Out:
# NEXT ARRIVAL TIME:  104
# Customer joins queue caseid = 1 time =  104 queue_length = 1
# NEXT ARRIVAL TIME:  119
# Begin_service caseid = 1 time =  104 queue_length = 1
# Customer joins queue caseid = 2 time =  119 queue_length = 1
# NEXT ARRIVAL TIME:  166
# Begin_service caseid = 2 time =  119 queue_length = 1
# End_service caseid = 1 time =  164 queue_length = 0
# Customer joins queue caseid = 3 time =  166 queue_length = 1
# NEXT ARRIVAL TIME:  178
# Begin_service caseid = 3 time =  166 queue_length = 1
# Customer joins queue caseid = 4 time =  178 queue_length = 1
# NEXT ARRIVAL TIME:  234
# Begin_service caseid = 4 time =  178 queue_length = 1
# End_service caseid = 2 time =  179 queue_length = 0
# End_service caseid = 3 time =  232 queue_length = 0
# Customer joins queue caseid = 5 time =  234 queue_length = 1
# NEXT ARRIVAL TIME:  296
# Begin_service caseid = 5 time =  234 queue_length = 1
# End_service caseid = 4 time =  259 queue_length = 0
# Customer joins queue caseid = 6 time =  296 queue_length = 1
# NEXT ARRIVAL TIME:  384
# Begin_service caseid = 6 time =  296 queue_length = 1
# End_service caseid = 6 time =  356 queue_length = 0
# Customer joins queue caseid = 7 time =  384 queue_length = 1
# NEXT ARRIVAL TIME:  416
# Begin_service caseid = 7 time =  384 queue_length = 1
# Customer joins queue caseid = 8 time =  416 queue_length = 1
# NEXT ARRIVAL TIME:  443
# Begin_service caseid = 8 time =  416 queue_length = 1
# Customer joins queue caseid = 9 time =  443 queue_length = 1
# NEXT ARRIVAL TIME:  495
# End_service caseid = 7 time =  444 queue_length = 1
# Begin_service caseid = 9 time =  444 queue_length = 1
# End_service caseid = 8 time =  476 queue_length = 0
# Customer joins queue caseid = 10 time =  495 queue_length = 1
# NEXT ARRIVAL TIME:  519
# Begin_service caseid = 10 time =  495 queue_length = 1
# End_service caseid = 9 time =  504 queue_length = 0
# Customer joins queue caseid = 11 time =  519 queue_length = 1
# NEXT ARRIVAL TIME:  530
# Begin_service caseid = 11 time =  519 queue_length = 1
# End_service caseid = 5 time =  527 queue_length = 0
# Customer joins queue caseid = 12 time =  530 queue_length = 1
# NEXT ARRIVAL TIME:  578
# Begin_service caseid = 12 time =  530 queue_length = 1
# Customer joins queue caseid = 13 time =  578 queue_length = 1
# NEXT ARRIVAL TIME:  612
# End_service caseid = 11 time =  598 queue_length = 1
# Begin_service caseid = 13 time =  598 queue_length = 1
# Customer joins queue caseid = 14 time =  612 queue_length = 1
# NEXT ARRIVAL TIME:  733
# End_service caseid = 12 time =  641 queue_length = 1
# Begin_service caseid = 14 time =  641 queue_length = 1
# End_service caseid = 13 time =  675 queue_length = 0
# End_service caseid = 10 time =  725 queue_length = 0
# Customer joins queue caseid = 15 time =  733 queue_length = 1
# NEXT ARRIVAL TIME:  773
# Begin_service caseid = 15 time =  733 queue_length = 1
# End_service caseid = 14 time =  734 queue_length = 0
# Customer joins queue caseid = 16 time =  773 queue_length = 1
# NEXT ARRIVAL TIME:  825
# Begin_service caseid = 16 time =  773 queue_length = 1
# End_service caseid = 15 time =  793 queue_length = 0
# Customer joins queue caseid = 17 time =  825 queue_length = 1
# NEXT ARRIVAL TIME:  872
# Begin_service caseid = 17 time =  825 queue_length = 1
# Customer joins queue caseid = 18 time =  872 queue_length = 1
# NEXT ARRIVAL TIME:  963
# Begin_service caseid = 18 time =  872 queue_length = 1
# End_service caseid = 16 time =  909 queue_length = 0
# Customer joins queue caseid = 19 time =  963 queue_length = 1
# NEXT ARRIVAL TIME:  969
# Begin_service caseid = 19 time =  963 queue_length = 1
# Customer joins queue caseid = 20 time =  969 queue_length = 1
# NEXT ARRIVAL TIME:  984
# Customer joins queue caseid = 21 time =  984 queue_length = 2
# NEXT ARRIVAL TIME:  988
# Customer joins queue caseid = 22 time =  988 queue_length = 3
# NEXT ARRIVAL TIME:  992
# Customer joins queue caseid = 23 time =  992 queue_length = 4
# NEXT ARRIVAL TIME:  1032
# End_service caseid = 18 time =  1021 queue_length = 4
# Begin_service caseid = 20 time =  1021 queue_length = 4
# Customer joins queue caseid = 24 time =  1032 queue_length = 4
# NEXT ARRIVAL TIME:  1093
# End_service caseid = 20 time =  1081 queue_length = 4
# Begin_service caseid = 21 time =  1081 queue_length = 4
# Customer joins queue caseid = 25 time =  1093 queue_length = 4
# NEXT ARRIVAL TIME:  1181
# End_service caseid = 17 time =  1118 queue_length = 4
# Begin_service caseid = 22 time =  1118 queue_length = 4
# End_service caseid = 22 time =  1178 queue_length = 3
# Begin_service caseid = 23 time =  1178 queue_length = 3
# Customer joins queue caseid = 26 time =  1181 queue_length = 3
# NEXT ARRIVAL TIME:  1322
# End_service caseid = 21 time =  1208 queue_length = 3
# Begin_service caseid = 24 time =  1208 queue_length = 3
# End_service caseid = 23 time =  1238 queue_length = 2
# Begin_service caseid = 25 time =  1238 queue_length = 2
# End_service caseid = 19 time =  1263 queue_length = 1
# Begin_service caseid = 26 time =  1263 queue_length = 1
# End_service caseid = 24 time =  1268 queue_length = 0
# Customer joins queue caseid = 27 time =  1322 queue_length = 1
# NEXT ARRIVAL TIME:  1426
# Begin_service caseid = 27 time =  1322 queue_length = 1
# End_service caseid = 25 time =  1342 queue_length = 0
# End_service caseid = 26 time =  1345 queue_length = 0
# End_service caseid = 27 time =  1406 queue_length = 0
# Customer joins queue caseid = 28 time =  1426 queue_length = 1
# NEXT ARRIVAL TIME:  1493
# Begin_service caseid = 28 time =  1426 queue_length = 1
# Customer joins queue caseid = 29 time =  1493 queue_length = 1
# NEXT ARRIVAL TIME:  1496
# Begin_service caseid = 29 time =  1493 queue_length = 1
# Customer joins queue caseid = 30 time =  1496 queue_length = 1
# NEXT ARRIVAL TIME:  1723
# Begin_service caseid = 30 time =  1496 queue_length = 1
# End_service caseid = 28 time =  1497 queue_length = 0
# End_service caseid = 30 time =  1556 queue_length = 0
# End_service caseid = 29 time =  1678 queue_length = 0
# Customer joins queue caseid = 31 time =  1723 queue_length = 1
# NEXT ARRIVAL TIME:  1725
# Begin_service caseid = 31 time =  1723 queue_length = 1
# Customer joins queue caseid = 32 time =  1725 queue_length = 1
# NEXT ARRIVAL TIME:  1727
# Begin_service caseid = 32 time =  1725 queue_length = 1
# Customer joins queue caseid = 33 time =  1727 queue_length = 1
# NEXT ARRIVAL TIME:  1879
# Begin_service caseid = 33 time =  1727 queue_length = 1
# End_service caseid = 31 time =  1837 queue_length = 0
# Customer joins queue caseid = 34 time =  1879 queue_length = 1
# NEXT ARRIVAL TIME:  1928
# Begin_service caseid = 34 time =  1879 queue_length = 1
# Customer joins queue caseid = 35 time =  1928 queue_length = 1
# NEXT ARRIVAL TIME:  1988
# End_service caseid = 33 time =  1930 queue_length = 1
# Begin_service caseid = 35 time =  1930 queue_length = 1
# End_service caseid = 34 time =  1939 queue_length = 0
# End_service caseid = 32 time =  1979 queue_length = 0
# Customer joins queue caseid = 36 time =  1988 queue_length = 1
# NEXT ARRIVAL TIME:  2005
# Begin_service caseid = 36 time =  1988 queue_length = 1
# End_service caseid = 35 time =  1990 queue_length = 0
# Customer joins queue caseid = 37 time =  2005 queue_length = 1
# NEXT ARRIVAL TIME:  2007
# Begin_service caseid = 37 time =  2005 queue_length = 1
# Customer joins queue caseid = 38 time =  2007 queue_length = 1
# NEXT ARRIVAL TIME:  2055
# Begin_service caseid = 38 time =  2007 queue_length = 1
# End_service caseid = 36 time =  2048 queue_length = 0
# Customer joins queue caseid = 39 time =  2055 queue_length = 1
# NEXT ARRIVAL TIME:  2075
# Begin_service caseid = 39 time =  2055 queue_length = 1
# End_service caseid = 38 time =  2067 queue_length = 0
# Customer joins queue caseid = 40 time =  2075 queue_length = 1
# NEXT ARRIVAL TIME:  2101
# Begin_service caseid = 40 time =  2075 queue_length = 1
# Customer joins queue caseid = 41 time =  2101 queue_length = 1
# NEXT ARRIVAL TIME:  2139
# End_service caseid = 37 time =  2103 queue_length = 1
# Begin_service caseid = 41 time =  2103 queue_length = 1
# End_service caseid = 39 time =  2115 queue_length = 0
# End_service caseid = 40 time =  2135 queue_length = 0
# Customer joins queue caseid = 42 time =  2139 queue_length = 1
# NEXT ARRIVAL TIME:  2166
# Begin_service caseid = 42 time =  2139 queue_length = 1
# Customer joins queue caseid = 43 time =  2166 queue_length = 1
# NEXT ARRIVAL TIME:  2193
# Begin_service caseid = 43 time =  2166 queue_length = 1
# Customer joins queue caseid = 44 time =  2193 queue_length = 1
# NEXT ARRIVAL TIME:  2338
# End_service caseid = 42 time =  2199 queue_length = 1
# Begin_service caseid = 44 time =  2199 queue_length = 1
# End_service caseid = 41 time =  2212 queue_length = 0
# End_service caseid = 43 time =  2226 queue_length = 0
# End_service caseid = 44 time =  2259 queue_length = 0
# Customer joins queue caseid = 45 time =  2338 queue_length = 1
# NEXT ARRIVAL TIME:  2375
# Begin_service caseid = 45 time =  2338 queue_length = 1
# Customer joins queue caseid = 46 time =  2375 queue_length = 1
# NEXT ARRIVAL TIME:  2389
# Begin_service caseid = 46 time =  2375 queue_length = 1
# Customer joins queue caseid = 47 time =  2389 queue_length = 1
# NEXT ARRIVAL TIME:  2426
# Begin_service caseid = 47 time =  2389 queue_length = 1
# End_service caseid = 45 time =  2413 queue_length = 0
# Customer joins queue caseid = 48 time =  2426 queue_length = 1
# NEXT ARRIVAL TIME:  2529
# Begin_service caseid = 48 time =  2426 queue_length = 1
# End_service caseid = 46 time =  2441 queue_length = 0
# End_service caseid = 47 time =  2475 queue_length = 0
# Customer joins queue caseid = 49 time =  2529 queue_length = 1
# NEXT ARRIVAL TIME:  2609
# Begin_service caseid = 49 time =  2529 queue_length = 1
# End_service caseid = 49 time =  2598 queue_length = 0
# Customer joins queue caseid = 50 time =  2609 queue_length = 1
# NEXT ARRIVAL TIME:  2632
# Begin_service caseid = 50 time =  2609 queue_length = 1
# Customer joins queue caseid = 51 time =  2632 queue_length = 1
# NEXT ARRIVAL TIME:  2634
# Begin_service caseid = 51 time =  2632 queue_length = 1
# Customer joins queue caseid = 52 time =  2634 queue_length = 1
# NEXT ARRIVAL TIME:  2649
# End_service caseid = 48 time =  2646 queue_length = 1
# Begin_service caseid = 52 time =  2646 queue_length = 1
# Customer joins queue caseid = 53 time =  2649 queue_length = 1
# NEXT ARRIVAL TIME:  2741
# End_service caseid = 50 time =  2669 queue_length = 1
# Begin_service caseid = 53 time =  2669 queue_length = 1
# End_service caseid = 52 time =  2706 queue_length = 0
# End_service caseid = 51 time =  2707 queue_length = 0
# Customer joins queue caseid = 54 time =  2741 queue_length = 1
# NEXT ARRIVAL TIME:  2741
# Begin_service caseid = 54 time =  2741 queue_length = 1
# Customer joins queue caseid = 55 time =  2741 queue_length = 1
# NEXT ARRIVAL TIME:  2746
# Begin_service caseid = 55 time =  2741 queue_length = 1
# Customer joins queue caseid = 56 time =  2746 queue_length = 1
# NEXT ARRIVAL TIME:  2818
# End_service caseid = 53 time =  2752 queue_length = 1
# Begin_service caseid = 56 time =  2752 queue_length = 1
# End_service caseid = 54 time =  2807 queue_length = 0
# End_service caseid = 56 time =  2812 queue_length = 0
# Customer joins queue caseid = 57 time =  2818 queue_length = 1
# NEXT ARRIVAL TIME:  2863
# Begin_service caseid = 57 time =  2818 queue_length = 1
# End_service caseid = 55 time =  2835 queue_length = 0
# Customer joins queue caseid = 58 time =  2863 queue_length = 1
# NEXT ARRIVAL TIME:  3011
# Begin_service caseid = 58 time =  2863 queue_length = 1
# End_service caseid = 57 time =  2878 queue_length = 0
# Customer joins queue caseid = 59 time =  3011 queue_length = 1
# NEXT ARRIVAL TIME:  3065
# Begin_service caseid = 59 time =  3011 queue_length = 1
# Customer joins queue caseid = 60 time =  3065 queue_length = 1
# NEXT ARRIVAL TIME:  3092
# Begin_service caseid = 60 time =  3065 queue_length = 1
# Customer joins queue caseid = 61 time =  3092 queue_length = 1
# NEXT ARRIVAL TIME:  3094
# Customer joins queue caseid = 62 time =  3094 queue_length = 2
# NEXT ARRIVAL TIME:  3104
# Customer joins queue caseid = 63 time =  3104 queue_length = 3
# NEXT ARRIVAL TIME:  3113
# Customer joins queue caseid = 64 time =  3113 queue_length = 4
# NEXT ARRIVAL TIME:  3239
# End_service caseid = 59 time =  3124 queue_length = 4
# Begin_service caseid = 61 time =  3124 queue_length = 4
# End_service caseid = 58 time =  3126 queue_length = 3
# Begin_service caseid = 62 time =  3126 queue_length = 3
# End_service caseid = 60 time =  3186 queue_length = 2
# Begin_service caseid = 63 time =  3186 queue_length = 2
# Customer joins queue caseid = 65 time =  3239 queue_length = 2
# NEXT ARRIVAL TIME:  3271
# End_service caseid = 63 time =  3246 queue_length = 2
# Begin_service caseid = 64 time =  3246 queue_length = 2
# Customer joins queue caseid = 66 time =  3271 queue_length = 2
# NEXT ARRIVAL TIME:  3288
# End_service caseid = 61 time =  3272 queue_length = 2
# Begin_service caseid = 65 time =  3272 queue_length = 2
# Customer joins queue caseid = 67 time =  3288 queue_length = 2
# NEXT ARRIVAL TIME:  3348
# End_service caseid = 64 time =  3306 queue_length = 2
# Begin_service caseid = 66 time =  3306 queue_length = 2
# End_service caseid = 62 time =  3308 queue_length = 1
# Begin_service caseid = 67 time =  3308 queue_length = 1
# End_service caseid = 65 time =  3333 queue_length = 0
# Customer joins queue caseid = 68 time =  3348 queue_length = 1
# NEXT ARRIVAL TIME:  3390
# Begin_service caseid = 68 time =  3348 queue_length = 1
# End_service caseid = 66 time =  3375 queue_length = 0
# Customer joins queue caseid = 69 time =  3390 queue_length = 1
# NEXT ARRIVAL TIME:  3428
# Begin_service caseid = 69 time =  3390 queue_length = 1
# End_service caseid = 67 time =  3427 queue_length = 0
# Customer joins queue caseid = 70 time =  3428 queue_length = 1
# NEXT ARRIVAL TIME:  3448
# Begin_service caseid = 70 time =  3428 queue_length = 1
# End_service caseid = 68 time =  3439 queue_length = 0
# Customer joins queue caseid = 71 time =  3448 queue_length = 1
# NEXT ARRIVAL TIME:  3493
# Begin_service caseid = 71 time =  3448 queue_length = 1
# End_service caseid = 69 time =  3487 queue_length = 0
# Customer joins queue caseid = 72 time =  3493 queue_length = 1
# NEXT ARRIVAL TIME:  3596
# Begin_service caseid = 72 time =  3493 queue_length = 1
# End_service caseid = 71 time =  3551 queue_length = 0
# Customer joins queue caseid = 73 time =  3596 queue_length = 1
# NEXT ARRIVAL TIME:  3633
# Begin_service caseid = 73 time =  3596 queue_length = 1
# End_service caseid = 70 time =  3612 queue_length = 0
# End_service caseid = 72 time =  3630 queue_length = 0
# Customer joins queue caseid = 74 time =  3633 queue_length = 1
# NEXT ARRIVAL TIME:  3662
# Begin_service caseid = 74 time =  3633 queue_length = 1
# End_service caseid = 73 time =  3656 queue_length = 0
# Customer joins queue caseid = 75 time =  3662 queue_length = 1
# NEXT ARRIVAL TIME:  3672
# Begin_service caseid = 75 time =  3662 queue_length = 1
# Customer joins queue caseid = 76 time =  3672 queue_length = 1
# NEXT ARRIVAL TIME:  3682
# Begin_service caseid = 76 time =  3672 queue_length = 1
# Customer joins queue caseid = 77 time =  3682 queue_length = 1
# NEXT ARRIVAL TIME:  3728
# Customer joins queue caseid = 78 time =  3728 queue_length = 2
# NEXT ARRIVAL TIME:  3749
# Customer joins queue caseid = 79 time =  3749 queue_length = 3
# NEXT ARRIVAL TIME:  3799
# End_service caseid = 76 time =  3760 queue_length = 3
# Begin_service caseid = 77 time =  3760 queue_length = 3
# End_service caseid = 75 time =  3765 queue_length = 2
# Begin_service caseid = 78 time =  3765 queue_length = 2
# Customer joins queue caseid = 80 time =  3799 queue_length = 2
# NEXT ARRIVAL TIME:  3960
# End_service caseid = 77 time =  3839 queue_length = 2
# Begin_service caseid = 79 time =  3839 queue_length = 2
# End_service caseid = 78 time =  3860 queue_length = 1
# Begin_service caseid = 80 time =  3860 queue_length = 1
# End_service caseid = 79 time =  3899 queue_length = 0
# End_service caseid = 80 time =  3920 queue_length = 0
# End_service caseid = 74 time =  3925 queue_length = 0
# Customer joins queue caseid = 81 time =  3960 queue_length = 1
# NEXT ARRIVAL TIME:  4218
# Begin_service caseid = 81 time =  3960 queue_length = 1
# End_service caseid = 81 time =  4020 queue_length = 0
# Customer joins queue caseid = 82 time =  4218 queue_length = 1
# NEXT ARRIVAL TIME:  4274
# Begin_service caseid = 82 time =  4218 queue_length = 1
# Customer joins queue caseid = 83 time =  4274 queue_length = 1
# NEXT ARRIVAL TIME:  4363
# Begin_service caseid = 83 time =  4274 queue_length = 1
# End_service caseid = 82 time =  4314 queue_length = 0
# End_service caseid = 83 time =  4334 queue_length = 0
# Customer joins queue caseid = 84 time =  4363 queue_length = 1
# NEXT ARRIVAL TIME:  4423
# Begin_service caseid = 84 time =  4363 queue_length = 1
# End_service caseid = 84 time =  4423 queue_length = 0
# Customer joins queue caseid = 85 time =  4423 queue_length = 1
# NEXT ARRIVAL TIME:  4445
# Begin_service caseid = 85 time =  4423 queue_length = 1
# Customer joins queue caseid = 86 time =  4445 queue_length = 1
# NEXT ARRIVAL TIME:  4477
# Begin_service caseid = 86 time =  4445 queue_length = 1
# Customer joins queue caseid = 87 time =  4477 queue_length = 1
# NEXT ARRIVAL TIME:  4638
# Begin_service caseid = 87 time =  4477 queue_length = 1
# End_service caseid = 86 time =  4505 queue_length = 0
# End_service caseid = 87 time =  4537 queue_length = 0
# End_service caseid = 85 time =  4628 queue_length = 0
# Customer joins queue caseid = 88 time =  4638 queue_length = 1
# NEXT ARRIVAL TIME:  4665
# Begin_service caseid = 88 time =  4638 queue_length = 1
# Customer joins queue caseid = 89 time =  4665 queue_length = 1
# NEXT ARRIVAL TIME:  4666
# Begin_service caseid = 89 time =  4665 queue_length = 1
# Customer joins queue caseid = 90 time =  4666 queue_length = 1
# NEXT ARRIVAL TIME:  4683
# Begin_service caseid = 90 time =  4666 queue_length = 1
# Customer joins queue caseid = 91 time =  4683 queue_length = 1
# NEXT ARRIVAL TIME:  4765
# End_service caseid = 88 time =  4698 queue_length = 1
# Begin_service caseid = 91 time =  4698 queue_length = 1
# End_service caseid = 89 time =  4725 queue_length = 0
# End_service caseid = 90 time =  4726 queue_length = 0
# End_service caseid = 91 time =  4758 queue_length = 0
# Customer joins queue caseid = 92 time =  4765 queue_length = 1
# NEXT ARRIVAL TIME:  4896
# Begin_service caseid = 92 time =  4765 queue_length = 1
# End_service caseid = 92 time =  4825 queue_length = 0
# Customer joins queue caseid = 93 time =  4896 queue_length = 1
# NEXT ARRIVAL TIME:  4978
# Begin_service caseid = 93 time =  4896 queue_length = 1
# End_service caseid = 93 time =  4956 queue_length = 0
# Customer joins queue caseid = 94 time =  4978 queue_length = 1
# NEXT ARRIVAL TIME:  4982
# Begin_service caseid = 94 time =  4978 queue_length = 1
# Customer joins queue caseid = 95 time =  4982 queue_length = 1
# NEXT ARRIVAL TIME:  5018
# Begin_service caseid = 95 time =  4982 queue_length = 1
# Customer joins queue caseid = 96 time =  5018 queue_length = 1
# NEXT ARRIVAL TIME:  5114
# Begin_service caseid = 96 time =  5018 queue_length = 1
# End_service caseid = 94 time =  5038 queue_length = 0
# Customer joins queue caseid = 97 time =  5114 queue_length = 1
# NEXT ARRIVAL TIME:  5126
# Begin_service caseid = 97 time =  5114 queue_length = 1
# Customer joins queue caseid = 98 time =  5126 queue_length = 1
# NEXT ARRIVAL TIME:  5233
# End_service caseid = 96 time =  5158 queue_length = 1
# Begin_service caseid = 98 time =  5158 queue_length = 1
# End_service caseid = 98 time =  5218 queue_length = 0
# Customer joins queue caseid = 99 time =  5233 queue_length = 1
# NEXT ARRIVAL TIME:  5234
# Begin_service caseid = 99 time =  5233 queue_length = 1
# Customer joins queue caseid = 100 time =  5234 queue_length = 1
# NEXT ARRIVAL TIME:  5351
# End_service caseid = 95 time =  5282 queue_length = 1
# Begin_service caseid = 100 time =  5282 queue_length = 1
# End_service caseid = 97 time =  5283 queue_length = 0
# End_service caseid = 100 time =  5342 queue_length = 0
# Customer joins queue caseid = 101 time =  5351 queue_length = 1
# NEXT ARRIVAL TIME:  5557
# Begin_service caseid = 101 time =  5351 queue_length = 1
# End_service caseid = 99 time =  5404 queue_length = 0
# End_service caseid = 101 time =  5411 queue_length = 0
# Customer joins queue caseid = 102 time =  5557 queue_length = 1
# NEXT ARRIVAL TIME:  5602
# Begin_service caseid = 102 time =  5557 queue_length = 1
# Customer joins queue caseid = 103 time =  5602 queue_length = 1
# NEXT ARRIVAL TIME:  5657
# Begin_service caseid = 103 time =  5602 queue_length = 1
# End_service caseid = 102 time =  5617 queue_length = 0
# Customer joins queue caseid = 104 time =  5657 queue_length = 1
# NEXT ARRIVAL TIME:  5686
# Begin_service caseid = 104 time =  5657 queue_length = 1
# End_service caseid = 103 time =  5678 queue_length = 0
# Customer joins queue caseid = 105 time =  5686 queue_length = 1
# NEXT ARRIVAL TIME:  5714
# Begin_service caseid = 105 time =  5686 queue_length = 1
# Customer joins queue caseid = 106 time =  5714 queue_length = 1
# NEXT ARRIVAL TIME:  5731
# Begin_service caseid = 106 time =  5714 queue_length = 1
# Customer joins queue caseid = 107 time =  5731 queue_length = 1
# NEXT ARRIVAL TIME:  5743
# Customer joins queue caseid = 108 time =  5743 queue_length = 2
# NEXT ARRIVAL TIME:  5861
# End_service caseid = 106 time =  5774 queue_length = 2
# Begin_service caseid = 107 time =  5774 queue_length = 2
# End_service caseid = 104 time =  5788 queue_length = 1
# Begin_service caseid = 108 time =  5788 queue_length = 1
# End_service caseid = 107 time =  5834 queue_length = 0
# Customer joins queue caseid = 109 time =  5861 queue_length = 1
# NEXT ARRIVAL TIME:  5920
# Begin_service caseid = 109 time =  5861 queue_length = 1
# Customer joins queue caseid = 110 time =  5920 queue_length = 1
# NEXT ARRIVAL TIME:  5976
# Customer joins queue caseid = 111 time =  5976 queue_length = 2
# NEXT ARRIVAL TIME:  5998
# End_service caseid = 105 time =  5977 queue_length = 2
# Begin_service caseid = 110 time =  5977 queue_length = 2
# Customer joins queue caseid = 112 time =  5998 queue_length = 2
# NEXT ARRIVAL TIME:  6112
# End_service caseid = 109 time =  6075 queue_length = 2
# Begin_service caseid = 111 time =  6075 queue_length = 2
# End_service caseid = 108 time =  6088 queue_length = 1
# Begin_service caseid = 112 time =  6088 queue_length = 1
# End_service caseid = 110 time =  6111 queue_length = 0
# Customer joins queue caseid = 113 time =  6112 queue_length = 1
# NEXT ARRIVAL TIME:  6119
# Begin_service caseid = 113 time =  6112 queue_length = 1
# Customer joins queue caseid = 114 time =  6119 queue_length = 1
# NEXT ARRIVAL TIME:  6128
# Customer joins queue caseid = 115 time =  6128 queue_length = 2
# NEXT ARRIVAL TIME:  6263
# End_service caseid = 113 time =  6176 queue_length = 2
# Begin_service caseid = 114 time =  6176 queue_length = 2
# End_service caseid = 114 time =  6236 queue_length = 1
# Begin_service caseid = 115 time =  6236 queue_length = 1
# End_service caseid = 111 time =  6261 queue_length = 0
# Customer joins queue caseid = 116 time =  6263 queue_length = 1
# NEXT ARRIVAL TIME:  6279
# Begin_service caseid = 116 time =  6263 queue_length = 1
# Customer joins queue caseid = 117 time =  6279 queue_length = 1
# NEXT ARRIVAL TIME:  6308
# Customer joins queue caseid = 118 time =  6308 queue_length = 2
# NEXT ARRIVAL TIME:  6375
# Customer joins queue caseid = 119 time =  6375 queue_length = 3
# NEXT ARRIVAL TIME:  6412
# End_service caseid = 112 time =  6388 queue_length = 3
# Begin_service caseid = 117 time =  6388 queue_length = 3
# End_service caseid = 116 time =  6403 queue_length = 2
# Begin_service caseid = 118 time =  6403 queue_length = 2
# Customer joins queue caseid = 120 time =  6412 queue_length = 2
# NEXT ARRIVAL TIME:  6492
# End_service caseid = 117 time =  6448 queue_length = 2
# Begin_service caseid = 119 time =  6448 queue_length = 2
# Customer joins queue caseid = 121 time =  6492 queue_length = 2
# NEXT ARRIVAL TIME:  6515
# End_service caseid = 119 time =  6508 queue_length = 2
# Begin_service caseid = 120 time =  6508 queue_length = 2
# Customer joins queue caseid = 122 time =  6515 queue_length = 2
# NEXT ARRIVAL TIME:  6600
# End_service caseid = 115 time =  6536 queue_length = 2
# Begin_service caseid = 121 time =  6536 queue_length = 2
# End_service caseid = 118 time =  6545 queue_length = 1
# Begin_service caseid = 122 time =  6545 queue_length = 1
# Customer joins queue caseid = 123 time =  6600 queue_length = 1
# NEXT ARRIVAL TIME:  6614
# End_service caseid = 122 time =  6605 queue_length = 1
# Begin_service caseid = 123 time =  6605 queue_length = 1
# End_service caseid = 121 time =  6613 queue_length = 0
# Customer joins queue caseid = 124 time =  6614 queue_length = 1
# NEXT ARRIVAL TIME:  6670
# Begin_service caseid = 124 time =  6614 queue_length = 1
# End_service caseid = 120 time =  6615 queue_length = 0
# Customer joins queue caseid = 125 time =  6670 queue_length = 1
# NEXT ARRIVAL TIME:  6727
# Begin_service caseid = 125 time =  6670 queue_length = 1
# End_service caseid = 124 time =  6686 queue_length = 0
# End_service caseid = 123 time =  6711 queue_length = 0
# Customer joins queue caseid = 126 time =  6727 queue_length = 1
# NEXT ARRIVAL TIME:  6779
# Begin_service caseid = 126 time =  6727 queue_length = 1
# End_service caseid = 125 time =  6730 queue_length = 0
# Customer joins queue caseid = 127 time =  6779 queue_length = 1
# NEXT ARRIVAL TIME:  6818
# Begin_service caseid = 127 time =  6779 queue_length = 1
# End_service caseid = 126 time =  6787 queue_length = 0
# Customer joins queue caseid = 128 time =  6818 queue_length = 1
# NEXT ARRIVAL TIME:  6825
# Begin_service caseid = 128 time =  6818 queue_length = 1
# Customer joins queue caseid = 129 time =  6825 queue_length = 1
# NEXT ARRIVAL TIME:  6828
# Begin_service caseid = 129 time =  6825 queue_length = 1
# Customer joins queue caseid = 130 time =  6828 queue_length = 1
# NEXT ARRIVAL TIME:  6916
# End_service caseid = 127 time =  6839 queue_length = 1
# Begin_service caseid = 130 time =  6839 queue_length = 1
# End_service caseid = 129 time =  6885 queue_length = 0
# End_service caseid = 128 time =  6902 queue_length = 0
# Customer joins queue caseid = 131 time =  6916 queue_length = 1
# NEXT ARRIVAL TIME:  6963
# Begin_service caseid = 131 time =  6916 queue_length = 1
# End_service caseid = 130 time =  6934 queue_length = 0
# Customer joins queue caseid = 132 time =  6963 queue_length = 1
# NEXT ARRIVAL TIME:  6969
# Begin_service caseid = 132 time =  6963 queue_length = 1
# Customer joins queue caseid = 133 time =  6969 queue_length = 1
# NEXT ARRIVAL TIME:  7023
# Begin_service caseid = 133 time =  6969 queue_length = 1
# End_service caseid = 131 time =  7016 queue_length = 0
# Customer joins queue caseid = 134 time =  7023 queue_length = 1
# NEXT ARRIVAL TIME:  7130
# Begin_service caseid = 134 time =  7023 queue_length = 1
# End_service caseid = 133 time =  7029 queue_length = 0
# End_service caseid = 132 time =  7081 queue_length = 0
# Customer joins queue caseid = 135 time =  7130 queue_length = 1
# NEXT ARRIVAL TIME:  7147
# Begin_service caseid = 135 time =  7130 queue_length = 1
# Customer joins queue caseid = 136 time =  7147 queue_length = 1
# NEXT ARRIVAL TIME:  7265
# Begin_service caseid = 136 time =  7147 queue_length = 1
# End_service caseid = 134 time =  7171 queue_length = 0
# End_service caseid = 136 time =  7207 queue_length = 0
# Customer joins queue caseid = 137 time =  7265 queue_length = 1
# NEXT ARRIVAL TIME:  7268
# Begin_service caseid = 137 time =  7265 queue_length = 1
# Customer joins queue caseid = 138 time =  7268 queue_length = 1
# NEXT ARRIVAL TIME:  7357
# Begin_service caseid = 138 time =  7268 queue_length = 1
# End_service caseid = 137 time =  7325 queue_length = 0
# End_service caseid = 138 time =  7328 queue_length = 0
# Customer joins queue caseid = 139 time =  7357 queue_length = 1
# NEXT ARRIVAL TIME:  7486
# Begin_service caseid = 139 time =  7357 queue_length = 1
# End_service caseid = 139 time =  7417 queue_length = 0
# End_service caseid = 135 time =  7430 queue_length = 0
# Customer joins queue caseid = 140 time =  7486 queue_length = 1
# NEXT ARRIVAL TIME:  7579
# Begin_service caseid = 140 time =  7486 queue_length = 1
# Customer joins queue caseid = 141 time =  7579 queue_length = 1
# NEXT ARRIVAL TIME:  7590
# Begin_service caseid = 141 time =  7579 queue_length = 1
# Customer joins queue caseid = 142 time =  7590 queue_length = 1
# NEXT ARRIVAL TIME:  7722
# Begin_service caseid = 142 time =  7590 queue_length = 1
# End_service caseid = 142 time =  7650 queue_length = 0
# End_service caseid = 140 time =  7672 queue_length = 0
# End_service caseid = 141 time =  7672 queue_length = 0
# Customer joins queue caseid = 143 time =  7722 queue_length = 1
# NEXT ARRIVAL TIME:  7846
# Begin_service caseid = 143 time =  7722 queue_length = 1
# End_service caseid = 143 time =  7782 queue_length = 0
# Customer joins queue caseid = 144 time =  7846 queue_length = 1
# NEXT ARRIVAL TIME:  7850
# Begin_service caseid = 144 time =  7846 queue_length = 1
# Customer joins queue caseid = 145 time =  7850 queue_length = 1
# NEXT ARRIVAL TIME:  7892
# Begin_service caseid = 145 time =  7850 queue_length = 1
# Customer joins queue caseid = 146 time =  7892 queue_length = 1
# NEXT ARRIVAL TIME:  8001
# Begin_service caseid = 146 time =  7892 queue_length = 1
# End_service caseid = 144 time =  7906 queue_length = 0
# End_service caseid = 145 time =  7910 queue_length = 0
# Customer joins queue caseid = 147 time =  8001 queue_length = 1
# NEXT ARRIVAL TIME:  8132
# Begin_service caseid = 147 time =  8001 queue_length = 1
# End_service caseid = 147 time =  8061 queue_length = 0
# End_service caseid = 146 time =  8106 queue_length = 0
# Customer joins queue caseid = 148 time =  8132 queue_length = 1
# NEXT ARRIVAL TIME:  8202
# Begin_service caseid = 148 time =  8132 queue_length = 1
# Customer joins queue caseid = 149 time =  8202 queue_length = 1
# NEXT ARRIVAL TIME:  8203
# Begin_service caseid = 149 time =  8202 queue_length = 1
# Customer joins queue caseid = 150 time =  8203 queue_length = 1
# NEXT ARRIVAL TIME:  8306
# Begin_service caseid = 150 time =  8203 queue_length = 1
# End_service caseid = 150 time =  8263 queue_length = 0
# End_service caseid = 148 time =  8272 queue_length = 0
# Customer joins queue caseid = 151 time =  8306 queue_length = 1
# NEXT ARRIVAL TIME:  8306
# Begin_service caseid = 151 time =  8306 queue_length = 1
# Customer joins queue caseid = 152 time =  8306 queue_length = 1
# NEXT ARRIVAL TIME:  8325
# Begin_service caseid = 152 time =  8306 queue_length = 1
# End_service caseid = 149 time =  8316 queue_length = 0
# Customer joins queue caseid = 153 time =  8325 queue_length = 1
# NEXT ARRIVAL TIME:  8332
# Begin_service caseid = 153 time =  8325 queue_length = 1
# Customer joins queue caseid = 154 time =  8332 queue_length = 1
# NEXT ARRIVAL TIME:  8349
# Customer joins queue caseid = 155 time =  8349 queue_length = 2
# NEXT ARRIVAL TIME:  8461
# End_service caseid = 153 time =  8385 queue_length = 2
# Begin_service caseid = 154 time =  8385 queue_length = 2
# End_service caseid = 152 time =  8423 queue_length = 1
# Begin_service caseid = 155 time =  8423 queue_length = 1
# End_service caseid = 154 time =  8454 queue_length = 0
# Customer joins queue caseid = 156 time =  8461 queue_length = 1
# NEXT ARRIVAL TIME:  8492
# Begin_service caseid = 156 time =  8461 queue_length = 1
# End_service caseid = 155 time =  8483 queue_length = 0
# Customer joins queue caseid = 157 time =  8492 queue_length = 1
# NEXT ARRIVAL TIME:  8508
# Begin_service caseid = 157 time =  8492 queue_length = 1
# Customer joins queue caseid = 158 time =  8508 queue_length = 1
# NEXT ARRIVAL TIME:  8577
# End_service caseid = 156 time =  8521 queue_length = 1
# Begin_service caseid = 158 time =  8521 queue_length = 1
# Customer joins queue caseid = 159 time =  8577 queue_length = 1
# NEXT ARRIVAL TIME:  8610
# End_service caseid = 151 time =  8606 queue_length = 1
# Begin_service caseid = 159 time =  8606 queue_length = 1
# Customer joins queue caseid = 160 time =  8610 queue_length = 1
# NEXT ARRIVAL TIME:  8664
# End_service caseid = 158 time =  8638 queue_length = 1
# Begin_service caseid = 160 time =  8638 queue_length = 1
# Customer joins queue caseid = 161 time =  8664 queue_length = 1
# NEXT ARRIVAL TIME:  8722
# End_service caseid = 159 time =  8666 queue_length = 1
# Begin_service caseid = 161 time =  8666 queue_length = 1
# Customer joins queue caseid = 162 time =  8722 queue_length = 1
# NEXT ARRIVAL TIME:  8781
# End_service caseid = 157 time =  8746 queue_length = 1
# Begin_service caseid = 162 time =  8746 queue_length = 1
# Customer joins queue caseid = 163 time =  8781 queue_length = 1
# NEXT ARRIVAL TIME:  8807
# End_service caseid = 160 time =  8789 queue_length = 1
# Begin_service caseid = 163 time =  8789 queue_length = 1
# End_service caseid = 162 time =  8806 queue_length = 0
# Customer joins queue caseid = 164 time =  8807 queue_length = 1
# NEXT ARRIVAL TIME:  8821
# Begin_service caseid = 164 time =  8807 queue_length = 1
# Customer joins queue caseid = 165 time =  8821 queue_length = 1
# NEXT ARRIVAL TIME:  8852
# Customer joins queue caseid = 166 time =  8852 queue_length = 2
# NEXT ARRIVAL TIME:  8907
# End_service caseid = 164 time =  8893 queue_length = 2
# Begin_service caseid = 165 time =  8893 queue_length = 2
# Customer joins queue caseid = 167 time =  8907 queue_length = 2
# NEXT ARRIVAL TIME:  8938
# End_service caseid = 161 time =  8918 queue_length = 2
# Begin_service caseid = 166 time =  8918 queue_length = 2
# Customer joins queue caseid = 168 time =  8938 queue_length = 2
# NEXT ARRIVAL TIME:  8978
# End_service caseid = 163 time =  8972 queue_length = 2
# Begin_service caseid = 167 time =  8972 queue_length = 2
# Customer joins queue caseid = 169 time =  8978 queue_length = 2
# NEXT ARRIVAL TIME:  9015
# End_service caseid = 165 time =  9008 queue_length = 2
# Begin_service caseid = 168 time =  9008 queue_length = 2
# Customer joins queue caseid = 170 time =  9015 queue_length = 2
# NEXT ARRIVAL TIME:  9026
# Customer joins queue caseid = 171 time =  9026 queue_length = 3
# NEXT ARRIVAL TIME:  9033
# Customer joins queue caseid = 172 time =  9033 queue_length = 4
# NEXT ARRIVAL TIME:  9100
# End_service caseid = 167 time =  9043 queue_length = 4
# Begin_service caseid = 169 time =  9043 queue_length = 4
# End_service caseid = 166 time =  9064 queue_length = 3
# Begin_service caseid = 170 time =  9064 queue_length = 3
# End_service caseid = 168 time =  9068 queue_length = 2
# Begin_service caseid = 171 time =  9068 queue_length = 2
# Customer joins queue caseid = 173 time =  9100 queue_length = 2
# NEXT ARRIVAL TIME:  9173
# End_service caseid = 169 time =  9103 queue_length = 2
# Begin_service caseid = 172 time =  9103 queue_length = 2
# End_service caseid = 170 time =  9124 queue_length = 1
# Begin_service caseid = 173 time =  9124 queue_length = 1
# End_service caseid = 171 time =  9141 queue_length = 0
# Customer joins queue caseid = 174 time =  9173 queue_length = 1
# NEXT ARRIVAL TIME:  9261
# Begin_service caseid = 174 time =  9173 queue_length = 1
# End_service caseid = 172 time =  9245 queue_length = 0
# End_service caseid = 173 time =  9255 queue_length = 0
# Customer joins queue caseid = 175 time =  9261 queue_length = 1
# NEXT ARRIVAL TIME:  9282
# Begin_service caseid = 175 time =  9261 queue_length = 1
# Customer joins queue caseid = 176 time =  9282 queue_length = 1
# NEXT ARRIVAL TIME:  9342
# Begin_service caseid = 176 time =  9282 queue_length = 1
# End_service caseid = 174 time =  9295 queue_length = 0
# End_service caseid = 176 time =  9342 queue_length = 0
# Customer joins queue caseid = 177 time =  9342 queue_length = 1
# NEXT ARRIVAL TIME:  9345
# Begin_service caseid = 177 time =  9342 queue_length = 1
# Customer joins queue caseid = 178 time =  9345 queue_length = 1
# NEXT ARRIVAL TIME:  9414
# Begin_service caseid = 178 time =  9345 queue_length = 1
# End_service caseid = 177 time =  9402 queue_length = 0
# End_service caseid = 178 time =  9407 queue_length = 0
# Customer joins queue caseid = 179 time =  9414 queue_length = 1
# NEXT ARRIVAL TIME:  9427
# Begin_service caseid = 179 time =  9414 queue_length = 1
# End_service caseid = 175 time =  9422 queue_length = 0
# Customer joins queue caseid = 180 time =  9427 queue_length = 1
# NEXT ARRIVAL TIME:  9461
# Begin_service caseid = 180 time =  9427 queue_length = 1
# Customer joins queue caseid = 181 time =  9461 queue_length = 1
# NEXT ARRIVAL TIME:  9544
# Begin_service caseid = 181 time =  9461 queue_length = 1
# End_service caseid = 179 time =  9474 queue_length = 0
# End_service caseid = 180 time =  9487 queue_length = 0
# End_service caseid = 181 time =  9521 queue_length = 0
# Customer joins queue caseid = 182 time =  9544 queue_length = 1
# NEXT ARRIVAL TIME:  9571
# Begin_service caseid = 182 time =  9544 queue_length = 1
# Customer joins queue caseid = 183 time =  9571 queue_length = 1
# NEXT ARRIVAL TIME:  9584
# Begin_service caseid = 183 time =  9571 queue_length = 1
# Customer joins queue caseid = 184 time =  9584 queue_length = 1
# NEXT ARRIVAL TIME:  9619
# Begin_service caseid = 184 time =  9584 queue_length = 1
# End_service caseid = 182 time =  9618 queue_length = 0
# Customer joins queue caseid = 185 time =  9619 queue_length = 1
# NEXT ARRIVAL TIME:  9677
# Begin_service caseid = 185 time =  9619 queue_length = 1
# End_service caseid = 184 time =  9644 queue_length = 0
# Customer joins queue caseid = 186 time =  9677 queue_length = 1
# NEXT ARRIVAL TIME:  9714
# Begin_service caseid = 186 time =  9677 queue_length = 1
# Customer joins queue caseid = 187 time =  9714 queue_length = 1
# NEXT ARRIVAL TIME:  9718
# Customer joins queue caseid = 188 time =  9718 queue_length = 2
# NEXT ARRIVAL TIME:  9756
# Customer joins queue caseid = 189 time =  9756 queue_length = 3
# NEXT ARRIVAL TIME:  9820
# End_service caseid = 186 time =  9790 queue_length = 3
# Begin_service caseid = 187 time =  9790 queue_length = 3
# End_service caseid = 183 time =  9798 queue_length = 2
# Begin_service caseid = 188 time =  9798 queue_length = 2
# End_service caseid = 185 time =  9805 queue_length = 1
# Begin_service caseid = 189 time =  9805 queue_length = 1
# Customer joins queue caseid = 190 time =  9820 queue_length = 1
# NEXT ARRIVAL TIME:  9829
# Customer joins queue caseid = 191 time =  9829 queue_length = 2
# NEXT ARRIVAL TIME:  9960
# End_service caseid = 187 time =  9850 queue_length = 2
# Begin_service caseid = 190 time =  9850 queue_length = 2
# End_service caseid = 188 time =  9871 queue_length = 1
# Begin_service caseid = 191 time =  9871 queue_length = 1
# End_service caseid = 189 time =  9887 queue_length = 0
# Customer joins queue caseid = 192 time =  9960 queue_length = 1
# NEXT ARRIVAL TIME:  10112
# Begin_service caseid = 192 time =  9960 queue_length = 1
# End_service caseid = 190 time =  9998 queue_length = 0
# End_service caseid = 191 time =  10042 queue_length = 0
# End_service caseid = 192 time =  10062 queue_length = 0
# Customer joins queue caseid = 193 time =  10112 queue_length = 1
# NEXT ARRIVAL TIME:  10134
# Begin_service caseid = 193 time =  10112 queue_length = 1
# Customer joins queue caseid = 194 time =  10134 queue_length = 1
# NEXT ARRIVAL TIME:  10191
# Begin_service caseid = 194 time =  10134 queue_length = 1
# Customer joins queue caseid = 195 time =  10191 queue_length = 1
# NEXT ARRIVAL TIME:  10239
# Begin_service caseid = 195 time =  10191 queue_length = 1
# End_service caseid = 193 time =  10216 queue_length = 0
# Customer joins queue caseid = 196 time =  10239 queue_length = 1
# NEXT ARRIVAL TIME:  10328
# Begin_service caseid = 196 time =  10239 queue_length = 1
# End_service caseid = 195 time =  10251 queue_length = 0
# End_service caseid = 194 time =  10281 queue_length = 0
# Customer joins queue caseid = 197 time =  10328 queue_length = 1
# NEXT ARRIVAL TIME:  10382
# Begin_service caseid = 197 time =  10328 queue_length = 1
# Customer joins queue caseid = 198 time =  10382 queue_length = 1
# NEXT ARRIVAL TIME:  10396
# Begin_service caseid = 198 time =  10382 queue_length = 1
# End_service caseid = 196 time =  10386 queue_length = 0
# Customer joins queue caseid = 199 time =  10396 queue_length = 1
# NEXT ARRIVAL TIME:  10431
# Begin_service caseid = 199 time =  10396 queue_length = 1
# Customer joins queue caseid = 200 time =  10431 queue_length = 1
# NEXT ARRIVAL TIME:  10465
# Customer joins queue caseid = 201 time =  10465 queue_length = 2
# NEXT ARRIVAL TIME:  10595
# End_service caseid = 199 time =  10488 queue_length = 2
# Begin_service caseid = 200 time =  10488 queue_length = 2
# End_service caseid = 198 time =  10521 queue_length = 1
# Begin_service caseid = 201 time =  10521 queue_length = 1
# End_service caseid = 200 time =  10548 queue_length = 0
# End_service caseid = 201 time =  10581 queue_length = 0
# Customer joins queue caseid = 202 time =  10595 queue_length = 1
# NEXT ARRIVAL TIME:  10754
# Begin_service caseid = 202 time =  10595 queue_length = 1
# End_service caseid = 197 time =  10628 queue_length = 0
# End_service caseid = 202 time =  10655 queue_length = 0
# Customer joins queue caseid = 203 time =  10754 queue_length = 1
# NEXT ARRIVAL TIME:  10762
# Begin_service caseid = 203 time =  10754 queue_length = 1
# Customer joins queue caseid = 204 time =  10762 queue_length = 1
# NEXT ARRIVAL TIME:  10871
# Begin_service caseid = 204 time =  10762 queue_length = 1
# Customer joins queue caseid = 205 time =  10871 queue_length = 1
# NEXT ARRIVAL TIME:  11037
# Begin_service caseid = 205 time =  10871 queue_length = 1
# End_service caseid = 203 time =  10954 queue_length = 0
# Customer joins queue caseid = 206 time =  11037 queue_length = 1
# NEXT ARRIVAL TIME:  11039
# Begin_service caseid = 206 time =  11037 queue_length = 1
# Customer joins queue caseid = 207 time =  11039 queue_length = 1
# NEXT ARRIVAL TIME:  11049
# Customer joins queue caseid = 208 time =  11049 queue_length = 2
# NEXT ARRIVAL TIME:  11094
# End_service caseid = 205 time =  11052 queue_length = 2
# Begin_service caseid = 207 time =  11052 queue_length = 2
# End_service caseid = 204 time =  11062 queue_length = 1
# Begin_service caseid = 208 time =  11062 queue_length = 1
# Customer joins queue caseid = 209 time =  11094 queue_length = 1
# NEXT ARRIVAL TIME:  11109
# End_service caseid = 206 time =  11097 queue_length = 1
# Begin_service caseid = 209 time =  11097 queue_length = 1
# Customer joins queue caseid = 210 time =  11109 queue_length = 1
# NEXT ARRIVAL TIME:  11212
# End_service caseid = 207 time =  11112 queue_length = 1
# Begin_service caseid = 210 time =  11112 queue_length = 1
# End_service caseid = 208 time =  11122 queue_length = 0
# End_service caseid = 209 time =  11157 queue_length = 0
# End_service caseid = 210 time =  11172 queue_length = 0
# Customer joins queue caseid = 211 time =  11212 queue_length = 1
# NEXT ARRIVAL TIME:  11358
# Begin_service caseid = 211 time =  11212 queue_length = 1
# End_service caseid = 211 time =  11272 queue_length = 0
# Customer joins queue caseid = 212 time =  11358 queue_length = 1
# NEXT ARRIVAL TIME:  11366
# Begin_service caseid = 212 time =  11358 queue_length = 1
# Customer joins queue caseid = 213 time =  11366 queue_length = 1
# NEXT ARRIVAL TIME:  11538
# Begin_service caseid = 213 time =  11366 queue_length = 1
# End_service caseid = 212 time =  11490 queue_length = 0
# End_service caseid = 213 time =  11504 queue_length = 0
# Customer joins queue caseid = 214 time =  11538 queue_length = 1
# NEXT ARRIVAL TIME:  11760
# Begin_service caseid = 214 time =  11538 queue_length = 1
# End_service caseid = 214 time =  11671 queue_length = 0
# Customer joins queue caseid = 215 time =  11760 queue_length = 1
# NEXT ARRIVAL TIME:  11765
# Begin_service caseid = 215 time =  11760 queue_length = 1
# Customer joins queue caseid = 216 time =  11765 queue_length = 1
# NEXT ARRIVAL TIME:  11787
# Begin_service caseid = 216 time =  11765 queue_length = 1
# Customer joins queue caseid = 217 time =  11787 queue_length = 1
# NEXT ARRIVAL TIME:  11815
# Begin_service caseid = 217 time =  11787 queue_length = 1
# Customer joins queue caseid = 218 time =  11815 queue_length = 1
# NEXT ARRIVAL TIME:  11815
# Customer joins queue caseid = 219 time =  11815 queue_length = 2
# NEXT ARRIVAL TIME:  11870
# End_service caseid = 215 time =  11822 queue_length = 2
# Begin_service caseid = 218 time =  11822 queue_length = 2
# End_service caseid = 216 time =  11825 queue_length = 1
# Begin_service caseid = 219 time =  11825 queue_length = 1
# End_service caseid = 217 time =  11847 queue_length = 0
# Customer joins queue caseid = 220 time =  11870 queue_length = 1
# NEXT ARRIVAL TIME:  11890
# Begin_service caseid = 220 time =  11870 queue_length = 1
# End_service caseid = 219 time =  11885 queue_length = 0
# Customer joins queue caseid = 221 time =  11890 queue_length = 1
# NEXT ARRIVAL TIME:  11946
# Begin_service caseid = 221 time =  11890 queue_length = 1
# Customer joins queue caseid = 222 time =  11946 queue_length = 1
# NEXT ARRIVAL TIME:  11969
# End_service caseid = 221 time =  11960 queue_length = 1
# Begin_service caseid = 222 time =  11960 queue_length = 1
# End_service caseid = 218 time =  11963 queue_length = 0
# Customer joins queue caseid = 223 time =  11969 queue_length = 1
# NEXT ARRIVAL TIME:  12041
# Begin_service caseid = 223 time =  11969 queue_length = 1
# End_service caseid = 222 time =  12020 queue_length = 0
# End_service caseid = 223 time =  12029 queue_length = 0
# Customer joins queue caseid = 224 time =  12041 queue_length = 1
# NEXT ARRIVAL TIME:  12074
# Begin_service caseid = 224 time =  12041 queue_length = 1
# Customer joins queue caseid = 225 time =  12074 queue_length = 1
# NEXT ARRIVAL TIME:  12112
# Begin_service caseid = 225 time =  12074 queue_length = 1
# End_service caseid = 224 time =  12101 queue_length = 0
# Customer joins queue caseid = 226 time =  12112 queue_length = 1
# NEXT ARRIVAL TIME:  12160
# Begin_service caseid = 226 time =  12112 queue_length = 1
# End_service caseid = 225 time =  12134 queue_length = 0
# Customer joins queue caseid = 227 time =  12160 queue_length = 1
# NEXT ARRIVAL TIME:  12214
# Begin_service caseid = 227 time =  12160 queue_length = 1
# End_service caseid = 220 time =  12170 queue_length = 0
# End_service caseid = 226 time =  12198 queue_length = 0
# Customer joins queue caseid = 228 time =  12214 queue_length = 1
# NEXT ARRIVAL TIME:  12347
# Begin_service caseid = 228 time =  12214 queue_length = 1
# End_service caseid = 228 time =  12274 queue_length = 0
# Customer joins queue caseid = 229 time =  12347 queue_length = 1
# NEXT ARRIVAL TIME:  12380
# Begin_service caseid = 229 time =  12347 queue_length = 1
# Customer joins queue caseid = 230 time =  12380 queue_length = 1
# NEXT ARRIVAL TIME:  12521
# Begin_service caseid = 230 time =  12380 queue_length = 1
# End_service caseid = 230 time =  12459 queue_length = 0
# End_service caseid = 227 time =  12460 queue_length = 0
# Customer joins queue caseid = 231 time =  12521 queue_length = 1
# NEXT ARRIVAL TIME:  12687
# Begin_service caseid = 231 time =  12521 queue_length = 1
# End_service caseid = 229 time =  12552 queue_length = 0
# End_service caseid = 231 time =  12581 queue_length = 0
# Customer joins queue caseid = 232 time =  12687 queue_length = 1
# NEXT ARRIVAL TIME:  12731
# Begin_service caseid = 232 time =  12687 queue_length = 1
# Customer joins queue caseid = 233 time =  12731 queue_length = 1
# NEXT ARRIVAL TIME:  12758
# Begin_service caseid = 233 time =  12731 queue_length = 1
# Customer joins queue caseid = 234 time =  12758 queue_length = 1
# NEXT ARRIVAL TIME:  12770
# Begin_service caseid = 234 time =  12758 queue_length = 1
# Customer joins queue caseid = 235 time =  12770 queue_length = 1
# NEXT ARRIVAL TIME:  12779
# Customer joins queue caseid = 236 time =  12779 queue_length = 2
# NEXT ARRIVAL TIME:  12831
# End_service caseid = 233 time =  12820 queue_length = 2
# Begin_service caseid = 235 time =  12820 queue_length = 2
# End_service caseid = 234 time =  12821 queue_length = 1
# Begin_service caseid = 236 time =  12821 queue_length = 1
# Customer joins queue caseid = 237 time =  12831 queue_length = 1
# NEXT ARRIVAL TIME:  12859
# Customer joins queue caseid = 238 time =  12859 queue_length = 2
# NEXT ARRIVAL TIME:  12933
# End_service caseid = 236 time =  12881 queue_length = 2
# Begin_service caseid = 237 time =  12881 queue_length = 2
# End_service caseid = 235 time =  12922 queue_length = 1
# Begin_service caseid = 238 time =  12922 queue_length = 1
# End_service caseid = 232 time =  12931 queue_length = 0
# Customer joins queue caseid = 239 time =  12933 queue_length = 1
# NEXT ARRIVAL TIME:  12951
# Begin_service caseid = 239 time =  12933 queue_length = 1
# Customer joins queue caseid = 240 time =  12951 queue_length = 1
# NEXT ARRIVAL TIME:  13038
# End_service caseid = 237 time =  12975 queue_length = 1
# Begin_service caseid = 240 time =  12975 queue_length = 1
# End_service caseid = 238 time =  12985 queue_length = 0
# End_service caseid = 239 time =  12993 queue_length = 0
# ...
# End_service caseid = 535 time =  30746 queue_length = 0
# End_service caseid = 530 time =  30757 queue_length = 0
# Customer joins queue caseid = 536 time =  30786 queue_length = 1
# NEXT ARRIVAL TIME:  30817
# Begin_service caseid = 536 time =  30786 queue_length = 1
# End_service caseid = 534 time =  30787 queue_length = 0
# Customer joins queue caseid = 537 time =  30817 queue_length = 1
# NEXT ARRIVAL TIME:  30915
# Begin_service caseid = 537 time =  30817 queue_length = 1
# End_service caseid = 537 time =  30877 queue_length = 0
# Customer joins queue caseid = 538 time =  30915 queue_length = 1
# NEXT ARRIVAL TIME:  31052
# Begin_service caseid = 538 time =  30915 queue_length = 1
# End_service caseid = 536 time =  30953 queue_length = 0
# End_service caseid = 538 time =  30975 queue_length = 0
# Customer joins queue caseid = 539 time =  31052 queue_length = 1
# NEXT ARRIVAL TIME:  31064
# Begin_service caseid = 539 time =  31052 queue_length = 1
# Customer joins queue caseid = 540 time =  31064 queue_length = 1
# NEXT ARRIVAL TIME:  31071
# Begin_service caseid = 540 time =  31064 queue_length = 1
# Customer joins queue caseid = 541 time =  31071 queue_length = 1
# NEXT ARRIVAL TIME:  31096
# Begin_service caseid = 541 time =  31071 queue_length = 1
# Customer joins queue caseid = 542 time =  31096 queue_length = 1
# NEXT ARRIVAL TIME:  31127
# Customer joins queue caseid = 543 time =  31127 queue_length = 2
# NEXT ARRIVAL TIME:  31249
# End_service caseid = 540 time =  31186 queue_length = 2
# Begin_service caseid = 542 time =  31186 queue_length = 2
# End_service caseid = 542 time =  31246 queue_length = 1
# Begin_service caseid = 543 time =  31246 queue_length = 1
# Customer joins queue caseid = 544 time =  31249 queue_length = 1
# NEXT ARRIVAL TIME:  31348
# End_service caseid = 541 time =  31291 queue_length = 1
# Begin_service caseid = 544 time =  31291 queue_length = 1
# Customer joins queue caseid = 545 time =  31348 queue_length = 1
# NEXT ARRIVAL TIME:  31405
# End_service caseid = 539 time =  31352 queue_length = 1
# Begin_service caseid = 545 time =  31352 queue_length = 1
# End_service caseid = 544 time =  31363 queue_length = 0
# Customer joins queue caseid = 546 time =  31405 queue_length = 1
# NEXT ARRIVAL TIME:  31442
# Begin_service caseid = 546 time =  31405 queue_length = 1
# Customer joins queue caseid = 547 time =  31442 queue_length = 1
# NEXT ARRIVAL TIME:  31463
# Customer joins queue caseid = 548 time =  31463 queue_length = 2
# NEXT ARRIVAL TIME:  31601
# End_service caseid = 545 time =  31519 queue_length = 2
# Begin_service caseid = 547 time =  31519 queue_length = 2
# End_service caseid = 543 time =  31546 queue_length = 1
# Begin_service caseid = 548 time =  31546 queue_length = 1
# Customer joins queue caseid = 549 time =  31601 queue_length = 1
# NEXT ARRIVAL TIME:  31624
# End_service caseid = 547 time =  31605 queue_length = 1
# Begin_service caseid = 549 time =  31605 queue_length = 1
# Customer joins queue caseid = 550 time =  31624 queue_length = 1
# NEXT ARRIVAL TIME:  31639
# Customer joins queue caseid = 551 time =  31639 queue_length = 2
# NEXT ARRIVAL TIME:  31777
# End_service caseid = 548 time =  31640 queue_length = 2
# Begin_service caseid = 550 time =  31640 queue_length = 2
# End_service caseid = 546 time =  31647 queue_length = 1
# Begin_service caseid = 551 time =  31647 queue_length = 1
# End_service caseid = 549 time =  31665 queue_length = 0
# End_service caseid = 551 time =  31707 queue_length = 0
# End_service caseid = 550 time =  31759 queue_length = 0
# Customer joins queue caseid = 552 time =  31777 queue_length = 1
# NEXT ARRIVAL TIME:  31778
# Begin_service caseid = 552 time =  31777 queue_length = 1
# Customer joins queue caseid = 553 time =  31778 queue_length = 1
# NEXT ARRIVAL TIME:  31792
# Begin_service caseid = 553 time =  31778 queue_length = 1
# Customer joins queue caseid = 554 time =  31792 queue_length = 1
# NEXT ARRIVAL TIME:  31825
# Begin_service caseid = 554 time =  31792 queue_length = 1
# Customer joins queue caseid = 555 time =  31825 queue_length = 1
# NEXT ARRIVAL TIME:  31891
# End_service caseid = 552 time =  31837 queue_length = 1
# Begin_service caseid = 555 time =  31837 queue_length = 1
# End_service caseid = 554 time =  31852 queue_length = 0
# Customer joins queue caseid = 556 time =  31891 queue_length = 1
# NEXT ARRIVAL TIME:  31892
# Begin_service caseid = 556 time =  31891 queue_length = 1
# Customer joins queue caseid = 557 time =  31892 queue_length = 1
# NEXT ARRIVAL TIME:  31908
# Customer joins queue caseid = 558 time =  31908 queue_length = 2
# NEXT ARRIVAL TIME:  31922
# Customer joins queue caseid = 559 time =  31922 queue_length = 3
# NEXT ARRIVAL TIME:  32021
# End_service caseid = 556 time =  31980 queue_length = 3
# Begin_service caseid = 557 time =  31980 queue_length = 3
# End_service caseid = 553 time =  31981 queue_length = 2
# Begin_service caseid = 558 time =  31981 queue_length = 2
# Customer joins queue caseid = 560 time =  32021 queue_length = 2
# NEXT ARRIVAL TIME:  32181
# End_service caseid = 555 time =  32026 queue_length = 2
# Begin_service caseid = 559 time =  32026 queue_length = 2
# End_service caseid = 559 time =  32128 queue_length = 1
# Begin_service caseid = 560 time =  32128 queue_length = 1
# End_service caseid = 557 time =  32139 queue_length = 0
# Customer joins queue caseid = 561 time =  32181 queue_length = 1
# NEXT ARRIVAL TIME:  32209
# Begin_service caseid = 561 time =  32181 queue_length = 1
# End_service caseid = 560 time =  32188 queue_length = 0
# End_service caseid = 558 time =  32195 queue_length = 0
# Customer joins queue caseid = 562 time =  32209 queue_length = 1
# NEXT ARRIVAL TIME:  32294
# Begin_service caseid = 562 time =  32209 queue_length = 1
# End_service caseid = 562 time =  32269 queue_length = 0
# End_service caseid = 561 time =  32271 queue_length = 0
# Customer joins queue caseid = 563 time =  32294 queue_length = 1
# NEXT ARRIVAL TIME:  32295
# Begin_service caseid = 563 time =  32294 queue_length = 1
# Customer joins queue caseid = 564 time =  32295 queue_length = 1
# NEXT ARRIVAL TIME:  32465
# Begin_service caseid = 564 time =  32295 queue_length = 1
# End_service caseid = 563 time =  32354 queue_length = 0
# End_service caseid = 564 time =  32438 queue_length = 0
# Customer joins queue caseid = 565 time =  32465 queue_length = 1
# NEXT ARRIVAL TIME:  32514
# Begin_service caseid = 565 time =  32465 queue_length = 1
# Customer joins queue caseid = 566 time =  32514 queue_length = 1
# NEXT ARRIVAL TIME:  32527
# Begin_service caseid = 566 time =  32514 queue_length = 1
# End_service caseid = 565 time =  32525 queue_length = 0
# Customer joins queue caseid = 567 time =  32527 queue_length = 1
# NEXT ARRIVAL TIME:  32623
# Begin_service caseid = 567 time =  32527 queue_length = 1
# End_service caseid = 567 time =  32620 queue_length = 0
# Customer joins queue caseid = 568 time =  32623 queue_length = 1
# NEXT ARRIVAL TIME:  32651
# Begin_service caseid = 568 time =  32623 queue_length = 1
# Customer joins queue caseid = 569 time =  32651 queue_length = 1
# NEXT ARRIVAL TIME:  32750
# Begin_service caseid = 569 time =  32651 queue_length = 1
# End_service caseid = 569 time =  32737 queue_length = 0
# Customer joins queue caseid = 570 time =  32750 queue_length = 1
# NEXT ARRIVAL TIME:  32814
# Begin_service caseid = 570 time =  32750 queue_length = 1
# End_service caseid = 566 time =  32814 queue_length = 0
# Customer joins queue caseid = 571 time =  32814 queue_length = 1
# NEXT ARRIVAL TIME:  32816
# Begin_service caseid = 571 time =  32814 queue_length = 1
# Customer joins queue caseid = 572 time =  32816 queue_length = 1
# NEXT ARRIVAL TIME:  32858
# Customer joins queue caseid = 573 time =  32858 queue_length = 2
# NEXT ARRIVAL TIME:  33032
# End_service caseid = 570 time =  32870 queue_length = 2
# Begin_service caseid = 572 time =  32870 queue_length = 2
# End_service caseid = 571 time =  32874 queue_length = 1
# Begin_service caseid = 573 time =  32874 queue_length = 1
# End_service caseid = 568 time =  32923 queue_length = 0
# End_service caseid = 573 time =  32934 queue_length = 0
# End_service caseid = 572 time =  32942 queue_length = 0
# Customer joins queue caseid = 574 time =  33032 queue_length = 1
# NEXT ARRIVAL TIME:  33469
# Begin_service caseid = 574 time =  33032 queue_length = 1
# End_service caseid = 574 time =  33174 queue_length = 0
# Customer joins queue caseid = 575 time =  33469 queue_length = 1
# NEXT ARRIVAL TIME:  33549
# Begin_service caseid = 575 time =  33469 queue_length = 1
# End_service caseid = 575 time =  33529 queue_length = 0
# Customer joins queue caseid = 576 time =  33549 queue_length = 1
# NEXT ARRIVAL TIME:  33640
# Begin_service caseid = 576 time =  33549 queue_length = 1
# Customer joins queue caseid = 577 time =  33640 queue_length = 1
# NEXT ARRIVAL TIME:  33881
# Begin_service caseid = 577 time =  33640 queue_length = 1
# End_service caseid = 576 time =  33849 queue_length = 0
# Customer joins queue caseid = 578 time =  33881 queue_length = 1
# NEXT ARRIVAL TIME:  33970
# Begin_service caseid = 578 time =  33881 queue_length = 1
# End_service caseid = 577 time =  33940 queue_length = 0
# Customer joins queue caseid = 579 time =  33970 queue_length = 1
# NEXT ARRIVAL TIME:  34074
# Begin_service caseid = 579 time =  33970 queue_length = 1
# End_service caseid = 579 time =  34030 queue_length = 0
# End_service caseid = 578 time =  34072 queue_length = 0
# Customer joins queue caseid = 580 time =  34074 queue_length = 1
# NEXT ARRIVAL TIME:  34123
# Begin_service caseid = 580 time =  34074 queue_length = 1
# Customer joins queue caseid = 581 time =  34123 queue_length = 1
# NEXT ARRIVAL TIME:  34138
# Begin_service caseid = 581 time =  34123 queue_length = 1
# Customer joins queue caseid = 582 time =  34138 queue_length = 1
# NEXT ARRIVAL TIME:  34177
# Begin_service caseid = 582 time =  34138 queue_length = 1
# End_service caseid = 580 time =  34149 queue_length = 0
# Customer joins queue caseid = 583 time =  34177 queue_length = 1
# NEXT ARRIVAL TIME:  34194
# Begin_service caseid = 583 time =  34177 queue_length = 1
# Customer joins queue caseid = 584 time =  34194 queue_length = 1
# NEXT ARRIVAL TIME:  34218
# End_service caseid = 582 time =  34198 queue_length = 1
# Begin_service caseid = 584 time =  34198 queue_length = 1
# Customer joins queue caseid = 585 time =  34218 queue_length = 1
# NEXT ARRIVAL TIME:  34335
# End_service caseid = 583 time =  34237 queue_length = 1
# Begin_service caseid = 585 time =  34237 queue_length = 1
# End_service caseid = 584 time =  34258 queue_length = 0
# Customer joins queue caseid = 586 time =  34335 queue_length = 1
# NEXT ARRIVAL TIME:  34370
# Begin_service caseid = 586 time =  34335 queue_length = 1
# End_service caseid = 585 time =  34340 queue_length = 0
# Customer joins queue caseid = 587 time =  34370 queue_length = 1
# NEXT ARRIVAL TIME:  34428
# Begin_service caseid = 587 time =  34370 queue_length = 1
# End_service caseid = 586 time =  34395 queue_length = 0
# End_service caseid = 581 time =  34423 queue_length = 0
# Customer joins queue caseid = 588 time =  34428 queue_length = 1
# NEXT ARRIVAL TIME:  34476
# Begin_service caseid = 588 time =  34428 queue_length = 1
# End_service caseid = 587 time =  34430 queue_length = 0
# Customer joins queue caseid = 589 time =  34476 queue_length = 1
# NEXT ARRIVAL TIME:  34485
# Begin_service caseid = 589 time =  34476 queue_length = 1
# Customer joins queue caseid = 590 time =  34485 queue_length = 1
# NEXT ARRIVAL TIME:  34556
# Begin_service caseid = 590 time =  34485 queue_length = 1
# End_service caseid = 588 time =  34533 queue_length = 0
# End_service caseid = 589 time =  34536 queue_length = 0
# End_service caseid = 590 time =  34552 queue_length = 0
# Customer joins queue caseid = 591 time =  34556 queue_length = 1
# NEXT ARRIVAL TIME:  34605
# Begin_service caseid = 591 time =  34556 queue_length = 1
# Customer joins queue caseid = 592 time =  34605 queue_length = 1
# NEXT ARRIVAL TIME:  34658
# Begin_service caseid = 592 time =  34605 queue_length = 1
# End_service caseid = 591 time =  34639 queue_length = 0
# Customer joins queue caseid = 593 time =  34658 queue_length = 1
# NEXT ARRIVAL TIME:  34659
# Begin_service caseid = 593 time =  34658 queue_length = 1
# Customer joins queue caseid = 594 time =  34659 queue_length = 1
# NEXT ARRIVAL TIME:  34684
# Begin_service caseid = 594 time =  34659 queue_length = 1
# End_service caseid = 592 time =  34665 queue_length = 0
# Customer joins queue caseid = 595 time =  34684 queue_length = 1
# NEXT ARRIVAL TIME:  34693
# Begin_service caseid = 595 time =  34684 queue_length = 1
# Customer joins queue caseid = 596 time =  34693 queue_length = 1
# NEXT ARRIVAL TIME:  34714
# Customer joins queue caseid = 597 time =  34714 queue_length = 2
# NEXT ARRIVAL TIME:  34793
# End_service caseid = 593 time =  34724 queue_length = 2
# Begin_service caseid = 596 time =  34724 queue_length = 2
# End_service caseid = 594 time =  34729 queue_length = 1
# Begin_service caseid = 597 time =  34729 queue_length = 1
# End_service caseid = 595 time =  34767 queue_length = 0
# End_service caseid = 596 time =  34784 queue_length = 0
# End_service caseid = 597 time =  34789 queue_length = 0
# Customer joins queue caseid = 598 time =  34793 queue_length = 1
# NEXT ARRIVAL TIME:  34835
# Begin_service caseid = 598 time =  34793 queue_length = 1
# Customer joins queue caseid = 599 time =  34835 queue_length = 1
# NEXT ARRIVAL TIME:  34896
# Begin_service caseid = 599 time =  34835 queue_length = 1
# Customer joins queue caseid = 600 time =  34896 queue_length = 1
# NEXT ARRIVAL TIME:  34931
# Begin_service caseid = 600 time =  34896 queue_length = 1
# Customer joins queue caseid = 601 time =  34931 queue_length = 1
# NEXT ARRIVAL TIME:  35008
# End_service caseid = 600 time =  34956 queue_length = 1
# Begin_service caseid = 601 time =  34956 queue_length = 1
# End_service caseid = 598 time =  34980 queue_length = 0
# Customer joins queue caseid = 602 time =  35008 queue_length = 1
# NEXT ARRIVAL TIME:  35043
# Begin_service caseid = 602 time =  35008 queue_length = 1
# Customer joins queue caseid = 603 time =  35043 queue_length = 1
# NEXT ARRIVAL TIME:  35175
# End_service caseid = 599 time =  35057 queue_length = 1
# Begin_service caseid = 603 time =  35057 queue_length = 1
# End_service caseid = 602 time =  35068 queue_length = 0
# End_service caseid = 601 time =  35092 queue_length = 0
# End_service caseid = 603 time =  35122 queue_length = 0
# Customer joins queue caseid = 604 time =  35175 queue_length = 1
# NEXT ARRIVAL TIME:  35235
# Begin_service caseid = 604 time =  35175 queue_length = 1
# End_service caseid = 604 time =  35235 queue_length = 0
# Customer joins queue caseid = 605 time =  35235 queue_length = 1
# NEXT ARRIVAL TIME:  35548
# Begin_service caseid = 605 time =  35235 queue_length = 1
# End_service caseid = 605 time =  35443 queue_length = 0
# Customer joins queue caseid = 606 time =  35548 queue_length = 1
# NEXT ARRIVAL TIME:  35593
# Begin_service caseid = 606 time =  35548 queue_length = 1
# Customer joins queue caseid = 607 time =  35593 queue_length = 1
# NEXT ARRIVAL TIME:  35650
# Begin_service caseid = 607 time =  35593 queue_length = 1
# End_service caseid = 606 time =  35608 queue_length = 0
# Customer joins queue caseid = 608 time =  35650 queue_length = 1
# NEXT ARRIVAL TIME:  35684
# Begin_service caseid = 608 time =  35650 queue_length = 1
# End_service caseid = 607 time =  35653 queue_length = 0
# Customer joins queue caseid = 609 time =  35684 queue_length = 1
# NEXT ARRIVAL TIME:  35735
# Begin_service caseid = 609 time =  35684 queue_length = 1
# Customer joins queue caseid = 610 time =  35735 queue_length = 1
# NEXT ARRIVAL TIME:  35801
# Begin_service caseid = 610 time =  35735 queue_length = 1
# End_service caseid = 609 time =  35744 queue_length = 0
# Customer joins queue caseid = 611 time =  35801 queue_length = 1
# NEXT ARRIVAL TIME:  35955
# Begin_service caseid = 611 time =  35801 queue_length = 1
# End_service caseid = 611 time =  35861 queue_length = 0
# End_service caseid = 608 time =  35950 queue_length = 0
# Customer joins queue caseid = 612 time =  35955 queue_length = 1
# NEXT ARRIVAL TIME:  35970
# Begin_service caseid = 612 time =  35955 queue_length = 1
# Customer joins queue caseid = 613 time =  35970 queue_length = 1
# NEXT ARRIVAL TIME:  36034
# Begin_service caseid = 613 time =  35970 queue_length = 1
