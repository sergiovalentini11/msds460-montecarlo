# %% [markdown]
# ## libraries used in this assignemnt

# %%
# initialize queue length
# queue_length = 0

import numpy as np # for random number distributions
import pandas as pd # for event_log data frame
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 10)
import queue # add FIFO queue data structure
from functools import partial, wraps
import os

import simpy # discrete event simulation environment

# %% [markdown]
# ## Functions and methods

# %% [markdown]
# ### Modified Arrival - To represent people leaving the queue based on the patience measurement

# %%
def arrival(env,available_baristas, caseid_queue, event_log):
    # generates new customers... arrivals
    caseid = 0
    while True:  # infinite loop for generating arrivals
        # get the service process started
        # must have waiting customers to begin service
    
        # schedule the time of next customer arrival       
        # by waiting until the next arrival time from now
        # when the process yields an event, the process gets suspended
        inter_arrival_time = round(60*np.random.exponential(scale = mean_inter_arrival_time))
        print("NEXT ARRIVAL TIME: ", env.now + inter_arrival_time)

        yield env.timeout(inter_arrival_time)  # generator function waits
        # env.timeout does not advance the clock. when an event/process calls env.timeout, 
        # that process waits until the clock gets to that time, it does not block 
        # other agents from doing stuff. Other processes can still do stuff 
        # while the first process is waiting for env.timeout to finish.
        caseid += 1
        time = env.now
        activity = 'arrival'
        env.process(event_log_append(env, caseid, time, activity, event_log)) 
        yield env.timeout(0) 
        if caseid_queue.qsize() < balking_queue_length:
            caseid_queue.put(caseid)          
            print("Customer joins queue caseid =",caseid,'time = ',env.now,'queue_length =',caseid_queue.qsize())
            time = env.now
            activity = 'join_queue'
            env.process(event_log_append(env, caseid, time, activity, event_log)) 
            env.process(service_process(env,available_baristas, caseid_queue, event_log))       
        else:
            print("Customer balks caseid =",caseid,'time = ',env.now,'queue_length =',caseid_queue.qsize()) 
            env.process(event_log_append(env, caseid, env.now, 'balk', event_log))

# %% [markdown]
# ### Serivce process

# %%
# user-defined function for random service time (modified exponential)
# returns real number of minutes
def random_service_time(minimum_service_time,mean_service_time,maximum_service_time) :
    try_service_time = np.random.exponential(scale = mean_service_time)
    if (try_service_time < minimum_service_time):
        return(minimum_service_time)
    if (try_service_time > maximum_service_time):
        return(maximum_service_time)
    if (try_service_time >= minimum_service_time) and (try_service_time <= maximum_service_time):
        return(try_service_time)
    


def service_process(env,available_baristas, caseid_queue, event_log):
    # must have baristas to provide service... freeze until request can be met
    with available_baristas.request() as req:
        yield req  # wait until the request can be met.. there must be an available barista
        queue_length_on_entering_service = caseid_queue.qsize()
        caseid = caseid_queue.get()
        print("Begin_service caseid =",caseid,'time = ',env.now,'queue_length =',queue_length_on_entering_service)
        env.process(event_log_append(env, caseid, env.now, 'begin_service', event_log)) 
        # schedule end_service event based on service_time
        service_time = round(60*random_service_time(minimum_service_time,mean_service_time,maximum_service_time))   
        yield env.timeout(service_time)  # sets begin_service as generator function
        queue_length_on_leaving_service = caseid_queue.qsize()
        print("End_service caseid =",caseid,'time = ',env.now,'queue_length =',queue_length_on_leaving_service)
        env.process(event_log_append(env, caseid, env.now, 'end_service', event_log))

# %% [markdown]
# ### Tracing of the simulation

# %%
'''        
---------------------------------------------------------
set up event tracing of all simulation program events 
controlled by the simulation environment
that is, all timeout and process events that begin with "env."
documentation at:
  https://simpy.readthedocs.io/en/latest/topical_guides/monitoring.html#event-tracing
  https://docs.python.org/3/library/functools.html#functools.partial
'''
def trace(env, callback):
     """Replace the ``step()`` method of *env* with a tracing function
     that calls *callbacks* with an events time, priority, ID and its
     instance just before it is processed.
     note: "event" here refers to simulaiton program events

     """
     def get_wrapper(env_step, callback):
         """Generate the wrapper for env.step()."""
         @wraps(env_step)
         def tracing_step():
             """Call *callback* for the next event if one exist before
             calling ``env.step()``."""
             if len(env._queue):
                 t, prio, eid, event = env._queue[0]
                 callback(t, prio, eid, event)
             return env_step()
         return tracing_step

     env.step = get_wrapper(env.step, callback)

def trace_monitor(data, t, prio, eid, event):
     data.append((t, eid, type(event)))

def test_process(env):
     yield env.timeout(1)

'''
---------------------------------------------------------
set up an event log for recording events
as defined for the discrete event simulation
we use a list of tuples for the event log
documentation at:
  https://simpy.readthedocs.io/en/latest/topical_guides/monitoring.html#event-tracing
'''     
def event_log_append(env, caseid, time, activity, event_log):
    event_log.append((caseid, time, activity))
    yield env.timeout(0)

# %% [markdown]
# ### Parameters to be changed for each simulation

# %%
# let the simulation time unit be one second, but set parameters in minutes
# set global variables that do not change throughout the course of the simulation

# global variables that do not change throughout the course of the simulation

global simulation_hours, baristas, minimum_service_time, mean_service_time,\
        maximum_service_time, mean_inter_arrival_time, balking_queue_length,\
            obtain_reproducible_results

baristas = 3  # number of barista server resources... vary from 1 to 3

minimum_service_time = 1 # minutes (60 seconds)
mean_service_time = 2 # minutes (120 seconds)
maximum_service_time = 5 # minutes (300 seconds)

mean_inter_arrival_time = 1 # vary from 1 to 10 minutes (60 to 600 seconds)

balking_queue_length = 10  # longest queue length that customers will tolerate

# this binary toggle allows you to fix the random number seed
# so that every run of the program with specific parameter settings
# will yield the same results... setting to false will allow the
# program to obtain different results with each run
obtain_reproducible_results = True

# set length of simulation in simulation time units (assume seconds)
# run for similation_hours of simulation time
simulation_hours = 10
fixed_simulation_time =  simulation_hours*60*60   

parameter_string_list = [str(simulation_hours),'hours',
              str(baristas),str(minimum_service_time),
              str(mean_service_time),str(maximum_service_time),
              str(mean_inter_arrival_time),str(balking_queue_length)]
separator = '-'        
simulation_file_identifier = separator.join(parameter_string_list)

# initialize queue length
# queue_length = 0

# %% [markdown]
# ### Simulation

# %%
'''
---------------------------------------
set up the SimPy simulation environment
and run the simulation with monitoring
---------------------------------------
'''
if obtain_reproducible_results: 
    np.random.seed(9999)


# set up simulation trace monitoring for the simulation
data = []
# bind *data* as first argument to monitor()
this_trace_monitor = partial(trace_monitor, data)

env = simpy.Environment()
trace(env, this_trace_monitor)

env.process(test_process(env))

# implement FIFO queue to hold caseid values
caseid_queue = queue.Queue()

# set up limited server/baristas resource
available_baristas = simpy.Resource(env, capacity = baristas)
caseid = -1  # dummy caseid for beginning of simulation
# dummy caseid values will be omitted from the event_log
# prior to analyzing simulation results

# beginning record in event_log list of tuples of the form
# form of the event_log tuple item: (caseid, time, activity)
event_log = [(caseid,0,'null_start_simulation')]
# event_monitor = partial(event_monitor, event_log)
env.process(event_log_append(env, caseid, env.now, 'start_simulation', event_log))
 
# call customer arrival process/generator to begin the simulation
env.process(arrival(env,available_baristas, caseid_queue, event_log))  

env.run(until = fixed_simulation_time)  # start simulation with monitoring and fixed end-time
# Out:
# NEXT ARRIVAL TIME:  104
# Customer joins queue caseid = 1 time =  104 queue_length = 1
# NEXT ARRIVAL TIME:  119
# Begin_service caseid = 1 time =  104 queue_length = 1
# Customer joins queue caseid = 2 time =  119 queue_length = 1
# NEXT ARRIVAL TIME:  166
# Begin_service caseid = 2 time =  119 queue_length = 1
# End_service caseid = 1 time =  164 queue_length = 0
# Customer joins queue caseid = 3 time =  166 queue_length = 1
# NEXT ARRIVAL TIME:  178
# Begin_service caseid = 3 time =  166 queue_length = 1
# Customer joins queue caseid = 4 time =  178 queue_length = 1
# NEXT ARRIVAL TIME:  234
# Begin_service caseid = 4 time =  178 queue_length = 1
# End_service caseid = 2 time =  179 queue_length = 0
# End_service caseid = 3 time =  232 queue_length = 0
# Customer joins queue caseid = 5 time =  234 queue_length = 1
# NEXT ARRIVAL TIME:  296
# Begin_service caseid = 5 time =  234 queue_length = 1
# End_service caseid = 4 time =  259 queue_length = 0
# Customer joins queue caseid = 6 time =  296 queue_length = 1
# NEXT ARRIVAL TIME:  384
# Begin_service caseid = 6 time =  296 queue_length = 1
# End_service caseid = 6 time =  356 queue_length = 0
# Customer joins queue caseid = 7 time =  384 queue_length = 1
# NEXT ARRIVAL TIME:  416
# Begin_service caseid = 7 time =  384 queue_length = 1
# Customer joins queue caseid = 8 time =  416 queue_length = 1
# NEXT ARRIVAL TIME:  443
# Begin_service caseid = 8 time =  416 queue_length = 1
# Customer joins queue caseid = 9 time =  443 queue_length = 1
# NEXT ARRIVAL TIME:  495
# End_service caseid = 7 time =  444 queue_length = 1
# Begin_service caseid = 9 time =  444 queue_length = 1
# End_service caseid = 8 time =  476 queue_length = 0
# Customer joins queue caseid = 10 time =  495 queue_length = 1
# NEXT ARRIVAL TIME:  519
# Begin_service caseid = 10 time =  495 queue_length = 1
# End_service caseid = 9 time =  504 queue_length = 0
# Customer joins queue caseid = 11 time =  519 queue_length = 1
# NEXT ARRIVAL TIME:  530
# Begin_service caseid = 11 time =  519 queue_length = 1
# End_service caseid = 5 time =  527 queue_length = 0
# Customer joins queue caseid = 12 time =  530 queue_length = 1
# NEXT ARRIVAL TIME:  578
# Begin_service caseid = 12 time =  530 queue_length = 1
# Customer joins queue caseid = 13 time =  578 queue_length = 1
# NEXT ARRIVAL TIME:  612
# End_service caseid = 11 time =  598 queue_length = 1
# Begin_service caseid = 13 time =  598 queue_length = 1
# Customer joins queue caseid = 14 time =  612 queue_length = 1
# NEXT ARRIVAL TIME:  733
# End_service caseid = 12 time =  641 queue_length = 1
# Begin_service caseid = 14 time =  641 queue_length = 1
# End_service caseid = 13 time =  675 queue_length = 0
# End_service caseid = 10 time =  725 queue_length = 0
# Customer joins queue caseid = 15 time =  733 queue_length = 1
# NEXT ARRIVAL TIME:  773
# Begin_service caseid = 15 time =  733 queue_length = 1
# End_service caseid = 14 time =  734 queue_length = 0
# Customer joins queue caseid = 16 time =  773 queue_length = 1
# NEXT ARRIVAL TIME:  825
# Begin_service caseid = 16 time =  773 queue_length = 1
# End_service caseid = 15 time =  793 queue_length = 0
# Customer joins queue caseid = 17 time =  825 queue_length = 1
# NEXT ARRIVAL TIME:  872
# Begin_service caseid = 17 time =  825 queue_length = 1
# Customer joins queue caseid = 18 time =  872 queue_length = 1
# NEXT ARRIVAL TIME:  963
# Begin_service caseid = 18 time =  872 queue_length = 1
# End_service caseid = 16 time =  909 queue_length = 0
# Customer joins queue caseid = 19 time =  963 queue_length = 1
# NEXT ARRIVAL TIME:  969
# Begin_service caseid = 19 time =  963 queue_length = 1
# Customer joins queue caseid = 20 time =  969 queue_length = 1
# NEXT ARRIVAL TIME:  984
# Customer joins queue caseid = 21 time =  984 queue_length = 2
# NEXT ARRIVAL TIME:  988
# Customer joins queue caseid = 22 time =  988 queue_length = 3
# NEXT ARRIVAL TIME:  992
# Customer joins queue caseid = 23 time =  992 queue_length = 4
# NEXT ARRIVAL TIME:  1032
# End_service caseid = 18 time =  1021 queue_length = 4
# Begin_service caseid = 20 time =  1021 queue_length = 4
# Customer joins queue caseid = 24 time =  1032 queue_length = 4
# NEXT ARRIVAL TIME:  1093
# End_service caseid = 20 time =  1081 queue_length = 4
# Begin_service caseid = 21 time =  1081 queue_length = 4
# Customer joins queue caseid = 25 time =  1093 queue_length = 4
# NEXT ARRIVAL TIME:  1181
# End_service caseid = 17 time =  1118 queue_length = 4
# Begin_service caseid = 22 time =  1118 queue_length = 4
# End_service caseid = 22 time =  1178 queue_length = 3
# Begin_service caseid = 23 time =  1178 queue_length = 3
# Customer joins queue caseid = 26 time =  1181 queue_length = 3
# NEXT ARRIVAL TIME:  1322
# End_service caseid = 21 time =  1208 queue_length = 3
# Begin_service caseid = 24 time =  1208 queue_length = 3
# End_service caseid = 23 time =  1238 queue_length = 2
# Begin_service caseid = 25 time =  1238 queue_length = 2
# End_service caseid = 19 time =  1263 queue_length = 1
# Begin_service caseid = 26 time =  1263 queue_length = 1
# End_service caseid = 24 time =  1268 queue_length = 0
# Customer joins queue caseid = 27 time =  1322 queue_length = 1
# NEXT ARRIVAL TIME:  1426
# Begin_service caseid = 27 time =  1322 queue_length = 1
# End_service caseid = 25 time =  1342 queue_length = 0
# End_service caseid = 26 time =  1345 queue_length = 0
# End_service caseid = 27 time =  1406 queue_length = 0
# Customer joins queue caseid = 28 time =  1426 queue_length = 1
# NEXT ARRIVAL TIME:  1493
# Begin_service caseid = 28 time =  1426 queue_length = 1
# Customer joins queue caseid = 29 time =  1493 queue_length = 1
# NEXT ARRIVAL TIME:  1496
# Begin_service caseid = 29 time =  1493 queue_length = 1
# Customer joins queue caseid = 30 time =  1496 queue_length = 1
# NEXT ARRIVAL TIME:  1723
# Begin_service caseid = 30 time =  1496 queue_length = 1
# End_service caseid = 28 time =  1497 queue_length = 0
# End_service caseid = 30 time =  1556 queue_length = 0
# End_service caseid = 29 time =  1678 queue_length = 0
# Customer joins queue caseid = 31 time =  1723 queue_length = 1
# NEXT ARRIVAL TIME:  1725
# Begin_service caseid = 31 time =  1723 queue_length = 1
# Customer joins queue caseid = 32 time =  1725 queue_length = 1
# NEXT ARRIVAL TIME:  1727
# Begin_service caseid = 32 time =  1725 queue_length = 1
# Customer joins queue caseid = 33 time =  1727 queue_length = 1
# NEXT ARRIVAL TIME:  1879
# Begin_service caseid = 33 time =  1727 queue_length = 1
# End_service caseid = 31 time =  1837 queue_length = 0
# Customer joins queue caseid = 34 time =  1879 queue_length = 1
# NEXT ARRIVAL TIME:  1928
# Begin_service caseid = 34 time =  1879 queue_length = 1
# Customer joins queue caseid = 35 time =  1928 queue_length = 1
# NEXT ARRIVAL TIME:  1988
# End_service caseid = 33 time =  1930 queue_length = 1
# Begin_service caseid = 35 time =  1930 queue_length = 1
# End_service caseid = 34 time =  1939 queue_length = 0
# End_service caseid = 32 time =  1979 queue_length = 0
# Customer joins queue caseid = 36 time =  1988 queue_length = 1
# NEXT ARRIVAL TIME:  2005
# Begin_service caseid = 36 time =  1988 queue_length = 1
# End_service caseid = 35 time =  1990 queue_length = 0
# Customer joins queue caseid = 37 time =  2005 queue_length = 1
# NEXT ARRIVAL TIME:  2007
# Begin_service caseid = 37 time =  2005 queue_length = 1
# Customer joins queue caseid = 38 time =  2007 queue_length = 1
# NEXT ARRIVAL TIME:  2055
# Begin_service caseid = 38 time =  2007 queue_length = 1
# End_service caseid = 36 time =  2048 queue_length = 0
# Customer joins queue caseid = 39 time =  2055 queue_length = 1
# NEXT ARRIVAL TIME:  2075
# Begin_service caseid = 39 time =  2055 queue_length = 1
# End_service caseid = 38 time =  2067 queue_length = 0
# Customer joins queue caseid = 40 time =  2075 queue_length = 1
# NEXT ARRIVAL TIME:  2101
# Begin_service caseid = 40 time =  2075 queue_length = 1
# Customer joins queue caseid = 41 time =  2101 queue_length = 1
# NEXT ARRIVAL TIME:  2139
# End_service caseid = 37 time =  2103 queue_length = 1
# Begin_service caseid = 41 time =  2103 queue_length = 1
# End_service caseid = 39 time =  2115 queue_length = 0
# End_service caseid = 40 time =  2135 queue_length = 0
# Customer joins queue caseid = 42 time =  2139 queue_length = 1
# NEXT ARRIVAL TIME:  2166
# Begin_service caseid = 42 time =  2139 queue_length = 1
# Customer joins queue caseid = 43 time =  2166 queue_length = 1
# NEXT ARRIVAL TIME:  2193
# Begin_service caseid = 43 time =  2166 queue_length = 1
# Customer joins queue caseid = 44 time =  2193 queue_length = 1
# NEXT ARRIVAL TIME:  2338
# End_service caseid = 42 time =  2199 queue_length = 1
# Begin_service caseid = 44 time =  2199 queue_length = 1
# End_service caseid = 41 time =  2212 queue_length = 0
# End_service caseid = 43 time =  2226 queue_length = 0
# End_service caseid = 44 time =  2259 queue_length = 0
# Customer joins queue caseid = 45 time =  2338 queue_length = 1
# NEXT ARRIVAL TIME:  2375
# Begin_service caseid = 45 time =  2338 queue_length = 1
# Customer joins queue caseid = 46 time =  2375 queue_length = 1
# NEXT ARRIVAL TIME:  2389
# Begin_service caseid = 46 time =  2375 queue_length = 1
# Customer joins queue caseid = 47 time =  2389 queue_length = 1
# NEXT ARRIVAL TIME:  2426
# Begin_service caseid = 47 time =  2389 queue_length = 1
# End_service caseid = 45 time =  2413 queue_length = 0
# Customer joins queue caseid = 48 time =  2426 queue_length = 1
# NEXT ARRIVAL TIME:  2529
# Begin_service caseid = 48 time =  2426 queue_length = 1
# End_service caseid = 46 time =  2441 queue_length = 0
# End_service caseid = 47 time =  2475 queue_length = 0
# Customer joins queue caseid = 49 time =  2529 queue_length = 1
# NEXT ARRIVAL TIME:  2609
# Begin_service caseid = 49 time =  2529 queue_length = 1
# End_service caseid = 49 time =  2598 queue_length = 0
# Customer joins queue caseid = 50 time =  2609 queue_length = 1
# NEXT ARRIVAL TIME:  2632
# Begin_service caseid = 50 time =  2609 queue_length = 1
# Customer joins queue caseid = 51 time =  2632 queue_length = 1
# NEXT ARRIVAL TIME:  2634
# Begin_service caseid = 51 time =  2632 queue_length = 1
# Customer joins queue caseid = 52 time =  2634 queue_length = 1
# NEXT ARRIVAL TIME:  2649
# End_service caseid = 48 time =  2646 queue_length = 1
# Begin_service caseid = 52 time =  2646 queue_length = 1
# Customer joins queue caseid = 53 time =  2649 queue_length = 1
# NEXT ARRIVAL TIME:  2741
# End_service caseid = 50 time =  2669 queue_length = 1
# Begin_service caseid = 53 time =  2669 queue_length = 1
# End_service caseid = 52 time =  2706 queue_length = 0
# End_service caseid = 51 time =  2707 queue_length = 0
# Customer joins queue caseid = 54 time =  2741 queue_length = 1
# NEXT ARRIVAL TIME:  2741
# Begin_service caseid = 54 time =  2741 queue_length = 1
# Customer joins queue caseid = 55 time =  2741 queue_length = 1
# NEXT ARRIVAL TIME:  2746
# Begin_service caseid = 55 time =  2741 queue_length = 1
# Customer joins queue caseid = 56 time =  2746 queue_length = 1
# NEXT ARRIVAL TIME:  2818
# End_service caseid = 53 time =  2752 queue_length = 1
# Begin_service caseid = 56 time =  2752 queue_length = 1
# End_service caseid = 54 time =  2807 queue_length = 0
# End_service caseid = 56 time =  2812 queue_length = 0
# Customer joins queue caseid = 57 time =  2818 queue_length = 1
# NEXT ARRIVAL TIME:  2863
# Begin_service caseid = 57 time =  2818 queue_length = 1
# End_service caseid = 55 time =  2835 queue_length = 0
# Customer joins queue caseid = 58 time =  2863 queue_length = 1
# NEXT ARRIVAL TIME:  3011
# Begin_service caseid = 58 time =  2863 queue_length = 1
# End_service caseid = 57 time =  2878 queue_length = 0
# Customer joins queue caseid = 59 time =  3011 queue_length = 1
# NEXT ARRIVAL TIME:  3065
# Begin_service caseid = 59 time =  3011 queue_length = 1
# Customer joins queue caseid = 60 time =  3065 queue_length = 1
# NEXT ARRIVAL TIME:  3092
# Begin_service caseid = 60 time =  3065 queue_length = 1
# Customer joins queue caseid = 61 time =  3092 queue_length = 1
# NEXT ARRIVAL TIME:  3094
# Customer joins queue caseid = 62 time =  3094 queue_length = 2
# NEXT ARRIVAL TIME:  3104
# Customer joins queue caseid = 63 time =  3104 queue_length = 3
# NEXT ARRIVAL TIME:  3113
# Customer joins queue caseid = 64 time =  3113 queue_length = 4
# NEXT ARRIVAL TIME:  3239
# End_service caseid = 59 time =  3124 queue_length = 4
# Begin_service caseid = 61 time =  3124 queue_length = 4
# End_service caseid = 58 time =  3126 queue_length = 3
# Begin_service caseid = 62 time =  3126 queue_length = 3
# End_service caseid = 60 time =  3186 queue_length = 2
# Begin_service caseid = 63 time =  3186 queue_length = 2
# Customer joins queue caseid = 65 time =  3239 queue_length = 2
# NEXT ARRIVAL TIME:  3271
# End_service caseid = 63 time =  3246 queue_length = 2
# Begin_service caseid = 64 time =  3246 queue_length = 2
# Customer joins queue caseid = 66 time =  3271 queue_length = 2
# NEXT ARRIVAL TIME:  3288
# End_service caseid = 61 time =  3272 queue_length = 2
# Begin_service caseid = 65 time =  3272 queue_length = 2
# Customer joins queue caseid = 67 time =  3288 queue_length = 2
# NEXT ARRIVAL TIME:  3348
# End_service caseid = 64 time =  3306 queue_length = 2
# Begin_service caseid = 66 time =  3306 queue_length = 2
# End_service caseid = 62 time =  3308 queue_length = 1
# Begin_service caseid = 67 time =  3308 queue_length = 1
# End_service caseid = 65 time =  3333 queue_length = 0
# Customer joins queue caseid = 68 time =  3348 queue_length = 1
# NEXT ARRIVAL TIME:  3390
# Begin_service caseid = 68 time =  3348 queue_length = 1
# End_service caseid = 66 time =  3375 queue_length = 0
# Customer joins queue caseid = 69 time =  3390 queue_length = 1
# NEXT ARRIVAL TIME:  3428
# Begin_service caseid = 69 time =  3390 queue_length = 1
# End_service caseid = 67 time =  3427 queue_length = 0
# Customer joins queue caseid = 70 time =  3428 queue_length = 1
# NEXT ARRIVAL TIME:  3448
# Begin_service caseid = 70 time =  3428 queue_length = 1
# End_service caseid = 68 time =  3439 queue_length = 0
# Customer joins queue caseid = 71 time =  3448 queue_length = 1
# NEXT ARRIVAL TIME:  3493
# Begin_service caseid = 71 time =  3448 queue_length = 1
# End_service caseid = 69 time =  3487 queue_length = 0
# Customer joins queue caseid = 72 time =  3493 queue_length = 1
# NEXT ARRIVAL TIME:  3596
# Begin_service caseid = 72 time =  3493 queue_length = 1
# End_service caseid = 71 time =  3551 queue_length = 0
# Customer joins queue caseid = 73 time =  3596 queue_length = 1
# NEXT ARRIVAL TIME:  3633
# Begin_service caseid = 73 time =  3596 queue_length = 1
# End_service caseid = 70 time =  3612 queue_length = 0
# End_service caseid = 72 time =  3630 queue_length = 0
# Customer joins queue caseid = 74 time =  3633 queue_length = 1
# NEXT ARRIVAL TIME:  3662
# Begin_service caseid = 74 time =  3633 queue_length = 1
# End_service caseid = 73 time =  3656 queue_length = 0
# Customer joins queue caseid = 75 time =  3662 queue_length = 1
# NEXT ARRIVAL TIME:  3672
# Begin_service caseid = 75 time =  3662 queue_length = 1
# Customer joins queue caseid = 76 time =  3672 queue_length = 1
# NEXT ARRIVAL TIME:  3682
# Begin_service caseid = 76 time =  3672 queue_length = 1
# Customer joins queue caseid = 77 time =  3682 queue_length = 1
# NEXT ARRIVAL TIME:  3728
# Customer joins queue caseid = 78 time =  3728 queue_length = 2
# NEXT ARRIVAL TIME:  3749
# Customer joins queue caseid = 79 time =  3749 queue_length = 3
# NEXT ARRIVAL TIME:  3799
# End_service caseid = 76 time =  3760 queue_length = 3
# Begin_service caseid = 77 time =  3760 queue_length = 3
# End_service caseid = 75 time =  3765 queue_length = 2
# Begin_service caseid = 78 time =  3765 queue_length = 2
# Customer joins queue caseid = 80 time =  3799 queue_length = 2
# NEXT ARRIVAL TIME:  3960
# End_service caseid = 77 time =  3839 queue_length = 2
# Begin_service caseid = 79 time =  3839 queue_length = 2
# End_service caseid = 78 time =  3860 queue_length = 1
# Begin_service caseid = 80 time =  3860 queue_length = 1
# End_service caseid = 79 time =  3899 queue_length = 0
# End_service caseid = 80 time =  3920 queue_length = 0
# End_service caseid = 74 time =  3925 queue_length = 0
# Customer joins queue caseid = 81 time =  3960 queue_length = 1
# NEXT ARRIVAL TIME:  4218
# Begin_service caseid = 81 time =  3960 queue_length = 1
# End_service caseid = 81 time =  4020 queue_length = 0
# Customer joins queue caseid = 82 time =  4218 queue_length = 1
# NEXT ARRIVAL TIME:  4274
# Begin_service caseid = 82 time =  4218 queue_length = 1
# Customer joins queue caseid = 83 time =  4274 queue_length = 1
# NEXT ARRIVAL TIME:  4363
# Begin_service caseid = 83 time =  4274 queue_length = 1
# End_service caseid = 82 time =  4314 queue_length = 0
# End_service caseid = 83 time =  4334 queue_length = 0
# Customer joins queue caseid = 84 time =  4363 queue_length = 1
# NEXT ARRIVAL TIME:  4423
# Begin_service caseid = 84 time =  4363 queue_length = 1
# End_service caseid = 84 time =  4423 queue_length = 0
# Customer joins queue caseid = 85 time =  4423 queue_length = 1
# NEXT ARRIVAL TIME:  4445
# Begin_service caseid = 85 time =  4423 queue_length = 1
# Customer joins queue caseid = 86 time =  4445 queue_length = 1
# NEXT ARRIVAL TIME:  4477
# Begin_service caseid = 86 time =  4445 queue_length = 1
# Customer joins queue caseid = 87 time =  4477 queue_length = 1
# NEXT ARRIVAL TIME:  4638
# Begin_service caseid = 87 time =  4477 queue_length = 1
# End_service caseid = 86 time =  4505 queue_length = 0
# End_service caseid = 87 time =  4537 queue_length = 0
# End_service caseid = 85 time =  4628 queue_length = 0
# Customer joins queue caseid = 88 time =  4638 queue_length = 1
# NEXT ARRIVAL TIME:  4665
# Begin_service caseid = 88 time =  4638 queue_length = 1
# Customer joins queue caseid = 89 time =  4665 queue_length = 1
# NEXT ARRIVAL TIME:  4666
# Begin_service caseid = 89 time =  4665 queue_length = 1
# Customer joins queue caseid = 90 time =  4666 queue_length = 1
# NEXT ARRIVAL TIME:  4683
# Begin_service caseid = 90 time =  4666 queue_length = 1
# Customer joins queue caseid = 91 time =  4683 queue_length = 1
# NEXT ARRIVAL TIME:  4765
# End_service caseid = 88 time =  4698 queue_length = 1
# Begin_service caseid = 91 time =  4698 queue_length = 1
# End_service caseid = 89 time =  4725 queue_length = 0
# End_service caseid = 90 time =  4726 queue_length = 0
# End_service caseid = 91 time =  4758 queue_length = 0
# Customer joins queue caseid = 92 time =  4765 queue_length = 1
# NEXT ARRIVAL TIME:  4896
# Begin_service caseid = 92 time =  4765 queue_length = 1
# End_service caseid = 92 time =  4825 queue_length = 0
# Customer joins queue caseid = 93 time =  4896 queue_length = 1
# NEXT ARRIVAL TIME:  4978
# Begin_service caseid = 93 time =  4896 queue_length = 1
# End_service caseid = 93 time =  4956 queue_length = 0
# Customer joins queue caseid = 94 time =  4978 queue_length = 1
# NEXT ARRIVAL TIME:  4982
# Begin_service caseid = 94 time =  4978 queue_length = 1
# Customer joins queue caseid = 95 time =  4982 queue_length = 1
# NEXT ARRIVAL TIME:  5018
# Begin_service caseid = 95 time =  4982 queue_length = 1
# Customer joins queue caseid = 96 time =  5018 queue_length = 1
# NEXT ARRIVAL TIME:  5114
# Begin_service caseid = 96 time =  5018 queue_length = 1
# End_service caseid = 94 time =  5038 queue_length = 0
# Customer joins queue caseid = 97 time =  5114 queue_length = 1
# NEXT ARRIVAL TIME:  5126
# Begin_service caseid = 97 time =  5114 queue_length = 1
# Customer joins queue caseid = 98 time =  5126 queue_length = 1
# NEXT ARRIVAL TIME:  5233
# End_service caseid = 96 time =  5158 queue_length = 1
# Begin_service caseid = 98 time =  5158 queue_length = 1
# End_service caseid = 98 time =  5218 queue_length = 0
# Customer joins queue caseid = 99 time =  5233 queue_length = 1
# NEXT ARRIVAL TIME:  5234
# Begin_service caseid = 99 time =  5233 queue_length = 1
# Customer joins queue caseid = 100 time =  5234 queue_length = 1
# NEXT ARRIVAL TIME:  5351
# End_service caseid = 95 time =  5282 queue_length = 1
# Begin_service caseid = 100 time =  5282 queue_length = 1
# End_service caseid = 97 time =  5283 queue_length = 0
# End_service caseid = 100 time =  5342 queue_length = 0
# Customer joins queue caseid = 101 time =  5351 queue_length = 1
# NEXT ARRIVAL TIME:  5557
# Begin_service caseid = 101 time =  5351 queue_length = 1
# End_service caseid = 99 time =  5404 queue_length = 0
# End_service caseid = 101 time =  5411 queue_length = 0
# Customer joins queue caseid = 102 time =  5557 queue_length = 1
# NEXT ARRIVAL TIME:  5602
# Begin_service caseid = 102 time =  5557 queue_length = 1
# Customer joins queue caseid = 103 time =  5602 queue_length = 1
# NEXT ARRIVAL TIME:  5657
# Begin_service caseid = 103 time =  5602 queue_length = 1
# End_service caseid = 102 time =  5617 queue_length = 0
# Customer joins queue caseid = 104 time =  5657 queue_length = 1
# NEXT ARRIVAL TIME:  5686
# Begin_service caseid = 104 time =  5657 queue_length = 1
# End_service caseid = 103 time =  5678 queue_length = 0
# Customer joins queue caseid = 105 time =  5686 queue_length = 1
# NEXT ARRIVAL TIME:  5714
# Begin_service caseid = 105 time =  5686 queue_length = 1
# Customer joins queue caseid = 106 time =  5714 queue_length = 1
# NEXT ARRIVAL TIME:  5731
# Begin_service caseid = 106 time =  5714 queue_length = 1
# Customer joins queue caseid = 107 time =  5731 queue_length = 1
# NEXT ARRIVAL TIME:  5743
# Customer joins queue caseid = 108 time =  5743 queue_length = 2
# NEXT ARRIVAL TIME:  5861
# End_service caseid = 106 time =  5774 queue_length = 2
# Begin_service caseid = 107 time =  5774 queue_length = 2
# End_service caseid = 104 time =  5788 queue_length = 1
# Begin_service caseid = 108 time =  5788 queue_length = 1
# End_service caseid = 107 time =  5834 queue_length = 0
# Customer joins queue caseid = 109 time =  5861 queue_length = 1
# NEXT ARRIVAL TIME:  5920
# Begin_service caseid = 109 time =  5861 queue_length = 1
# Customer joins queue caseid = 110 time =  5920 queue_length = 1
# NEXT ARRIVAL TIME:  5976
# Customer joins queue caseid = 111 time =  5976 queue_length = 2
# NEXT ARRIVAL TIME:  5998
# End_service caseid = 105 time =  5977 queue_length = 2
# Begin_service caseid = 110 time =  5977 queue_length = 2
# Customer joins queue caseid = 112 time =  5998 queue_length = 2
# NEXT ARRIVAL TIME:  6112
# End_service caseid = 109 time =  6075 queue_length = 2
# Begin_service caseid = 111 time =  6075 queue_length = 2
# End_service caseid = 108 time =  6088 queue_length = 1
# Begin_service caseid = 112 time =  6088 queue_length = 1
# End_service caseid = 110 time =  6111 queue_length = 0
# Customer joins queue caseid = 113 time =  6112 queue_length = 1
# NEXT ARRIVAL TIME:  6119
# Begin_service caseid = 113 time =  6112 queue_length = 1
# Customer joins queue caseid = 114 time =  6119 queue_length = 1
# NEXT ARRIVAL TIME:  6128
# Customer joins queue caseid = 115 time =  6128 queue_length = 2
# NEXT ARRIVAL TIME:  6263
# End_service caseid = 113 time =  6176 queue_length = 2
# Begin_service caseid = 114 time =  6176 queue_length = 2
# End_service caseid = 114 time =  6236 queue_length = 1
# Begin_service caseid = 115 time =  6236 queue_length = 1
# End_service caseid = 111 time =  6261 queue_length = 0
# Customer joins queue caseid = 116 time =  6263 queue_length = 1
# NEXT ARRIVAL TIME:  6279
# Begin_service caseid = 116 time =  6263 queue_length = 1
# Customer joins queue caseid = 117 time =  6279 queue_length = 1
# NEXT ARRIVAL TIME:  6308
# Customer joins queue caseid = 118 time =  6308 queue_length = 2
# NEXT ARRIVAL TIME:  6375
# Customer joins queue caseid = 119 time =  6375 queue_length = 3
# NEXT ARRIVAL TIME:  6412
# End_service caseid = 112 time =  6388 queue_length = 3
# Begin_service caseid = 117 time =  6388 queue_length = 3
# End_service caseid = 116 time =  6403 queue_length = 2
# Begin_service caseid = 118 time =  6403 queue_length = 2
# Customer joins queue caseid = 120 time =  6412 queue_length = 2
# NEXT ARRIVAL TIME:  6492
# End_service caseid = 117 time =  6448 queue_length = 2
# Begin_service caseid = 119 time =  6448 queue_length = 2
# Customer joins queue caseid = 121 time =  6492 queue_length = 2
# NEXT ARRIVAL TIME:  6515
# End_service caseid = 119 time =  6508 queue_length = 2
# Begin_service caseid = 120 time =  6508 queue_length = 2
# Customer joins queue caseid = 122 time =  6515 queue_length = 2
# NEXT ARRIVAL TIME:  6600
# End_service caseid = 115 time =  6536 queue_length = 2
# Begin_service caseid = 121 time =  6536 queue_length = 2
# End_service caseid = 118 time =  6545 queue_length = 1
# Begin_service caseid = 122 time =  6545 queue_length = 1
# Customer joins queue caseid = 123 time =  6600 queue_length = 1
# NEXT ARRIVAL TIME:  6614
# End_service caseid = 122 time =  6605 queue_length = 1
# Begin_service caseid = 123 time =  6605 queue_length = 1
# End_service caseid = 121 time =  6613 queue_length = 0
# Customer joins queue caseid = 124 time =  6614 queue_length = 1
# NEXT ARRIVAL TIME:  6670
# Begin_service caseid = 124 time =  6614 queue_length = 1
# End_service caseid = 120 time =  6615 queue_length = 0
# Customer joins queue caseid = 125 time =  6670 queue_length = 1
# NEXT ARRIVAL TIME:  6727
# Begin_service caseid = 125 time =  6670 queue_length = 1
# End_service caseid = 124 time =  6686 queue_length = 0
# End_service caseid = 123 time =  6711 queue_length = 0
# Customer joins queue caseid = 126 time =  6727 queue_length = 1
# NEXT ARRIVAL TIME:  6779
# Begin_service caseid = 126 time =  6727 queue_length = 1
# End_service caseid = 125 time =  6730 queue_length = 0
# Customer joins queue caseid = 127 time =  6779 queue_length = 1
# NEXT ARRIVAL TIME:  6818
# Begin_service caseid = 127 time =  6779 queue_length = 1
# End_service caseid = 126 time =  6787 queue_length = 0
# Customer joins queue caseid = 128 time =  6818 queue_length = 1
# NEXT ARRIVAL TIME:  6825
# Begin_service caseid = 128 time =  6818 queue_length = 1
# Customer joins queue caseid = 129 time =  6825 queue_length = 1
# NEXT ARRIVAL TIME:  6828
# Begin_service caseid = 129 time =  6825 queue_length = 1
# Customer joins queue caseid = 130 time =  6828 queue_length = 1
# NEXT ARRIVAL TIME:  6916
# End_service caseid = 127 time =  6839 queue_length = 1
# Begin_service caseid = 130 time =  6839 queue_length = 1
# End_service caseid = 129 time =  6885 queue_length = 0
# End_service caseid = 128 time =  6902 queue_length = 0
# Customer joins queue caseid = 131 time =  6916 queue_length = 1
# NEXT ARRIVAL TIME:  6963
# Begin_service caseid = 131 time =  6916 queue_length = 1
# End_service caseid = 130 time =  6934 queue_length = 0
# Customer joins queue caseid = 132 time =  6963 queue_length = 1
# NEXT ARRIVAL TIME:  6969
# Begin_service caseid = 132 time =  6963 queue_length = 1
# Customer joins queue caseid = 133 time =  6969 queue_length = 1
# NEXT ARRIVAL TIME:  7023
# Begin_service caseid = 133 time =  6969 queue_length = 1
# End_service caseid = 131 time =  7016 queue_length = 0
# Customer joins queue caseid = 134 time =  7023 queue_length = 1
# NEXT ARRIVAL TIME:  7130
# Begin_service caseid = 134 time =  7023 queue_length = 1
# End_service caseid = 133 time =  7029 queue_length = 0
# End_service caseid = 132 time =  7081 queue_length = 0
# Customer joins queue caseid = 135 time =  7130 queue_length = 1
# NEXT ARRIVAL TIME:  7147
# Begin_service caseid = 135 time =  7130 queue_length = 1
# Customer joins queue caseid = 136 time =  7147 queue_length = 1
# NEXT ARRIVAL TIME:  7265
# Begin_service caseid = 136 time =  7147 queue_length = 1
# End_service caseid = 134 time =  7171 queue_length = 0
# End_service caseid = 136 time =  7207 queue_length = 0
# Customer joins queue caseid = 137 time =  7265 queue_length = 1
# NEXT ARRIVAL TIME:  7268
# Begin_service caseid = 137 time =  7265 queue_length = 1
# Customer joins queue caseid = 138 time =  7268 queue_length = 1
# NEXT ARRIVAL TIME:  7357
# Begin_service caseid = 138 time =  7268 queue_length = 1
# End_service caseid = 137 time =  7325 queue_length = 0
# End_service caseid = 138 time =  7328 queue_length = 0
# Customer joins queue caseid = 139 time =  7357 queue_length = 1
# NEXT ARRIVAL TIME:  7486
# Begin_service caseid = 139 time =  7357 queue_length = 1
# End_service caseid = 139 time =  7417 queue_length = 0
# End_service caseid = 135 time =  7430 queue_length = 0
# Customer joins queue caseid = 140 time =  7486 queue_length = 1
# NEXT ARRIVAL TIME:  7579
# Begin_service caseid = 140 time =  7486 queue_length = 1
# Customer joins queue caseid = 141 time =  7579 queue_length = 1
# NEXT ARRIVAL TIME:  7590
# Begin_service caseid = 141 time =  7579 queue_length = 1
# Customer joins queue caseid = 142 time =  7590 queue_length = 1
# NEXT ARRIVAL TIME:  7722
# Begin_service caseid = 142 time =  7590 queue_length = 1
# End_service caseid = 142 time =  7650 queue_length = 0
# End_service caseid = 140 time =  7672 queue_length = 0
# End_service caseid = 141 time =  7672 queue_length = 0
# Customer joins queue caseid = 143 time =  7722 queue_length = 1
# NEXT ARRIVAL TIME:  7846
# Begin_service caseid = 143 time =  7722 queue_length = 1
# End_service caseid = 143 time =  7782 queue_length = 0
# Customer joins queue caseid = 144 time =  7846 queue_length = 1
# NEXT ARRIVAL TIME:  7850
# Begin_service caseid = 144 time =  7846 queue_length = 1
# Customer joins queue caseid = 145 time =  7850 queue_length = 1
# NEXT ARRIVAL TIME:  7892
# Begin_service caseid = 145 time =  7850 queue_length = 1
# Customer joins queue caseid = 146 time =  7892 queue_length = 1
# NEXT ARRIVAL TIME:  8001
# Begin_service caseid = 146 time =  7892 queue_length = 1
# End_service caseid = 144 time =  7906 queue_length = 0
# End_service caseid = 145 time =  7910 queue_length = 0
# Customer joins queue caseid = 147 time =  8001 queue_length = 1
# NEXT ARRIVAL TIME:  8132
# Begin_service caseid = 147 time =  8001 queue_length = 1
# End_service caseid = 147 time =  8061 queue_length = 0
# End_service caseid = 146 time =  8106 queue_length = 0
# Customer joins queue caseid = 148 time =  8132 queue_length = 1
# NEXT ARRIVAL TIME:  8202
# Begin_service caseid = 148 time =  8132 queue_length = 1
# Customer joins queue caseid = 149 time =  8202 queue_length = 1
# NEXT ARRIVAL TIME:  8203
# Begin_service caseid = 149 time =  8202 queue_length = 1
# Customer joins queue caseid = 150 time =  8203 queue_length = 1
# NEXT ARRIVAL TIME:  8306
# Begin_service caseid = 150 time =  8203 queue_length = 1
# End_service caseid = 150 time =  8263 queue_length = 0
# End_service caseid = 148 time =  8272 queue_length = 0
# Customer joins queue caseid = 151 time =  8306 queue_length = 1
# NEXT ARRIVAL TIME:  8306
# Begin_service caseid = 151 time =  8306 queue_length = 1
# Customer joins queue caseid = 152 time =  8306 queue_length = 1
# NEXT ARRIVAL TIME:  8325
# Begin_service caseid = 152 time =  8306 queue_length = 1
# End_service caseid = 149 time =  8316 queue_length = 0
# Customer joins queue caseid = 153 time =  8325 queue_length = 1
# NEXT ARRIVAL TIME:  8332
# Begin_service caseid = 153 time =  8325 queue_length = 1
# Customer joins queue caseid = 154 time =  8332 queue_length = 1
# NEXT ARRIVAL TIME:  8349
# Customer joins queue caseid = 155 time =  8349 queue_length = 2
# NEXT ARRIVAL TIME:  8461
# End_service caseid = 153 time =  8385 queue_length = 2
# Begin_service caseid = 154 time =  8385 queue_length = 2
# End_service caseid = 152 time =  8423 queue_length = 1
# Begin_service caseid = 155 time =  8423 queue_length = 1
# End_service caseid = 154 time =  8454 queue_length = 0
# Customer joins queue caseid = 156 time =  8461 queue_length = 1
# NEXT ARRIVAL TIME:  8492
# Begin_service caseid = 156 time =  8461 queue_length = 1
# End_service caseid = 155 time =  8483 queue_length = 0
# Customer joins queue caseid = 157 time =  8492 queue_length = 1
# NEXT ARRIVAL TIME:  8508
# Begin_service caseid = 157 time =  8492 queue_length = 1
# Customer joins queue caseid = 158 time =  8508 queue_length = 1
# NEXT ARRIVAL TIME:  8577
# End_service caseid = 156 time =  8521 queue_length = 1
# Begin_service caseid = 158 time =  8521 queue_length = 1
# Customer joins queue caseid = 159 time =  8577 queue_length = 1
# NEXT ARRIVAL TIME:  8610
# End_service caseid = 151 time =  8606 queue_length = 1
# Begin_service caseid = 159 time =  8606 queue_length = 1
# Customer joins queue caseid = 160 time =  8610 queue_length = 1
# NEXT ARRIVAL TIME:  8664
# End_service caseid = 158 time =  8638 queue_length = 1
# Begin_service caseid = 160 time =  8638 queue_length = 1
# Customer joins queue caseid = 161 time =  8664 queue_length = 1
# NEXT ARRIVAL TIME:  8722
# End_service caseid = 159 time =  8666 queue_length = 1
# Begin_service caseid = 161 time =  8666 queue_length = 1
# Customer joins queue caseid = 162 time =  8722 queue_length = 1
# NEXT ARRIVAL TIME:  8781
# End_service caseid = 157 time =  8746 queue_length = 1
# Begin_service caseid = 162 time =  8746 queue_length = 1
# Customer joins queue caseid = 163 time =  8781 queue_length = 1
# NEXT ARRIVAL TIME:  8807
# End_service caseid = 160 time =  8789 queue_length = 1
# Begin_service caseid = 163 time =  8789 queue_length = 1
# End_service caseid = 162 time =  8806 queue_length = 0
# Customer joins queue caseid = 164 time =  8807 queue_length = 1
# NEXT ARRIVAL TIME:  8821
# Begin_service caseid = 164 time =  8807 queue_length = 1
# Customer joins queue caseid = 165 time =  8821 queue_length = 1
# NEXT ARRIVAL TIME:  8852
# Customer joins queue caseid = 166 time =  8852 queue_length = 2
# NEXT ARRIVAL TIME:  8907
# End_service caseid = 164 time =  8893 queue_length = 2
# Begin_service caseid = 165 time =  8893 queue_length = 2
# Customer joins queue caseid = 167 time =  8907 queue_length = 2
# NEXT ARRIVAL TIME:  8938
# End_service caseid = 161 time =  8918 queue_length = 2
# Begin_service caseid = 166 time =  8918 queue_length = 2
# Customer joins queue caseid = 168 time =  8938 queue_length = 2
# NEXT ARRIVAL TIME:  8978
# End_service caseid = 163 time =  8972 queue_length = 2
# Begin_service caseid = 167 time =  8972 queue_length = 2
# Customer joins queue caseid = 169 time =  8978 queue_length = 2
# NEXT ARRIVAL TIME:  9015
# End_service caseid = 165 time =  9008 queue_length = 2
# Begin_service caseid = 168 time =  9008 queue_length = 2
# Customer joins queue caseid = 170 time =  9015 queue_length = 2
# NEXT ARRIVAL TIME:  9026
# Customer joins queue caseid = 171 time =  9026 queue_length = 3
# NEXT ARRIVAL TIME:  9033
# Customer joins queue caseid = 172 time =  9033 queue_length = 4
# NEXT ARRIVAL TIME:  9100
# End_service caseid = 167 time =  9043 queue_length = 4
# Begin_service caseid = 169 time =  9043 queue_length = 4
# End_service caseid = 166 time =  9064 queue_length = 3
# Begin_service caseid = 170 time =  9064 queue_length = 3
# End_service caseid = 168 time =  9068 queue_length = 2
# Begin_service caseid = 171 time =  9068 queue_length = 2
# Customer joins queue caseid = 173 time =  9100 queue_length = 2
# NEXT ARRIVAL TIME:  9173
# End_service caseid = 169 time =  9103 queue_length = 2
# Begin_service caseid = 172 time =  9103 queue_length = 2
# End_service caseid = 170 time =  9124 queue_length = 1
# Begin_service caseid = 173 time =  9124 queue_length = 1
# End_service caseid = 171 time =  9141 queue_length = 0
# Customer joins queue caseid = 174 time =  9173 queue_length = 1
# NEXT ARRIVAL TIME:  9261
# Begin_service caseid = 174 time =  9173 queue_length = 1
# End_service caseid = 172 time =  9245 queue_length = 0
# End_service caseid = 173 time =  9255 queue_length = 0
# Customer joins queue caseid = 175 time =  9261 queue_length = 1
# NEXT ARRIVAL TIME:  9282
# Begin_service caseid = 175 time =  9261 queue_length = 1
# Customer joins queue caseid = 176 time =  9282 queue_length = 1
# NEXT ARRIVAL TIME:  9342
# Begin_service caseid = 176 time =  9282 queue_length = 1
# End_service caseid = 174 time =  9295 queue_length = 0
# End_service caseid = 176 time =  9342 queue_length = 0
# Customer joins queue caseid = 177 time =  9342 queue_length = 1
# NEXT ARRIVAL TIME:  9345
# Begin_service caseid = 177 time =  9342 queue_length = 1
# Customer joins queue caseid = 178 time =  9345 queue_length = 1
# NEXT ARRIVAL TIME:  9414
# Begin_service caseid = 178 time =  9345 queue_length = 1
# End_service caseid = 177 time =  9402 queue_length = 0
# End_service caseid = 178 time =  9407 queue_length = 0
# Customer joins queue caseid = 179 time =  9414 queue_length = 1
# NEXT ARRIVAL TIME:  9427
# Begin_service caseid = 179 time =  9414 queue_length = 1
# End_service caseid = 175 time =  9422 queue_length = 0
# Customer joins queue caseid = 180 time =  9427 queue_length = 1
# NEXT ARRIVAL TIME:  9461
# Begin_service caseid = 180 time =  9427 queue_length = 1
# Customer joins queue caseid = 181 time =  9461 queue_length = 1
# NEXT ARRIVAL TIME:  9544
# Begin_service caseid = 181 time =  9461 queue_length = 1
# End_service caseid = 179 time =  9474 queue_length = 0
# End_service caseid = 180 time =  9487 queue_length = 0
# End_service caseid = 181 time =  9521 queue_length = 0
# Customer joins queue caseid = 182 time =  9544 queue_length = 1
# NEXT ARRIVAL TIME:  9571
# Begin_service caseid = 182 time =  9544 queue_length = 1
# Customer joins queue caseid = 183 time =  9571 queue_length = 1
# NEXT ARRIVAL TIME:  9584
# Begin_service caseid = 183 time =  9571 queue_length = 1
# Customer joins queue caseid = 184 time =  9584 queue_length = 1
# NEXT ARRIVAL TIME:  9619
# Begin_service caseid = 184 time =  9584 queue_length = 1
# End_service caseid = 182 time =  9618 queue_length = 0
# Customer joins queue caseid = 185 time =  9619 queue_length = 1
# NEXT ARRIVAL TIME:  9677
# Begin_service caseid = 185 time =  9619 queue_length = 1
# End_service caseid = 184 time =  9644 queue_length = 0
# Customer joins queue caseid = 186 time =  9677 queue_length = 1
# NEXT ARRIVAL TIME:  9714
# Begin_service caseid = 186 time =  9677 queue_length = 1
# Customer joins queue caseid = 187 time =  9714 queue_length = 1
# NEXT ARRIVAL TIME:  9718
# Customer joins queue caseid = 188 time =  9718 queue_length = 2
# NEXT ARRIVAL TIME:  9756
# Customer joins queue caseid = 189 time =  9756 queue_length = 3
# NEXT ARRIVAL TIME:  9820
# End_service caseid = 186 time =  9790 queue_length = 3
# Begin_service caseid = 187 time =  9790 queue_length = 3
# End_service caseid = 183 time =  9798 queue_length = 2
# Begin_service caseid = 188 time =  9798 queue_length = 2
# End_service caseid = 185 time =  9805 queue_length = 1
# Begin_service caseid = 189 time =  9805 queue_length = 1
# Customer joins queue caseid = 190 time =  9820 queue_length = 1
# NEXT ARRIVAL TIME:  9829
# Customer joins queue caseid = 191 time =  9829 queue_length = 2
# NEXT ARRIVAL TIME:  9960
# End_service caseid = 187 time =  9850 queue_length = 2
# Begin_service caseid = 190 time =  9850 queue_length = 2
# End_service caseid = 188 time =  9871 queue_length = 1
# Begin_service caseid = 191 time =  9871 queue_length = 1
# End_service caseid = 189 time =  9887 queue_length = 0
# Customer joins queue caseid = 192 time =  9960 queue_length = 1
# NEXT ARRIVAL TIME:  10112
# Begin_service caseid = 192 time =  9960 queue_length = 1
# End_service caseid = 190 time =  9998 queue_length = 0
# End_service caseid = 191 time =  10042 queue_length = 0
# End_service caseid = 192 time =  10062 queue_length = 0
# Customer joins queue caseid = 193 time =  10112 queue_length = 1
# NEXT ARRIVAL TIME:  10134
# Begin_service caseid = 193 time =  10112 queue_length = 1
# Customer joins queue caseid = 194 time =  10134 queue_length = 1
# NEXT ARRIVAL TIME:  10191
# Begin_service caseid = 194 time =  10134 queue_length = 1
# Customer joins queue caseid = 195 time =  10191 queue_length = 1
# NEXT ARRIVAL TIME:  10239
# Begin_service caseid = 195 time =  10191 queue_length = 1
# End_service caseid = 193 time =  10216 queue_length = 0
# Customer joins queue caseid = 196 time =  10239 queue_length = 1
# NEXT ARRIVAL TIME:  10328
# Begin_service caseid = 196 time =  10239 queue_length = 1
# End_service caseid = 195 time =  10251 queue_length = 0
# End_service caseid = 194 time =  10281 queue_length = 0
# Customer joins queue caseid = 197 time =  10328 queue_length = 1
# NEXT ARRIVAL TIME:  10382
# Begin_service caseid = 197 time =  10328 queue_length = 1
# Customer joins queue caseid = 198 time =  10382 queue_length = 1
# NEXT ARRIVAL TIME:  10396
# Begin_service caseid = 198 time =  10382 queue_length = 1
# End_service caseid = 196 time =  10386 queue_length = 0
# Customer joins queue caseid = 199 time =  10396 queue_length = 1
# NEXT ARRIVAL TIME:  10431
# Begin_service caseid = 199 time =  10396 queue_length = 1
# Customer joins queue caseid = 200 time =  10431 queue_length = 1
# NEXT ARRIVAL TIME:  10465
# Customer joins queue caseid = 201 time =  10465 queue_length = 2
# NEXT ARRIVAL TIME:  10595
# End_service caseid = 199 time =  10488 queue_length = 2
# Begin_service caseid = 200 time =  10488 queue_length = 2
# End_service caseid = 198 time =  10521 queue_length = 1
# Begin_service caseid = 201 time =  10521 queue_length = 1
# End_service caseid = 200 time =  10548 queue_length = 0
# End_service caseid = 201 time =  10581 queue_length = 0
# Customer joins queue caseid = 202 time =  10595 queue_length = 1
# NEXT ARRIVAL TIME:  10754
# Begin_service caseid = 202 time =  10595 queue_length = 1
# End_service caseid = 197 time =  10628 queue_length = 0
# End_service caseid = 202 time =  10655 queue_length = 0
# Customer joins queue caseid = 203 time =  10754 queue_length = 1
# NEXT ARRIVAL TIME:  10762
# Begin_service caseid = 203 time =  10754 queue_length = 1
# Customer joins queue caseid = 204 time =  10762 queue_length = 1
# NEXT ARRIVAL TIME:  10871
# Begin_service caseid = 204 time =  10762 queue_length = 1
# Customer joins queue caseid = 205 time =  10871 queue_length = 1
# NEXT ARRIVAL TIME:  11037
# Begin_service caseid = 205 time =  10871 queue_length = 1
# End_service caseid = 203 time =  10954 queue_length = 0
# Customer joins queue caseid = 206 time =  11037 queue_length = 1
# NEXT ARRIVAL TIME:  11039
# Begin_service caseid = 206 time =  11037 queue_length = 1
# Customer joins queue caseid = 207 time =  11039 queue_length = 1
# NEXT ARRIVAL TIME:  11049
# Customer joins queue caseid = 208 time =  11049 queue_length = 2
# NEXT ARRIVAL TIME:  11094
# End_service caseid = 205 time =  11052 queue_length = 2
# Begin_service caseid = 207 time =  11052 queue_length = 2
# End_service caseid = 204 time =  11062 queue_length = 1
# Begin_service caseid = 208 time =  11062 queue_length = 1
# Customer joins queue caseid = 209 time =  11094 queue_length = 1
# NEXT ARRIVAL TIME:  11109
# End_service caseid = 206 time =  11097 queue_length = 1
# Begin_service caseid = 209 time =  11097 queue_length = 1
# Customer joins queue caseid = 210 time =  11109 queue_length = 1
# NEXT ARRIVAL TIME:  11212
# End_service caseid = 207 time =  11112 queue_length = 1
# Begin_service caseid = 210 time =  11112 queue_length = 1
# End_service caseid = 208 time =  11122 queue_length = 0
# End_service caseid = 209 time =  11157 queue_length = 0
# End_service caseid = 210 time =  11172 queue_length = 0
# Customer joins queue caseid = 211 time =  11212 queue_length = 1
# NEXT ARRIVAL TIME:  11358
# Begin_service caseid = 211 time =  11212 queue_length = 1
# End_service caseid = 211 time =  11272 queue_length = 0
# Customer joins queue caseid = 212 time =  11358 queue_length = 1
# NEXT ARRIVAL TIME:  11366
# Begin_service caseid = 212 time =  11358 queue_length = 1
# Customer joins queue caseid = 213 time =  11366 queue_length = 1
# NEXT ARRIVAL TIME:  11538
# Begin_service caseid = 213 time =  11366 queue_length = 1
# End_service caseid = 212 time =  11490 queue_length = 0
# End_service caseid = 213 time =  11504 queue_length = 0
# Customer joins queue caseid = 214 time =  11538 queue_length = 1
# NEXT ARRIVAL TIME:  11760
# Begin_service caseid = 214 time =  11538 queue_length = 1
# End_service caseid = 214 time =  11671 queue_length = 0
# Customer joins queue caseid = 215 time =  11760 queue_length = 1
# NEXT ARRIVAL TIME:  11765
# Begin_service caseid = 215 time =  11760 queue_length = 1
# Customer joins queue caseid = 216 time =  11765 queue_length = 1
# NEXT ARRIVAL TIME:  11787
# Begin_service caseid = 216 time =  11765 queue_length = 1
# Customer joins queue caseid = 217 time =  11787 queue_length = 1
# NEXT ARRIVAL TIME:  11815
# Begin_service caseid = 217 time =  11787 queue_length = 1
# Customer joins queue caseid = 218 time =  11815 queue_length = 1
# NEXT ARRIVAL TIME:  11815
# Customer joins queue caseid = 219 time =  11815 queue_length = 2
# NEXT ARRIVAL TIME:  11870
# End_service caseid = 215 time =  11822 queue_length = 2
# Begin_service caseid = 218 time =  11822 queue_length = 2
# End_service caseid = 216 time =  11825 queue_length = 1
# Begin_service caseid = 219 time =  11825 queue_length = 1
# End_service caseid = 217 time =  11847 queue_length = 0
# Customer joins queue caseid = 220 time =  11870 queue_length = 1
# NEXT ARRIVAL TIME:  11890
# Begin_service caseid = 220 time =  11870 queue_length = 1
# End_service caseid = 219 time =  11885 queue_length = 0
# Customer joins queue caseid = 221 time =  11890 queue_length = 1
# NEXT ARRIVAL TIME:  11946
# Begin_service caseid = 221 time =  11890 queue_length = 1
# Customer joins queue caseid = 222 time =  11946 queue_length = 1
# NEXT ARRIVAL TIME:  11969
# End_service caseid = 221 time =  11960 queue_length = 1
# Begin_service caseid = 222 time =  11960 queue_length = 1
# End_service caseid = 218 time =  11963 queue_length = 0
# Customer joins queue caseid = 223 time =  11969 queue_length = 1
# NEXT ARRIVAL TIME:  12041
# Begin_service caseid = 223 time =  11969 queue_length = 1
# End_service caseid = 222 time =  12020 queue_length = 0
# End_service caseid = 223 time =  12029 queue_length = 0
# Customer joins queue caseid = 224 time =  12041 queue_length = 1
# NEXT ARRIVAL TIME:  12074
# Begin_service caseid = 224 time =  12041 queue_length = 1
# Customer joins queue caseid = 225 time =  12074 queue_length = 1
# NEXT ARRIVAL TIME:  12112
# Begin_service caseid = 225 time =  12074 queue_length = 1
# End_service caseid = 224 time =  12101 queue_length = 0
# Customer joins queue caseid = 226 time =  12112 queue_length = 1
# NEXT ARRIVAL TIME:  12160
# Begin_service caseid = 226 time =  12112 queue_length = 1
# End_service caseid = 225 time =  12134 queue_length = 0
# Customer joins queue caseid = 227 time =  12160 queue_length = 1
# NEXT ARRIVAL TIME:  12214
# Begin_service caseid = 227 time =  12160 queue_length = 1
# End_service caseid = 220 time =  12170 queue_length = 0
# End_service caseid = 226 time =  12198 queue_length = 0
# Customer joins queue caseid = 228 time =  12214 queue_length = 1
# NEXT ARRIVAL TIME:  12347
# Begin_service caseid = 228 time =  12214 queue_length = 1
# End_service caseid = 228 time =  12274 queue_length = 0
# Customer joins queue caseid = 229 time =  12347 queue_length = 1
# NEXT ARRIVAL TIME:  12380
# Begin_service caseid = 229 time =  12347 queue_length = 1
# Customer joins queue caseid = 230 time =  12380 queue_length = 1
# NEXT ARRIVAL TIME:  12521
# Begin_service caseid = 230 time =  12380 queue_length = 1
# End_service caseid = 230 time =  12459 queue_length = 0
# End_service caseid = 227 time =  12460 queue_length = 0
# Customer joins queue caseid = 231 time =  12521 queue_length = 1
# NEXT ARRIVAL TIME:  12687
# Begin_service caseid = 231 time =  12521 queue_length = 1
# End_service caseid = 229 time =  12552 queue_length = 0
# End_service caseid = 231 time =  12581 queue_length = 0
# Customer joins queue caseid = 232 time =  12687 queue_length = 1
# NEXT ARRIVAL TIME:  12731
# Begin_service caseid = 232 time =  12687 queue_length = 1
# Customer joins queue caseid = 233 time =  12731 queue_length = 1
# NEXT ARRIVAL TIME:  12758
# Begin_service caseid = 233 time =  12731 queue_length = 1
# Customer joins queue caseid = 234 time =  12758 queue_length = 1
# NEXT ARRIVAL TIME:  12770
# Begin_service caseid = 234 time =  12758 queue_length = 1
# Customer joins queue caseid = 235 time =  12770 queue_length = 1
# NEXT ARRIVAL TIME:  12779
# Customer joins queue caseid = 236 time =  12779 queue_length = 2
# NEXT ARRIVAL TIME:  12831
# End_service caseid = 233 time =  12820 queue_length = 2
# Begin_service caseid = 235 time =  12820 queue_length = 2
# End_service caseid = 234 time =  12821 queue_length = 1
# Begin_service caseid = 236 time =  12821 queue_length = 1
# Customer joins queue caseid = 237 time =  12831 queue_length = 1
# NEXT ARRIVAL TIME:  12859
# Customer joins queue caseid = 238 time =  12859 queue_length = 2
# NEXT ARRIVAL TIME:  12933
# End_service caseid = 236 time =  12881 queue_length = 2
# Begin_service caseid = 237 time =  12881 queue_length = 2
# End_service caseid = 235 time =  12922 queue_length = 1
# Begin_service caseid = 238 time =  12922 queue_length = 1
# End_service caseid = 232 time =  12931 queue_length = 0
# Customer joins queue caseid = 239 time =  12933 queue_length = 1
# NEXT ARRIVAL TIME:  12951
# Begin_service caseid = 239 time =  12933 queue_length = 1
# Customer joins queue caseid = 240 time =  12951 queue_length = 1
# NEXT ARRIVAL TIME:  13038
# End_service caseid = 237 time =  12975 queue_length = 1
# Begin_service caseid = 240 time =  12975 queue_length = 1
# End_service caseid = 238 time =  12985 queue_length = 0
# End_service caseid = 239 time =  12993 queue_length = 0
# ...
# End_service caseid = 535 time =  30746 queue_length = 0
# End_service caseid = 530 time =  30757 queue_length = 0
# Customer joins queue caseid = 536 time =  30786 queue_length = 1
# NEXT ARRIVAL TIME:  30817
# Begin_service caseid = 536 time =  30786 queue_length = 1
# End_service caseid = 534 time =  30787 queue_length = 0
# Customer joins queue caseid = 537 time =  30817 queue_length = 1
# NEXT ARRIVAL TIME:  30915
# Begin_service caseid = 537 time =  30817 queue_length = 1
# End_service caseid = 537 time =  30877 queue_length = 0
# Customer joins queue caseid = 538 time =  30915 queue_length = 1
# NEXT ARRIVAL TIME:  31052
# Begin_service caseid = 538 time =  30915 queue_length = 1
# End_service caseid = 536 time =  30953 queue_length = 0
# End_service caseid = 538 time =  30975 queue_length = 0
# Customer joins queue caseid = 539 time =  31052 queue_length = 1
# NEXT ARRIVAL TIME:  31064
# Begin_service caseid = 539 time =  31052 queue_length = 1
# Customer joins queue caseid = 540 time =  31064 queue_length = 1
# NEXT ARRIVAL TIME:  31071
# Begin_service caseid = 540 time =  31064 queue_length = 1
# Customer joins queue caseid = 541 time =  31071 queue_length = 1
# NEXT ARRIVAL TIME:  31096
# Begin_service caseid = 541 time =  31071 queue_length = 1
# Customer joins queue caseid = 542 time =  31096 queue_length = 1
# NEXT ARRIVAL TIME:  31127
# Customer joins queue caseid = 543 time =  31127 queue_length = 2
# NEXT ARRIVAL TIME:  31249
# End_service caseid = 540 time =  31186 queue_length = 2
# Begin_service caseid = 542 time =  31186 queue_length = 2
# End_service caseid = 542 time =  31246 queue_length = 1
# Begin_service caseid = 543 time =  31246 queue_length = 1
# Customer joins queue caseid = 544 time =  31249 queue_length = 1
# NEXT ARRIVAL TIME:  31348
# End_service caseid = 541 time =  31291 queue_length = 1
# Begin_service caseid = 544 time =  31291 queue_length = 1
# Customer joins queue caseid = 545 time =  31348 queue_length = 1
# NEXT ARRIVAL TIME:  31405
# End_service caseid = 539 time =  31352 queue_length = 1
# Begin_service caseid = 545 time =  31352 queue_length = 1
# End_service caseid = 544 time =  31363 queue_length = 0
# Customer joins queue caseid = 546 time =  31405 queue_length = 1
# NEXT ARRIVAL TIME:  31442
# Begin_service caseid = 546 time =  31405 queue_length = 1
# Customer joins queue caseid = 547 time =  31442 queue_length = 1
# NEXT ARRIVAL TIME:  31463
# Customer joins queue caseid = 548 time =  31463 queue_length = 2
# NEXT ARRIVAL TIME:  31601
# End_service caseid = 545 time =  31519 queue_length = 2
# Begin_service caseid = 547 time =  31519 queue_length = 2
# End_service caseid = 543 time =  31546 queue_length = 1
# Begin_service caseid = 548 time =  31546 queue_length = 1
# Customer joins queue caseid = 549 time =  31601 queue_length = 1
# NEXT ARRIVAL TIME:  31624
# End_service caseid = 547 time =  31605 queue_length = 1
# Begin_service caseid = 549 time =  31605 queue_length = 1
# Customer joins queue caseid = 550 time =  31624 queue_length = 1
# NEXT ARRIVAL TIME:  31639
# Customer joins queue caseid = 551 time =  31639 queue_length = 2
# NEXT ARRIVAL TIME:  31777
# End_service caseid = 548 time =  31640 queue_length = 2
# Begin_service caseid = 550 time =  31640 queue_length = 2
# End_service caseid = 546 time =  31647 queue_length = 1
# Begin_service caseid = 551 time =  31647 queue_length = 1
# End_service caseid = 549 time =  31665 queue_length = 0
# End_service caseid = 551 time =  31707 queue_length = 0
# End_service caseid = 550 time =  31759 queue_length = 0
# Customer joins queue caseid = 552 time =  31777 queue_length = 1
# NEXT ARRIVAL TIME:  31778
# Begin_service caseid = 552 time =  31777 queue_length = 1
# Customer joins queue caseid = 553 time =  31778 queue_length = 1
# NEXT ARRIVAL TIME:  31792
# Begin_service caseid = 553 time =  31778 queue_length = 1
# Customer joins queue caseid = 554 time =  31792 queue_length = 1
# NEXT ARRIVAL TIME:  31825
# Begin_service caseid = 554 time =  31792 queue_length = 1
# Customer joins queue caseid = 555 time =  31825 queue_length = 1
# NEXT ARRIVAL TIME:  31891
# End_service caseid = 552 time =  31837 queue_length = 1
# Begin_service caseid = 555 time =  31837 queue_length = 1
# End_service caseid = 554 time =  31852 queue_length = 0
# Customer joins queue caseid = 556 time =  31891 queue_length = 1
# NEXT ARRIVAL TIME:  31892
# Begin_service caseid = 556 time =  31891 queue_length = 1
# Customer joins queue caseid = 557 time =  31892 queue_length = 1
# NEXT ARRIVAL TIME:  31908
# Customer joins queue caseid = 558 time =  31908 queue_length = 2
# NEXT ARRIVAL TIME:  31922
# Customer joins queue caseid = 559 time =  31922 queue_length = 3
# NEXT ARRIVAL TIME:  32021
# End_service caseid = 556 time =  31980 queue_length = 3
# Begin_service caseid = 557 time =  31980 queue_length = 3
# End_service caseid = 553 time =  31981 queue_length = 2
# Begin_service caseid = 558 time =  31981 queue_length = 2
# Customer joins queue caseid = 560 time =  32021 queue_length = 2
# NEXT ARRIVAL TIME:  32181
# End_service caseid = 555 time =  32026 queue_length = 2
# Begin_service caseid = 559 time =  32026 queue_length = 2
# End_service caseid = 559 time =  32128 queue_length = 1
# Begin_service caseid = 560 time =  32128 queue_length = 1
# End_service caseid = 557 time =  32139 queue_length = 0
# Customer joins queue caseid = 561 time =  32181 queue_length = 1
# NEXT ARRIVAL TIME:  32209
# Begin_service caseid = 561 time =  32181 queue_length = 1
# End_service caseid = 560 time =  32188 queue_length = 0
# End_service caseid = 558 time =  32195 queue_length = 0
# Customer joins queue caseid = 562 time =  32209 queue_length = 1
# NEXT ARRIVAL TIME:  32294
# Begin_service caseid = 562 time =  32209 queue_length = 1
# End_service caseid = 562 time =  32269 queue_length = 0
# End_service caseid = 561 time =  32271 queue_length = 0
# Customer joins queue caseid = 563 time =  32294 queue_length = 1
# NEXT ARRIVAL TIME:  32295
# Begin_service caseid = 563 time =  32294 queue_length = 1
# Customer joins queue caseid = 564 time =  32295 queue_length = 1
# NEXT ARRIVAL TIME:  32465
# Begin_service caseid = 564 time =  32295 queue_length = 1
# End_service caseid = 563 time =  32354 queue_length = 0
# End_service caseid = 564 time =  32438 queue_length = 0
# Customer joins queue caseid = 565 time =  32465 queue_length = 1
# NEXT ARRIVAL TIME:  32514
# Begin_service caseid = 565 time =  32465 queue_length = 1
# Customer joins queue caseid = 566 time =  32514 queue_length = 1
# NEXT ARRIVAL TIME:  32527
# Begin_service caseid = 566 time =  32514 queue_length = 1
# End_service caseid = 565 time =  32525 queue_length = 0
# Customer joins queue caseid = 567 time =  32527 queue_length = 1
# NEXT ARRIVAL TIME:  32623
# Begin_service caseid = 567 time =  32527 queue_length = 1
# End_service caseid = 567 time =  32620 queue_length = 0
# Customer joins queue caseid = 568 time =  32623 queue_length = 1
# NEXT ARRIVAL TIME:  32651
# Begin_service caseid = 568 time =  32623 queue_length = 1
# Customer joins queue caseid = 569 time =  32651 queue_length = 1
# NEXT ARRIVAL TIME:  32750
# Begin_service caseid = 569 time =  32651 queue_length = 1
# End_service caseid = 569 time =  32737 queue_length = 0
# Customer joins queue caseid = 570 time =  32750 queue_length = 1
# NEXT ARRIVAL TIME:  32814
# Begin_service caseid = 570 time =  32750 queue_length = 1
# End_service caseid = 566 time =  32814 queue_length = 0
# Customer joins queue caseid = 571 time =  32814 queue_length = 1
# NEXT ARRIVAL TIME:  32816
# Begin_service caseid = 571 time =  32814 queue_length = 1
# Customer joins queue caseid = 572 time =  32816 queue_length = 1
# NEXT ARRIVAL TIME:  32858
# Customer joins queue caseid = 573 time =  32858 queue_length = 2
# NEXT ARRIVAL TIME:  33032
# End_service caseid = 570 time =  32870 queue_length = 2
# Begin_service caseid = 572 time =  32870 queue_length = 2
# End_service caseid = 571 time =  32874 queue_length = 1
# Begin_service caseid = 573 time =  32874 queue_length = 1
# End_service caseid = 568 time =  32923 queue_length = 0
# End_service caseid = 573 time =  32934 queue_length = 0
# End_service caseid = 572 time =  32942 queue_length = 0
# Customer joins queue caseid = 574 time =  33032 queue_length = 1
# NEXT ARRIVAL TIME:  33469
# Begin_service caseid = 574 time =  33032 queue_length = 1
# End_service caseid = 574 time =  33174 queue_length = 0
# Customer joins queue caseid = 575 time =  33469 queue_length = 1
# NEXT ARRIVAL TIME:  33549
# Begin_service caseid = 575 time =  33469 queue_length = 1
# End_service caseid = 575 time =  33529 queue_length = 0
# Customer joins queue caseid = 576 time =  33549 queue_length = 1
# NEXT ARRIVAL TIME:  33640
# Begin_service caseid = 576 time =  33549 queue_length = 1
# Customer joins queue caseid = 577 time =  33640 queue_length = 1
# NEXT ARRIVAL TIME:  33881
# Begin_service caseid = 577 time =  33640 queue_length = 1
# End_service caseid = 576 time =  33849 queue_length = 0
# Customer joins queue caseid = 578 time =  33881 queue_length = 1
# NEXT ARRIVAL TIME:  33970
# Begin_service caseid = 578 time =  33881 queue_length = 1
# End_service caseid = 577 time =  33940 queue_length = 0
# Customer joins queue caseid = 579 time =  33970 queue_length = 1
# NEXT ARRIVAL TIME:  34074
# Begin_service caseid = 579 time =  33970 queue_length = 1
# End_service caseid = 579 time =  34030 queue_length = 0
# End_service caseid = 578 time =  34072 queue_length = 0
# Customer joins queue caseid = 580 time =  34074 queue_length = 1
# NEXT ARRIVAL TIME:  34123
# Begin_service caseid = 580 time =  34074 queue_length = 1
# Customer joins queue caseid = 581 time =  34123 queue_length = 1
# NEXT ARRIVAL TIME:  34138
# Begin_service caseid = 581 time =  34123 queue_length = 1
# Customer joins queue caseid = 582 time =  34138 queue_length = 1
# NEXT ARRIVAL TIME:  34177
# Begin_service caseid = 582 time =  34138 queue_length = 1
# End_service caseid = 580 time =  34149 queue_length = 0
# Customer joins queue caseid = 583 time =  34177 queue_length = 1
# NEXT ARRIVAL TIME:  34194
# Begin_service caseid = 583 time =  34177 queue_length = 1
# Customer joins queue caseid = 584 time =  34194 queue_length = 1
# NEXT ARRIVAL TIME:  34218
# End_service caseid = 582 time =  34198 queue_length = 1
# Begin_service caseid = 584 time =  34198 queue_length = 1
# Customer joins queue caseid = 585 time =  34218 queue_length = 1
# NEXT ARRIVAL TIME:  34335
# End_service caseid = 583 time =  34237 queue_length = 1
# Begin_service caseid = 585 time =  34237 queue_length = 1
# End_service caseid = 584 time =  34258 queue_length = 0
# Customer joins queue caseid = 586 time =  34335 queue_length = 1
# NEXT ARRIVAL TIME:  34370
# Begin_service caseid = 586 time =  34335 queue_length = 1
# End_service caseid = 585 time =  34340 queue_length = 0
# Customer joins queue caseid = 587 time =  34370 queue_length = 1
# NEXT ARRIVAL TIME:  34428
# Begin_service caseid = 587 time =  34370 queue_length = 1
# End_service caseid = 586 time =  34395 queue_length = 0
# End_service caseid = 581 time =  34423 queue_length = 0
# Customer joins queue caseid = 588 time =  34428 queue_length = 1
# NEXT ARRIVAL TIME:  34476
# Begin_service caseid = 588 time =  34428 queue_length = 1
# End_service caseid = 587 time =  34430 queue_length = 0
# Customer joins queue caseid = 589 time =  34476 queue_length = 1
# NEXT ARRIVAL TIME:  34485
# Begin_service caseid = 589 time =  34476 queue_length = 1
# Customer joins queue caseid = 590 time =  34485 queue_length = 1
# NEXT ARRIVAL TIME:  34556
# Begin_service caseid = 590 time =  34485 queue_length = 1
# End_service caseid = 588 time =  34533 queue_length = 0
# End_service caseid = 589 time =  34536 queue_length = 0
# End_service caseid = 590 time =  34552 queue_length = 0
# Customer joins queue caseid = 591 time =  34556 queue_length = 1
# NEXT ARRIVAL TIME:  34605
# Begin_service caseid = 591 time =  34556 queue_length = 1
# Customer joins queue caseid = 592 time =  34605 queue_length = 1
# NEXT ARRIVAL TIME:  34658
# Begin_service caseid = 592 time =  34605 queue_length = 1
# End_service caseid = 591 time =  34639 queue_length = 0
# Customer joins queue caseid = 593 time =  34658 queue_length = 1
# NEXT ARRIVAL TIME:  34659
# Begin_service caseid = 593 time =  34658 queue_length = 1
# Customer joins queue caseid = 594 time =  34659 queue_length = 1
# NEXT ARRIVAL TIME:  34684
# Begin_service caseid = 594 time =  34659 queue_length = 1
# End_service caseid = 592 time =  34665 queue_length = 0
# Customer joins queue caseid = 595 time =  34684 queue_length = 1
# NEXT ARRIVAL TIME:  34693
# Begin_service caseid = 595 time =  34684 queue_length = 1
# Customer joins queue caseid = 596 time =  34693 queue_length = 1
# NEXT ARRIVAL TIME:  34714
# Customer joins queue caseid = 597 time =  34714 queue_length = 2
# NEXT ARRIVAL TIME:  34793
# End_service caseid = 593 time =  34724 queue_length = 2
# Begin_service caseid = 596 time =  34724 queue_length = 2
# End_service caseid = 594 time =  34729 queue_length = 1
# Begin_service caseid = 597 time =  34729 queue_length = 1
# End_service caseid = 595 time =  34767 queue_length = 0
# End_service caseid = 596 time =  34784 queue_length = 0
# End_service caseid = 597 time =  34789 queue_length = 0
# Customer joins queue caseid = 598 time =  34793 queue_length = 1
# NEXT ARRIVAL TIME:  34835
# Begin_service caseid = 598 time =  34793 queue_length = 1
# Customer joins queue caseid = 599 time =  34835 queue_length = 1
# NEXT ARRIVAL TIME:  34896
# Begin_service caseid = 599 time =  34835 queue_length = 1
# Customer joins queue caseid = 600 time =  34896 queue_length = 1
# NEXT ARRIVAL TIME:  34931
# Begin_service caseid = 600 time =  34896 queue_length = 1
# Customer joins queue caseid = 601 time =  34931 queue_length = 1
# NEXT ARRIVAL TIME:  35008
# End_service caseid = 600 time =  34956 queue_length = 1
# Begin_service caseid = 601 time =  34956 queue_length = 1
# End_service caseid = 598 time =  34980 queue_length = 0
# Customer joins queue caseid = 602 time =  35008 queue_length = 1
# NEXT ARRIVAL TIME:  35043
# Begin_service caseid = 602 time =  35008 queue_length = 1
# Customer joins queue caseid = 603 time =  35043 queue_length = 1
# NEXT ARRIVAL TIME:  35175
# End_service caseid = 599 time =  35057 queue_length = 1
# Begin_service caseid = 603 time =  35057 queue_length = 1
# End_service caseid = 602 time =  35068 queue_length = 0
# End_service caseid = 601 time =  35092 queue_length = 0
# End_service caseid = 603 time =  35122 queue_length = 0
# Customer joins queue caseid = 604 time =  35175 queue_length = 1
# NEXT ARRIVAL TIME:  35235
# Begin_service caseid = 604 time =  35175 queue_length = 1
# End_service caseid = 604 time =  35235 queue_length = 0
# Customer joins queue caseid = 605 time =  35235 queue_length = 1
# NEXT ARRIVAL TIME:  35548
# Begin_service caseid = 605 time =  35235 queue_length = 1
# End_service caseid = 605 time =  35443 queue_length = 0
# Customer joins queue caseid = 606 time =  35548 queue_length = 1
# NEXT ARRIVAL TIME:  35593
# Begin_service caseid = 606 time =  35548 queue_length = 1
# Customer joins queue caseid = 607 time =  35593 queue_length = 1
# NEXT ARRIVAL TIME:  35650
# Begin_service caseid = 607 time =  35593 queue_length = 1
# End_service caseid = 606 time =  35608 queue_length = 0
# Customer joins queue caseid = 608 time =  35650 queue_length = 1
# NEXT ARRIVAL TIME:  35684
# Begin_service caseid = 608 time =  35650 queue_length = 1
# End_service caseid = 607 time =  35653 queue_length = 0
# Customer joins queue caseid = 609 time =  35684 queue_length = 1
# NEXT ARRIVAL TIME:  35735
# Begin_service caseid = 609 time =  35684 queue_length = 1
# Customer joins queue caseid = 610 time =  35735 queue_length = 1
# NEXT ARRIVAL TIME:  35801
# Begin_service caseid = 610 time =  35735 queue_length = 1
# End_service caseid = 609 time =  35744 queue_length = 0
# Customer joins queue caseid = 611 time =  35801 queue_length = 1
# NEXT ARRIVAL TIME:  35955
# Begin_service caseid = 611 time =  35801 queue_length = 1
# End_service caseid = 611 time =  35861 queue_length = 0
# End_service caseid = 608 time =  35950 queue_length = 0
# Customer joins queue caseid = 612 time =  35955 queue_length = 1
# NEXT ARRIVAL TIME:  35970
# Begin_service caseid = 612 time =  35955 queue_length = 1
# Customer joins queue caseid = 613 time =  35970 queue_length = 1
# NEXT ARRIVAL TIME:  36034
# Begin_service caseid = 613 time =  35970 queue_length = 1

# %%
# encapsulating the simulation to be run in a function
# allows the simulation to be run multiple times
# with different parameter settings
# without having to re-run the entire program


def run_simulation(simulation_hours, baristas, minimum_service_time, mean_service_time,\
                    maximum_service_time, mean_inter_arrival_time, balking_queue_length, \
                        obtain_reproducible_results):

    # set length of simulation in simulation time units (assume seconds)
    # run for similation_hours of simulation time
    fixed_simulation_time =  simulation_hours*60*60   

    parameter_string_list = [str(simulation_hours),'hours',
                  str(baristas),str(minimum_service_time),
                  str(mean_service_time),str(maximum_service_time),
                  str(mean_inter_arrival_time),str(balking_queue_length)]
    separator = '-'        
    simulation_file_identifier = separator.join(parameter_string_list)

    # initialize queue length
    # queue_length = 0

    '''
    ---------------------------------------
    set up the SimPy simulation environment
    and run the simulation with monitoring
    ---------------------------------------
    '''
    if obtain_reproducible_results: 
        np.random.seed(9999)

    # set up simulation trace monitoring for the simulation
    data = []
    # bind *data* as first argument to monitor()
    this_trace_monitor = partial(trace_monitor, data)

    env = simpy.Environment()
    trace(env, this_trace_monitor)

    env.process(test_process(env))

    # implement FIFO queue to hold caseid values
    caseid_queue = queue.Queue()

    # set up limited server/baristas resource
    available_baristas = simpy.Resource(env, capacity = baristas)
    caseid = -1  # dummy caseid for beginning of simulation
    # dummy caseid values will be omitted from the event_log
    # prior to analyzing simulation results

    # beginning record in event_log list of tuples of the form
    # form of the event_log tuple item: (caseid, time, activity)
    event_log = [(caseid,0,'null_start_simulation')]
    # event_monitor = partial(event_monitor, event_log)
    env.process(event_log_append(env, caseid, env.now, 'start_simulation', event_log))

    # call customer arrival process/generator to begin the simulation
    env.process(arrival(env,available_baristas, caseid_queue, event_log))  

    env.run(until = fixed_simulation_time)  # start simulation with monitoring and fixed end-time

    return simulation_file_identifier,event_log

# %%
# prepare to run 100 simulations with different random seeds
# and save the event logs to files

for i in range(1):
    simulation_file_identifier,event_log = run_simulation(simulation_hours, baristas, minimum_service_time, mean_service_time,\
                    maximum_service_time, mean_inter_arrival_time, balking_queue_length, \
                        obtain_reproducible_results=0)
    
    # create folder for simulation output files
    # folder name is: 'simulation-event-log-' + simulation_file_identifier

    folder_name = 'simulation-event-log-' + simulation_file_identifier
    if not os.path.exists(folder_name):
        os.makedirs(folder_name)

    # save the event log to a file
    # into folder_name

    event_log_df = pd.DataFrame(event_log, columns = ['caseid', 'time', 'activity'])
    event_log_df.to_csv(
        folder_name
        + '/simulation-event-log-'
        + str(i) + '.csv'
        , index = False
        )
# Out:
# NEXT ARRIVAL TIME:  113
# Customer joins queue caseid = 1 time =  113 queue_length = 1
# NEXT ARRIVAL TIME:  167
# Begin_service caseid = 1 time =  113 queue_length = 1
# Customer joins queue caseid = 2 time =  167 queue_length = 1
# NEXT ARRIVAL TIME:  256
# Begin_service caseid = 2 time =  167 queue_length = 1
# End_service caseid = 1 time =  173 queue_length = 0
# End_service caseid = 2 time =  227 queue_length = 0
# Customer joins queue caseid = 3 time =  256 queue_length = 1
# NEXT ARRIVAL TIME:  288
# Begin_service caseid = 3 time =  256 queue_length = 1
# Customer joins queue caseid = 4 time =  288 queue_length = 1
# NEXT ARRIVAL TIME:  388
# Begin_service caseid = 4 time =  288 queue_length = 1
# End_service caseid = 3 time =  322 queue_length = 0
# Customer joins queue caseid = 5 time =  388 queue_length = 1
# NEXT ARRIVAL TIME:  402
# Begin_service caseid = 5 time =  388 queue_length = 1
# Customer joins queue caseid = 6 time =  402 queue_length = 1
# NEXT ARRIVAL TIME:  448
# Begin_service caseid = 6 time =  402 queue_length = 1
# End_service caseid = 5 time =  448 queue_length = 0
# Customer joins queue caseid = 7 time =  448 queue_length = 1
# NEXT ARRIVAL TIME:  497
# Begin_service caseid = 7 time =  448 queue_length = 1
# Customer joins queue caseid = 8 time =  497 queue_length = 1
# NEXT ARRIVAL TIME:  651
# End_service caseid = 7 time =  508 queue_length = 1
# Begin_service caseid = 8 time =  508 queue_length = 1
# End_service caseid = 4 time =  588 queue_length = 0
# End_service caseid = 8 time =  608 queue_length = 0
# Customer joins queue caseid = 9 time =  651 queue_length = 1
# NEXT ARRIVAL TIME:  706
# Begin_service caseid = 9 time =  651 queue_length = 1
# End_service caseid = 6 time =  702 queue_length = 0
# Customer joins queue caseid = 10 time =  706 queue_length = 1
# NEXT ARRIVAL TIME:  782
# Begin_service caseid = 10 time =  706 queue_length = 1
# End_service caseid = 9 time =  711 queue_length = 0
# Customer joins queue caseid = 11 time =  782 queue_length = 1
# NEXT ARRIVAL TIME:  797
# Begin_service caseid = 11 time =  782 queue_length = 1
# Customer joins queue caseid = 12 time =  797 queue_length = 1
# NEXT ARRIVAL TIME:  825
# Begin_service caseid = 12 time =  797 queue_length = 1
# Customer joins queue caseid = 13 time =  825 queue_length = 1
# NEXT ARRIVAL TIME:  846
# Customer joins queue caseid = 14 time =  846 queue_length = 2
# NEXT ARRIVAL TIME:  1035
# End_service caseid = 12 time =  857 queue_length = 2
# Begin_service caseid = 13 time =  857 queue_length = 2
# End_service caseid = 11 time =  899 queue_length = 1
# Begin_service caseid = 14 time =  899 queue_length = 1
# End_service caseid = 13 time =  926 queue_length = 0
# End_service caseid = 10 time =  1006 queue_length = 0
# Customer joins queue caseid = 15 time =  1035 queue_length = 1
# NEXT ARRIVAL TIME:  1118
# Begin_service caseid = 15 time =  1035 queue_length = 1
# End_service caseid = 14 time =  1039 queue_length = 0
# Customer joins queue caseid = 16 time =  1118 queue_length = 1
# NEXT ARRIVAL TIME:  1132
# Begin_service caseid = 16 time =  1118 queue_length = 1
# Customer joins queue caseid = 17 time =  1132 queue_length = 1
# NEXT ARRIVAL TIME:  1144
# Begin_service caseid = 17 time =  1132 queue_length = 1
# Customer joins queue caseid = 18 time =  1144 queue_length = 1
# NEXT ARRIVAL TIME:  1164
# Customer joins queue caseid = 19 time =  1164 queue_length = 2
# NEXT ARRIVAL TIME:  1176
# Customer joins queue caseid = 20 time =  1176 queue_length = 3
# NEXT ARRIVAL TIME:  1189
# Customer joins queue caseid = 21 time =  1189 queue_length = 4
# NEXT ARRIVAL TIME:  1309
# End_service caseid = 16 time =  1197 queue_length = 4
# Begin_service caseid = 18 time =  1197 queue_length = 4
# End_service caseid = 15 time =  1214 queue_length = 3
# Begin_service caseid = 19 time =  1214 queue_length = 3
# End_service caseid = 17 time =  1251 queue_length = 2
# Begin_service caseid = 20 time =  1251 queue_length = 2
# End_service caseid = 19 time =  1274 queue_length = 1
# Begin_service caseid = 21 time =  1274 queue_length = 1
# Customer joins queue caseid = 22 time =  1309 queue_length = 1
# NEXT ARRIVAL TIME:  1387
# End_service caseid = 20 time =  1311 queue_length = 1
# Begin_service caseid = 22 time =  1311 queue_length = 1
# End_service caseid = 18 time =  1329 queue_length = 0
# End_service caseid = 22 time =  1371 queue_length = 0
# Customer joins queue caseid = 23 time =  1387 queue_length = 1
# NEXT ARRIVAL TIME:  1393
# Begin_service caseid = 23 time =  1387 queue_length = 1
# Customer joins queue caseid = 24 time =  1393 queue_length = 1
# NEXT ARRIVAL TIME:  1531
# Begin_service caseid = 24 time =  1393 queue_length = 1
# End_service caseid = 21 time =  1415 queue_length = 0
# End_service caseid = 23 time =  1447 queue_length = 0
# Customer joins queue caseid = 25 time =  1531 queue_length = 1
# NEXT ARRIVAL TIME:  1551
# Begin_service caseid = 25 time =  1531 queue_length = 1
# Customer joins queue caseid = 26 time =  1551 queue_length = 1
# NEXT ARRIVAL TIME:  1597
# Begin_service caseid = 26 time =  1551 queue_length = 1
# Customer joins queue caseid = 27 time =  1597 queue_length = 1
# NEXT ARRIVAL TIME:  1869
# End_service caseid = 24 time =  1619 queue_length = 1
# Begin_service caseid = 27 time =  1619 queue_length = 1
# End_service caseid = 25 time =  1703 queue_length = 0
# End_service caseid = 27 time =  1758 queue_length = 0
# End_service caseid = 26 time =  1851 queue_length = 0
# Customer joins queue caseid = 28 time =  1869 queue_length = 1
# NEXT ARRIVAL TIME:  1915
# Begin_service caseid = 28 time =  1869 queue_length = 1
# Customer joins queue caseid = 29 time =  1915 queue_length = 1
# NEXT ARRIVAL TIME:  1998
# Begin_service caseid = 29 time =  1915 queue_length = 1
# End_service caseid = 28 time =  1961 queue_length = 0
# Customer joins queue caseid = 30 time =  1998 queue_length = 1
# NEXT ARRIVAL TIME:  1998
# Begin_service caseid = 30 time =  1998 queue_length = 1
# Customer joins queue caseid = 31 time =  1998 queue_length = 1
# NEXT ARRIVAL TIME:  2046
# Begin_service caseid = 31 time =  1998 queue_length = 1
# Customer joins queue caseid = 32 time =  2046 queue_length = 1
# NEXT ARRIVAL TIME:  2139
# End_service caseid = 31 time =  2058 queue_length = 1
# Begin_service caseid = 32 time =  2058 queue_length = 1
# End_service caseid = 30 time =  2075 queue_length = 0
# End_service caseid = 29 time =  2099 queue_length = 0
# Customer joins queue caseid = 33 time =  2139 queue_length = 1
# NEXT ARRIVAL TIME:  2295
# Begin_service caseid = 33 time =  2139 queue_length = 1
# End_service caseid = 33 time =  2199 queue_length = 0
# End_service caseid = 32 time =  2204 queue_length = 0
# Customer joins queue caseid = 34 time =  2295 queue_length = 1
# NEXT ARRIVAL TIME:  2314
# Begin_service caseid = 34 time =  2295 queue_length = 1
# Customer joins queue caseid = 35 time =  2314 queue_length = 1
# NEXT ARRIVAL TIME:  2320
# Begin_service caseid = 35 time =  2314 queue_length = 1
# Customer joins queue caseid = 36 time =  2320 queue_length = 1
# NEXT ARRIVAL TIME:  2388
# Begin_service caseid = 36 time =  2320 queue_length = 1
# End_service caseid = 34 time =  2355 queue_length = 0
# End_service caseid = 35 time =  2374 queue_length = 0
# Customer joins queue caseid = 37 time =  2388 queue_length = 1
# NEXT ARRIVAL TIME:  2432
# Begin_service caseid = 37 time =  2388 queue_length = 1
# Customer joins queue caseid = 38 time =  2432 queue_length = 1
# NEXT ARRIVAL TIME:  2456
# Begin_service caseid = 38 time =  2432 queue_length = 1
# End_service caseid = 37 time =  2448 queue_length = 0
# Customer joins queue caseid = 39 time =  2456 queue_length = 1
# NEXT ARRIVAL TIME:  2462
# Begin_service caseid = 39 time =  2456 queue_length = 1
# Customer joins queue caseid = 40 time =  2462 queue_length = 1
# NEXT ARRIVAL TIME:  2493
# Customer joins queue caseid = 41 time =  2493 queue_length = 2
# NEXT ARRIVAL TIME:  2507
# Customer joins queue caseid = 42 time =  2507 queue_length = 3
# NEXT ARRIVAL TIME:  2578
# End_service caseid = 39 time =  2516 queue_length = 3
# Begin_service caseid = 40 time =  2516 queue_length = 3
# End_service caseid = 36 time =  2525 queue_length = 2
# Begin_service caseid = 41 time =  2525 queue_length = 2
# End_service caseid = 38 time =  2545 queue_length = 1
# Begin_service caseid = 42 time =  2545 queue_length = 1
# Customer joins queue caseid = 43 time =  2578 queue_length = 1
# NEXT ARRIVAL TIME:  2738
# End_service caseid = 40 time =  2682 queue_length = 1
# Begin_service caseid = 43 time =  2682 queue_length = 1
# End_service caseid = 41 time =  2699 queue_length = 0
# Customer joins queue caseid = 44 time =  2738 queue_length = 1
# NEXT ARRIVAL TIME:  2748
# Begin_service caseid = 44 time =  2738 queue_length = 1
# Customer joins queue caseid = 45 time =  2748 queue_length = 1
# NEXT ARRIVAL TIME:  2751
# Customer joins queue caseid = 46 time =  2751 queue_length = 2
# NEXT ARRIVAL TIME:  2889
# End_service caseid = 43 time =  2759 queue_length = 2
# Begin_service caseid = 45 time =  2759 queue_length = 2
# End_service caseid = 44 time =  2798 queue_length = 1
# Begin_service caseid = 46 time =  2798 queue_length = 1
# End_service caseid = 42 time =  2817 queue_length = 0
# End_service caseid = 46 time =  2875 queue_length = 0
# Customer joins queue caseid = 47 time =  2889 queue_length = 1
# NEXT ARRIVAL TIME:  2956
# Begin_service caseid = 47 time =  2889 queue_length = 1
# Customer joins queue caseid = 48 time =  2956 queue_length = 1
# NEXT ARRIVAL TIME:  2967
# Begin_service caseid = 48 time =  2956 queue_length = 1
# Customer joins queue caseid = 49 time =  2967 queue_length = 1
# NEXT ARRIVAL TIME:  3023
# End_service caseid = 47 time =  2984 queue_length = 1
# Begin_service caseid = 49 time =  2984 queue_length = 1
# Customer joins queue caseid = 50 time =  3023 queue_length = 1
# NEXT ARRIVAL TIME:  3027
# Customer joins queue caseid = 51 time =  3027 queue_length = 2
# NEXT ARRIVAL TIME:  3028
# Customer joins queue caseid = 52 time =  3028 queue_length = 3
# NEXT ARRIVAL TIME:  3082
# End_service caseid = 49 time =  3044 queue_length = 3
# Begin_service caseid = 50 time =  3044 queue_length = 3
# End_service caseid = 45 time =  3059 queue_length = 2
# Begin_service caseid = 51 time =  3059 queue_length = 2
# Customer joins queue caseid = 53 time =  3082 queue_length = 2
# NEXT ARRIVAL TIME:  3204
# End_service caseid = 48 time =  3100 queue_length = 2
# Begin_service caseid = 52 time =  3100 queue_length = 2
# End_service caseid = 52 time =  3173 queue_length = 1
# Begin_service caseid = 53 time =  3173 queue_length = 1
# End_service caseid = 50 time =  3174 queue_length = 0
# Customer joins queue caseid = 54 time =  3204 queue_length = 1
# NEXT ARRIVAL TIME:  3225
# Begin_service caseid = 54 time =  3204 queue_length = 1
# Customer joins queue caseid = 55 time =  3225 queue_length = 1
# NEXT ARRIVAL TIME:  3234
# End_service caseid = 53 time =  3233 queue_length = 1
# Begin_service caseid = 55 time =  3233 queue_length = 1
# End_service caseid = 51 time =  3234 queue_length = 0
# Customer joins queue caseid = 56 time =  3234 queue_length = 1
# NEXT ARRIVAL TIME:  3294
# Begin_service caseid = 56 time =  3234 queue_length = 1
# End_service caseid = 54 time =  3264 queue_length = 0
# End_service caseid = 55 time =  3293 queue_length = 0
# Customer joins queue caseid = 57 time =  3294 queue_length = 1
# NEXT ARRIVAL TIME:  3306
# Begin_service caseid = 57 time =  3294 queue_length = 1
# Customer joins queue caseid = 58 time =  3306 queue_length = 1
# NEXT ARRIVAL TIME:  3323
# Begin_service caseid = 58 time =  3306 queue_length = 1
# Customer joins queue caseid = 59 time =  3323 queue_length = 1
# NEXT ARRIVAL TIME:  3338
# End_service caseid = 56 time =  3326 queue_length = 1
# Begin_service caseid = 59 time =  3326 queue_length = 1
# Customer joins queue caseid = 60 time =  3338 queue_length = 1
# NEXT ARRIVAL TIME:  3732
# End_service caseid = 58 time =  3366 queue_length = 1
# Begin_service caseid = 60 time =  3366 queue_length = 1
# End_service caseid = 59 time =  3402 queue_length = 0
# End_service caseid = 57 time =  3567 queue_length = 0
# End_service caseid = 60 time =  3576 queue_length = 0
# Customer joins queue caseid = 61 time =  3732 queue_length = 1
# NEXT ARRIVAL TIME:  3899
# Begin_service caseid = 61 time =  3732 queue_length = 1
# Customer joins queue caseid = 62 time =  3899 queue_length = 1
# NEXT ARRIVAL TIME:  3915
# Begin_service caseid = 62 time =  3899 queue_length = 1
# Customer joins queue caseid = 63 time =  3915 queue_length = 1
# NEXT ARRIVAL TIME:  4018
# Begin_service caseid = 63 time =  3915 queue_length = 1
# End_service caseid = 63 time =  3975 queue_length = 0
# Customer joins queue caseid = 64 time =  4018 queue_length = 1
# NEXT ARRIVAL TIME:  4027
# Begin_service caseid = 64 time =  4018 queue_length = 1
# Customer joins queue caseid = 65 time =  4027 queue_length = 1
# NEXT ARRIVAL TIME:  4231
# End_service caseid = 61 time =  4029 queue_length = 1
# Begin_service caseid = 65 time =  4029 queue_length = 1
# End_service caseid = 64 time =  4078 queue_length = 0
# End_service caseid = 62 time =  4081 queue_length = 0
# End_service caseid = 65 time =  4164 queue_length = 0
# Customer joins queue caseid = 66 time =  4231 queue_length = 1
# NEXT ARRIVAL TIME:  4268
# Begin_service caseid = 66 time =  4231 queue_length = 1
# Customer joins queue caseid = 67 time =  4268 queue_length = 1
# NEXT ARRIVAL TIME:  4311
# Begin_service caseid = 67 time =  4268 queue_length = 1
# End_service caseid = 66 time =  4291 queue_length = 0
# Customer joins queue caseid = 68 time =  4311 queue_length = 1
# NEXT ARRIVAL TIME:  4570
# Begin_service caseid = 68 time =  4311 queue_length = 1
# End_service caseid = 68 time =  4371 queue_length = 0
# End_service caseid = 67 time =  4535 queue_length = 0
# Customer joins queue caseid = 69 time =  4570 queue_length = 1
# NEXT ARRIVAL TIME:  4589
# Begin_service caseid = 69 time =  4570 queue_length = 1
# Customer joins queue caseid = 70 time =  4589 queue_length = 1
# NEXT ARRIVAL TIME:  4648
# Begin_service caseid = 70 time =  4589 queue_length = 1
# End_service caseid = 69 time =  4641 queue_length = 0
# Customer joins queue caseid = 71 time =  4648 queue_length = 1
# NEXT ARRIVAL TIME:  4723
# Begin_service caseid = 71 time =  4648 queue_length = 1
# Customer joins queue caseid = 72 time =  4723 queue_length = 1
# NEXT ARRIVAL TIME:  4930
# Begin_service caseid = 72 time =  4723 queue_length = 1
# End_service caseid = 72 time =  4783 queue_length = 0
# End_service caseid = 70 time =  4792 queue_length = 0
# Customer joins queue caseid = 73 time =  4930 queue_length = 1
# NEXT ARRIVAL TIME:  4994
# Begin_service caseid = 73 time =  4930 queue_length = 1
# End_service caseid = 71 time =  4932 queue_length = 0
# End_service caseid = 73 time =  4990 queue_length = 0
# Customer joins queue caseid = 74 time =  4994 queue_length = 1
# NEXT ARRIVAL TIME:  5102
# Begin_service caseid = 74 time =  4994 queue_length = 1
# Customer joins queue caseid = 75 time =  5102 queue_length = 1
# NEXT ARRIVAL TIME:  5195
# Begin_service caseid = 75 time =  5102 queue_length = 1
# End_service caseid = 74 time =  5183 queue_length = 0
# Customer joins queue caseid = 76 time =  5195 queue_length = 1
# NEXT ARRIVAL TIME:  5209
# Begin_service caseid = 76 time =  5195 queue_length = 1
# Customer joins queue caseid = 77 time =  5209 queue_length = 1
# NEXT ARRIVAL TIME:  5212
# Begin_service caseid = 77 time =  5209 queue_length = 1
# Customer joins queue caseid = 78 time =  5212 queue_length = 1
# NEXT ARRIVAL TIME:  5219
# Customer joins queue caseid = 79 time =  5219 queue_length = 2
# NEXT ARRIVAL TIME:  5354
# End_service caseid = 75 time =  5237 queue_length = 2
# Begin_service caseid = 78 time =  5237 queue_length = 2
# End_service caseid = 76 time =  5255 queue_length = 1
# Begin_service caseid = 79 time =  5255 queue_length = 1
# End_service caseid = 77 time =  5269 queue_length = 0
# End_service caseid = 79 time =  5315 queue_length = 0
# End_service caseid = 78 time =  5340 queue_length = 0
# Customer joins queue caseid = 80 time =  5354 queue_length = 1
# NEXT ARRIVAL TIME:  5419
# Begin_service caseid = 80 time =  5354 queue_length = 1
# Customer joins queue caseid = 81 time =  5419 queue_length = 1
# NEXT ARRIVAL TIME:  5493
# Begin_service caseid = 81 time =  5419 queue_length = 1
# End_service caseid = 80 time =  5460 queue_length = 0
# End_service caseid = 81 time =  5479 queue_length = 0
# Customer joins queue caseid = 82 time =  5493 queue_length = 1
# NEXT ARRIVAL TIME:  5539
# Begin_service caseid = 82 time =  5493 queue_length = 1
# Customer joins queue caseid = 83 time =  5539 queue_length = 1
# NEXT ARRIVAL TIME:  5622
# Begin_service caseid = 83 time =  5539 queue_length = 1
# End_service caseid = 82 time =  5553 queue_length = 0
# End_service caseid = 83 time =  5608 queue_length = 0
# Customer joins queue caseid = 84 time =  5622 queue_length = 1
# NEXT ARRIVAL TIME:  5651
# Begin_service caseid = 84 time =  5622 queue_length = 1
# Customer joins queue caseid = 85 time =  5651 queue_length = 1
# NEXT ARRIVAL TIME:  5747
# Begin_service caseid = 85 time =  5651 queue_length = 1
# End_service caseid = 84 time =  5682 queue_length = 0
# Customer joins queue caseid = 86 time =  5747 queue_length = 1
# NEXT ARRIVAL TIME:  5760
# Begin_service caseid = 86 time =  5747 queue_length = 1
# Customer joins queue caseid = 87 time =  5760 queue_length = 1
# NEXT ARRIVAL TIME:  5777
# Begin_service caseid = 87 time =  5760 queue_length = 1
# Customer joins queue caseid = 88 time =  5777 queue_length = 1
# NEXT ARRIVAL TIME:  5881
# End_service caseid = 86 time =  5809 queue_length = 1
# Begin_service caseid = 88 time =  5809 queue_length = 1
# End_service caseid = 85 time =  5862 queue_length = 0
# End_service caseid = 88 time =  5869 queue_length = 0
# Customer joins queue caseid = 89 time =  5881 queue_length = 1
# NEXT ARRIVAL TIME:  5901
# Begin_service caseid = 89 time =  5881 queue_length = 1
# End_service caseid = 87 time =  5894 queue_length = 0
# Customer joins queue caseid = 90 time =  5901 queue_length = 1
# NEXT ARRIVAL TIME:  6011
# Begin_service caseid = 90 time =  5901 queue_length = 1
# End_service caseid = 89 time =  5941 queue_length = 0
# Customer joins queue caseid = 91 time =  6011 queue_length = 1
# NEXT ARRIVAL TIME:  6078
# Begin_service caseid = 91 time =  6011 queue_length = 1
# End_service caseid = 90 time =  6076 queue_length = 0
# Customer joins queue caseid = 92 time =  6078 queue_length = 1
# NEXT ARRIVAL TIME:  6089
# Begin_service caseid = 92 time =  6078 queue_length = 1
# Customer joins queue caseid = 93 time =  6089 queue_length = 1
# NEXT ARRIVAL TIME:  6093
# Begin_service caseid = 93 time =  6089 queue_length = 1
# Customer joins queue caseid = 94 time =  6093 queue_length = 1
# NEXT ARRIVAL TIME:  6128
# End_service caseid = 91 time =  6128 queue_length = 1
# Customer joins queue caseid = 95 time =  6128 queue_length = 2
# NEXT ARRIVAL TIME:  6197
# Begin_service caseid = 94 time =  6128 queue_length = 2
# End_service caseid = 92 time =  6138 queue_length = 1
# Begin_service caseid = 95 time =  6138 queue_length = 1
# End_service caseid = 93 time =  6184 queue_length = 0
# Customer joins queue caseid = 96 time =  6197 queue_length = 1
# NEXT ARRIVAL TIME:  6238
# Begin_service caseid = 96 time =  6197 queue_length = 1
# End_service caseid = 95 time =  6198 queue_length = 0
# Customer joins queue caseid = 97 time =  6238 queue_length = 1
# NEXT ARRIVAL TIME:  6250
# Begin_service caseid = 97 time =  6238 queue_length = 1
# Customer joins queue caseid = 98 time =  6250 queue_length = 1
# NEXT ARRIVAL TIME:  6257
# End_service caseid = 96 time =  6257 queue_length = 1
# Customer joins queue caseid = 99 time =  6257 queue_length = 2
# NEXT ARRIVAL TIME:  6361
# Begin_service caseid = 98 time =  6257 queue_length = 2
# End_service caseid = 97 time =  6319 queue_length = 1
# Begin_service caseid = 99 time =  6319 queue_length = 1
# Customer joins queue caseid = 100 time =  6361 queue_length = 1
# NEXT ARRIVAL TIME:  6430
# End_service caseid = 99 time =  6379 queue_length = 1
# Begin_service caseid = 100 time =  6379 queue_length = 1
# End_service caseid = 94 time =  6428 queue_length = 0
# Customer joins queue caseid = 101 time =  6430 queue_length = 1
# NEXT ARRIVAL TIME:  6509
# Begin_service caseid = 101 time =  6430 queue_length = 1
# End_service caseid = 98 time =  6468 queue_length = 0
# End_service caseid = 100 time =  6489 queue_length = 0
# End_service caseid = 101 time =  6501 queue_length = 0
# Customer joins queue caseid = 102 time =  6509 queue_length = 1
# NEXT ARRIVAL TIME:  6591
# Begin_service caseid = 102 time =  6509 queue_length = 1
# End_service caseid = 102 time =  6569 queue_length = 0
# Customer joins queue caseid = 103 time =  6591 queue_length = 1
# NEXT ARRIVAL TIME:  6662
# Begin_service caseid = 103 time =  6591 queue_length = 1
# End_service caseid = 103 time =  6651 queue_length = 0
# Customer joins queue caseid = 104 time =  6662 queue_length = 1
# NEXT ARRIVAL TIME:  6673
# Begin_service caseid = 104 time =  6662 queue_length = 1
# Customer joins queue caseid = 105 time =  6673 queue_length = 1
# NEXT ARRIVAL TIME:  6761
# Begin_service caseid = 105 time =  6673 queue_length = 1
# End_service caseid = 104 time =  6722 queue_length = 0
# End_service caseid = 105 time =  6733 queue_length = 0
# Customer joins queue caseid = 106 time =  6761 queue_length = 1
# NEXT ARRIVAL TIME:  6878
# Begin_service caseid = 106 time =  6761 queue_length = 1
# End_service caseid = 106 time =  6874 queue_length = 0
# Customer joins queue caseid = 107 time =  6878 queue_length = 1
# NEXT ARRIVAL TIME:  6989
# Begin_service caseid = 107 time =  6878 queue_length = 1
# Customer joins queue caseid = 108 time =  6989 queue_length = 1
# NEXT ARRIVAL TIME:  7017
# Begin_service caseid = 108 time =  6989 queue_length = 1
# Customer joins queue caseid = 109 time =  7017 queue_length = 1
# NEXT ARRIVAL TIME:  7062
# Begin_service caseid = 109 time =  7017 queue_length = 1
# End_service caseid = 108 time =  7049 queue_length = 0
# Customer joins queue caseid = 110 time =  7062 queue_length = 1
# NEXT ARRIVAL TIME:  7252
# Begin_service caseid = 110 time =  7062 queue_length = 1
# End_service caseid = 110 time =  7122 queue_length = 0
# End_service caseid = 107 time =  7158 queue_length = 0
# Customer joins queue caseid = 111 time =  7252 queue_length = 1
# NEXT ARRIVAL TIME:  7306
# Begin_service caseid = 111 time =  7252 queue_length = 1
# Customer joins queue caseid = 112 time =  7306 queue_length = 1
# NEXT ARRIVAL TIME:  7360
# Begin_service caseid = 112 time =  7306 queue_length = 1
# End_service caseid = 109 time =  7311 queue_length = 0
# End_service caseid = 111 time =  7312 queue_length = 0
# Customer joins queue caseid = 113 time =  7360 queue_length = 1
# NEXT ARRIVAL TIME:  7374
# Begin_service caseid = 113 time =  7360 queue_length = 1
# End_service caseid = 112 time =  7371 queue_length = 0
# Customer joins queue caseid = 114 time =  7374 queue_length = 1
# NEXT ARRIVAL TIME:  7397
# Begin_service caseid = 114 time =  7374 queue_length = 1
# Customer joins queue caseid = 115 time =  7397 queue_length = 1
# NEXT ARRIVAL TIME:  7438
# Begin_service caseid = 115 time =  7397 queue_length = 1
# End_service caseid = 114 time =  7434 queue_length = 0
# Customer joins queue caseid = 116 time =  7438 queue_length = 1
# NEXT ARRIVAL TIME:  7452
# Begin_service caseid = 116 time =  7438 queue_length = 1
# End_service caseid = 113 time =  7445 queue_length = 0
# Customer joins queue caseid = 117 time =  7452 queue_length = 1
# NEXT ARRIVAL TIME:  7528
# Begin_service caseid = 117 time =  7452 queue_length = 1
# End_service caseid = 116 time =  7498 queue_length = 0
# End_service caseid = 117 time =  7512 queue_length = 0
# End_service caseid = 115 time =  7527 queue_length = 0
# Customer joins queue caseid = 118 time =  7528 queue_length = 1
# NEXT ARRIVAL TIME:  7670
# Begin_service caseid = 118 time =  7528 queue_length = 1
# Customer joins queue caseid = 119 time =  7670 queue_length = 1
# NEXT ARRIVAL TIME:  7906
# Begin_service caseid = 119 time =  7670 queue_length = 1
# End_service caseid = 119 time =  7730 queue_length = 0
# End_service caseid = 118 time =  7738 queue_length = 0
# Customer joins queue caseid = 120 time =  7906 queue_length = 1
# NEXT ARRIVAL TIME:  7937
# Begin_service caseid = 120 time =  7906 queue_length = 1
# Customer joins queue caseid = 121 time =  7937 queue_length = 1
# NEXT ARRIVAL TIME:  8039
# Begin_service caseid = 121 time =  7937 queue_length = 1
# End_service caseid = 120 time =  7966 queue_length = 0
# End_service caseid = 121 time =  7997 queue_length = 0
# Customer joins queue caseid = 122 time =  8039 queue_length = 1
# NEXT ARRIVAL TIME:  8299
# Begin_service caseid = 122 time =  8039 queue_length = 1
# Customer joins queue caseid = 123 time =  8299 queue_length = 1
# NEXT ARRIVAL TIME:  8408
# Begin_service caseid = 123 time =  8299 queue_length = 1
# End_service caseid = 122 time =  8339 queue_length = 0
# End_service caseid = 123 time =  8385 queue_length = 0
# Customer joins queue caseid = 124 time =  8408 queue_length = 1
# NEXT ARRIVAL TIME:  8425
# Begin_service caseid = 124 time =  8408 queue_length = 1
# Customer joins queue caseid = 125 time =  8425 queue_length = 1
# NEXT ARRIVAL TIME:  8435
# Begin_service caseid = 125 time =  8425 queue_length = 1
# Customer joins queue caseid = 126 time =  8435 queue_length = 1
# NEXT ARRIVAL TIME:  8543
# Begin_service caseid = 126 time =  8435 queue_length = 1
# End_service caseid = 124 time =  8482 queue_length = 0
# End_service caseid = 126 time =  8495 queue_length = 0
# Customer joins queue caseid = 127 time =  8543 queue_length = 1
# NEXT ARRIVAL TIME:  8692
# Begin_service caseid = 127 time =  8543 queue_length = 1
# End_service caseid = 125 time =  8557 queue_length = 0
# Customer joins queue caseid = 128 time =  8692 queue_length = 1
# NEXT ARRIVAL TIME:  8824
# Begin_service caseid = 128 time =  8692 queue_length = 1
# End_service caseid = 127 time =  8694 queue_length = 0
# End_service caseid = 128 time =  8752 queue_length = 0
# Customer joins queue caseid = 129 time =  8824 queue_length = 1
# NEXT ARRIVAL TIME:  8868
# Begin_service caseid = 129 time =  8824 queue_length = 1
# Customer joins queue caseid = 130 time =  8868 queue_length = 1
# NEXT ARRIVAL TIME:  8870
# Begin_service caseid = 130 time =  8868 queue_length = 1
# Customer joins queue caseid = 131 time =  8870 queue_length = 1
# NEXT ARRIVAL TIME:  8882
# Begin_service caseid = 131 time =  8870 queue_length = 1
# Customer joins queue caseid = 132 time =  8882 queue_length = 1
# NEXT ARRIVAL TIME:  8935
# End_service caseid = 129 time =  8885 queue_length = 1
# Begin_service caseid = 132 time =  8885 queue_length = 1
# Customer joins queue caseid = 133 time =  8935 queue_length = 1
# NEXT ARRIVAL TIME:  9027
# End_service caseid = 131 time =  8976 queue_length = 1
# Begin_service caseid = 133 time =  8976 queue_length = 1
# End_service caseid = 132 time =  9004 queue_length = 0
# Customer joins queue caseid = 134 time =  9027 queue_length = 1
# NEXT ARRIVAL TIME:  9127
# Begin_service caseid = 134 time =  9027 queue_length = 1
# End_service caseid = 133 time =  9036 queue_length = 0
# Customer joins queue caseid = 135 time =  9127 queue_length = 1
# NEXT ARRIVAL TIME:  9159
# Begin_service caseid = 135 time =  9127 queue_length = 1
# End_service caseid = 134 time =  9133 queue_length = 0
# Customer joins queue caseid = 136 time =  9159 queue_length = 1
# NEXT ARRIVAL TIME:  9206
# Begin_service caseid = 136 time =  9159 queue_length = 1
# End_service caseid = 130 time =  9168 queue_length = 0
# End_service caseid = 135 time =  9187 queue_length = 0
# Customer joins queue caseid = 137 time =  9206 queue_length = 1
# NEXT ARRIVAL TIME:  9221
# Begin_service caseid = 137 time =  9206 queue_length = 1
# End_service caseid = 136 time =  9219 queue_length = 0
# Customer joins queue caseid = 138 time =  9221 queue_length = 1
# NEXT ARRIVAL TIME:  9340
# Begin_service caseid = 138 time =  9221 queue_length = 1
# End_service caseid = 137 time =  9269 queue_length = 0
# Customer joins queue caseid = 139 time =  9340 queue_length = 1
# NEXT ARRIVAL TIME:  9350
# Begin_service caseid = 139 time =  9340 queue_length = 1
# End_service caseid = 138 time =  9347 queue_length = 0
# Customer joins queue caseid = 140 time =  9350 queue_length = 1
# NEXT ARRIVAL TIME:  9389
# Begin_service caseid = 140 time =  9350 queue_length = 1
# Customer joins queue caseid = 141 time =  9389 queue_length = 1
# NEXT ARRIVAL TIME:  9464
# Begin_service caseid = 141 time =  9389 queue_length = 1
# End_service caseid = 139 time =  9400 queue_length = 0
# End_service caseid = 140 time =  9447 queue_length = 0
# End_service caseid = 141 time =  9449 queue_length = 0
# Customer joins queue caseid = 142 time =  9464 queue_length = 1
# NEXT ARRIVAL TIME:  9610
# Begin_service caseid = 142 time =  9464 queue_length = 1
# End_service caseid = 142 time =  9589 queue_length = 0
# Customer joins queue caseid = 143 time =  9610 queue_length = 1
# NEXT ARRIVAL TIME:  9671
# Begin_service caseid = 143 time =  9610 queue_length = 1
# Customer joins queue caseid = 144 time =  9671 queue_length = 1
# NEXT ARRIVAL TIME:  9780
# Begin_service caseid = 144 time =  9671 queue_length = 1
# End_service caseid = 143 time =  9715 queue_length = 0
# End_service caseid = 144 time =  9779 queue_length = 0
# Customer joins queue caseid = 145 time =  9780 queue_length = 1
# NEXT ARRIVAL TIME:  9875
# Begin_service caseid = 145 time =  9780 queue_length = 1
# Customer joins queue caseid = 146 time =  9875 queue_length = 1
# NEXT ARRIVAL TIME:  10202
# Begin_service caseid = 146 time =  9875 queue_length = 1
# End_service caseid = 145 time =  9919 queue_length = 0
# End_service caseid = 146 time =  9982 queue_length = 0
# Customer joins queue caseid = 147 time =  10202 queue_length = 1
# NEXT ARRIVAL TIME:  10385
# Begin_service caseid = 147 time =  10202 queue_length = 1
# End_service caseid = 147 time =  10322 queue_length = 0
# Customer joins queue caseid = 148 time =  10385 queue_length = 1
# NEXT ARRIVAL TIME:  10386
# Begin_service caseid = 148 time =  10385 queue_length = 1
# Customer joins queue caseid = 149 time =  10386 queue_length = 1
# NEXT ARRIVAL TIME:  10524
# Begin_service caseid = 149 time =  10386 queue_length = 1
# Customer joins queue caseid = 150 time =  10524 queue_length = 1
# NEXT ARRIVAL TIME:  10591
# Begin_service caseid = 150 time =  10524 queue_length = 1
# Customer joins queue caseid = 151 time =  10591 queue_length = 1
# NEXT ARRIVAL TIME:  10685
# End_service caseid = 148 time =  10605 queue_length = 1
# Begin_service caseid = 151 time =  10605 queue_length = 1
# End_service caseid = 150 time =  10653 queue_length = 0
# End_service caseid = 149 time =  10662 queue_length = 0
# Customer joins queue caseid = 152 time =  10685 queue_length = 1
# NEXT ARRIVAL TIME:  10685
# Begin_service caseid = 152 time =  10685 queue_length = 1
# Customer joins queue caseid = 153 time =  10685 queue_length = 1
# NEXT ARRIVAL TIME:  10808
# Begin_service caseid = 153 time =  10685 queue_length = 1
# Customer joins queue caseid = 154 time =  10808 queue_length = 1
# NEXT ARRIVAL TIME:  10875
# End_service caseid = 151 time =  10846 queue_length = 1
# Begin_service caseid = 154 time =  10846 queue_length = 1
# Customer joins queue caseid = 155 time =  10875 queue_length = 1
# NEXT ARRIVAL TIME:  10918
# End_service caseid = 152 time =  10887 queue_length = 1
# Begin_service caseid = 155 time =  10887 queue_length = 1
# End_service caseid = 154 time =  10906 queue_length = 0
# Customer joins queue caseid = 156 time =  10918 queue_length = 1
# NEXT ARRIVAL TIME:  10979
# Begin_service caseid = 156 time =  10918 queue_length = 1
# Customer joins queue caseid = 157 time =  10979 queue_length = 1
# NEXT ARRIVAL TIME:  11085
# End_service caseid = 153 time =  10985 queue_length = 1
# Begin_service caseid = 157 time =  10985 queue_length = 1
# End_service caseid = 156 time =  11023 queue_length = 0
# End_service caseid = 157 time =  11045 queue_length = 0
# Customer joins queue caseid = 158 time =  11085 queue_length = 1
# NEXT ARRIVAL TIME:  11101
# Begin_service caseid = 158 time =  11085 queue_length = 1
# Customer joins queue caseid = 159 time =  11101 queue_length = 1
# NEXT ARRIVAL TIME:  11101
# Begin_service caseid = 159 time =  11101 queue_length = 1
# Customer joins queue caseid = 160 time =  11101 queue_length = 1
# NEXT ARRIVAL TIME:  11227
# End_service caseid = 159 time =  11161 queue_length = 1
# Begin_service caseid = 160 time =  11161 queue_length = 1
# End_service caseid = 155 time =  11187 queue_length = 0
# End_service caseid = 160 time =  11221 queue_length = 0
# Customer joins queue caseid = 161 time =  11227 queue_length = 1
# NEXT ARRIVAL TIME:  11472
# Begin_service caseid = 161 time =  11227 queue_length = 1
# End_service caseid = 158 time =  11302 queue_length = 0
# End_service caseid = 161 time =  11377 queue_length = 0
# Customer joins queue caseid = 162 time =  11472 queue_length = 1
# NEXT ARRIVAL TIME:  11495
# Begin_service caseid = 162 time =  11472 queue_length = 1
# Customer joins queue caseid = 163 time =  11495 queue_length = 1
# NEXT ARRIVAL TIME:  11539
# Begin_service caseid = 163 time =  11495 queue_length = 1
# Customer joins queue caseid = 164 time =  11539 queue_length = 1
# NEXT ARRIVAL TIME:  11631
# Begin_service caseid = 164 time =  11539 queue_length = 1
# End_service caseid = 164 time =  11625 queue_length = 0
# Customer joins queue caseid = 165 time =  11631 queue_length = 1
# NEXT ARRIVAL TIME:  11684
# Begin_service caseid = 165 time =  11631 queue_length = 1
# End_service caseid = 162 time =  11634 queue_length = 0
# End_service caseid = 163 time =  11677 queue_length = 0
# Customer joins queue caseid = 166 time =  11684 queue_length = 1
# NEXT ARRIVAL TIME:  11724
# Begin_service caseid = 166 time =  11684 queue_length = 1
# Customer joins queue caseid = 167 time =  11724 queue_length = 1
# NEXT ARRIVAL TIME:  11731
# Begin_service caseid = 167 time =  11724 queue_length = 1
# Customer joins queue caseid = 168 time =  11731 queue_length = 1
# NEXT ARRIVAL TIME:  11761
# End_service caseid = 165 time =  11740 queue_length = 1
# Begin_service caseid = 168 time =  11740 queue_length = 1
# Customer joins queue caseid = 169 time =  11761 queue_length = 1
# NEXT ARRIVAL TIME:  11763
# Customer joins queue caseid = 170 time =  11763 queue_length = 2
# NEXT ARRIVAL TIME:  11823
# End_service caseid = 166 time =  11765 queue_length = 2
# Begin_service caseid = 169 time =  11765 queue_length = 2
# End_service caseid = 167 time =  11784 queue_length = 1
# Begin_service caseid = 170 time =  11784 queue_length = 1
# End_service caseid = 168 time =  11808 queue_length = 0
# Customer joins queue caseid = 171 time =  11823 queue_length = 1
# NEXT ARRIVAL TIME:  11850
# Begin_service caseid = 171 time =  11823 queue_length = 1
# End_service caseid = 170 time =  11846 queue_length = 0
# Customer joins queue caseid = 172 time =  11850 queue_length = 1
# NEXT ARRIVAL TIME:  11862
# Begin_service caseid = 172 time =  11850 queue_length = 1
# Customer joins queue caseid = 173 time =  11862 queue_length = 1
# NEXT ARRIVAL TIME:  11936
# End_service caseid = 169 time =  11887 queue_length = 1
# Begin_service caseid = 173 time =  11887 queue_length = 1
# Customer joins queue caseid = 174 time =  11936 queue_length = 1
# NEXT ARRIVAL TIME:  12010
# Customer joins queue caseid = 175 time =  12010 queue_length = 2
# NEXT ARRIVAL TIME:  12061
# Customer joins queue caseid = 176 time =  12061 queue_length = 3
# NEXT ARRIVAL TIME:  12072
# Customer joins queue caseid = 177 time =  12072 queue_length = 4
# NEXT ARRIVAL TIME:  12093
# End_service caseid = 172 time =  12077 queue_length = 4
# Begin_service caseid = 174 time =  12077 queue_length = 4
# Customer joins queue caseid = 178 time =  12093 queue_length = 4
# NEXT ARRIVAL TIME:  12111
# Customer joins queue caseid = 179 time =  12111 queue_length = 5
# NEXT ARRIVAL TIME:  12143
# End_service caseid = 171 time =  12123 queue_length = 5
# Begin_service caseid = 175 time =  12123 queue_length = 5
# End_service caseid = 174 time =  12137 queue_length = 4
# Begin_service caseid = 176 time =  12137 queue_length = 4
# Customer joins queue caseid = 180 time =  12143 queue_length = 4
# NEXT ARRIVAL TIME:  12177
# Customer joins queue caseid = 181 time =  12177 queue_length = 5
# NEXT ARRIVAL TIME:  12194
# End_service caseid = 175 time =  12183 queue_length = 5
# Begin_service caseid = 177 time =  12183 queue_length = 5
# End_service caseid = 173 time =  12187 queue_length = 4
# Begin_service caseid = 178 time =  12187 queue_length = 4
# Customer joins queue caseid = 182 time =  12194 queue_length = 4
# NEXT ARRIVAL TIME:  12238
# End_service caseid = 176 time =  12197 queue_length = 4
# Begin_service caseid = 179 time =  12197 queue_length = 4
# Customer joins queue caseid = 183 time =  12238 queue_length = 4
# NEXT ARRIVAL TIME:  12246
# Customer joins queue caseid = 184 time =  12246 queue_length = 5
# NEXT ARRIVAL TIME:  12355
# End_service caseid = 179 time =  12257 queue_length = 5
# Begin_service caseid = 180 time =  12257 queue_length = 5
# End_service caseid = 177 time =  12274 queue_length = 4
# End_service caseid = 178 time =  12274 queue_length = 4
# Begin_service caseid = 181 time =  12274 queue_length = 4
# Begin_service caseid = 182 time =  12274 queue_length = 3
# End_service caseid = 182 time =  12334 queue_length = 2
# Begin_service caseid = 183 time =  12334 queue_length = 2
# Customer joins queue caseid = 185 time =  12355 queue_length = 2
# NEXT ARRIVAL TIME:  12433
# End_service caseid = 180 time =  12360 queue_length = 2
# Begin_service caseid = 184 time =  12360 queue_length = 2
# End_service caseid = 183 time =  12394 queue_length = 1
# Begin_service caseid = 185 time =  12394 queue_length = 1
# End_service caseid = 184 time =  12425 queue_length = 0
# Customer joins queue caseid = 186 time =  12433 queue_length = 1
# NEXT ARRIVAL TIME:  12456
# Begin_service caseid = 186 time =  12433 queue_length = 1
# End_service caseid = 181 time =  12452 queue_length = 0
# Customer joins queue caseid = 187 time =  12456 queue_length = 1
# NEXT ARRIVAL TIME:  12469
# Begin_service caseid = 187 time =  12456 queue_length = 1
# Customer joins queue caseid = 188 time =  12469 queue_length = 1
# NEXT ARRIVAL TIME:  12476
# Customer joins queue caseid = 189 time =  12476 queue_length = 2
# NEXT ARRIVAL TIME:  12599
# End_service caseid = 186 time =  12493 queue_length = 2
# Begin_service caseid = 188 time =  12493 queue_length = 2
# End_service caseid = 188 time =  12553 queue_length = 1
# Begin_service caseid = 189 time =  12553 queue_length = 1
# Customer joins queue caseid = 190 time =  12599 queue_length = 1
# NEXT ARRIVAL TIME:  12633
# End_service caseid = 189 time =  12613 queue_length = 1
# Begin_service caseid = 190 time =  12613 queue_length = 1
# Customer joins queue caseid = 191 time =  12633 queue_length = 1
# NEXT ARRIVAL TIME:  12688
# End_service caseid = 187 time =  12676 queue_length = 1
# Begin_service caseid = 191 time =  12676 queue_length = 1
# Customer joins queue caseid = 192 time =  12688 queue_length = 1
# NEXT ARRIVAL TIME:  12750
# End_service caseid = 185 time =  12694 queue_length = 1
# Begin_service caseid = 192 time =  12694 queue_length = 1
# Customer joins queue caseid = 193 time =  12750 queue_length = 1
# NEXT ARRIVAL TIME:  12786
# End_service caseid = 192 time =  12754 queue_length = 1
# Begin_service caseid = 193 time =  12754 queue_length = 1
# End_service caseid = 191 time =  12755 queue_length = 0
# Customer joins queue caseid = 194 time =  12786 queue_length = 1
# NEXT ARRIVAL TIME:  12998
# Begin_service caseid = 194 time =  12786 queue_length = 1
# End_service caseid = 194 time =  12849 queue_length = 0
# End_service caseid = 193 time =  12873 queue_length = 0
# End_service caseid = 190 time =  12913 queue_length = 0
# Customer joins queue caseid = 195 time =  12998 queue_length = 1
# NEXT ARRIVAL TIME:  13080
# Begin_service caseid = 195 time =  12998 queue_length = 1
# Customer joins queue caseid = 196 time =  13080 queue_length = 1
# NEXT ARRIVAL TIME:  13139
# Begin_service caseid = 196 time =  13080 queue_length = 1
# Customer joins queue caseid = 197 time =  13139 queue_length = 1
# NEXT ARRIVAL TIME:  13162
# Begin_service caseid = 197 time =  13139 queue_length = 1
# Customer joins queue caseid = 198 time =  13162 queue_length = 1
# NEXT ARRIVAL TIME:  13165
# Customer joins queue caseid = 199 time =  13165 queue_length = 2
# NEXT ARRIVAL TIME:  13210
# Customer joins queue caseid = 200 time =  13210 queue_length = 3
# NEXT ARRIVAL TIME:  13237
# Customer joins queue caseid = 201 time =  13237 queue_length = 4
# NEXT ARRIVAL TIME:  13489
# End_service caseid = 196 time =  13257 queue_length = 4
# Begin_service caseid = 198 time =  13257 queue_length = 4
# End_service caseid = 197 time =  13261 queue_length = 3
# Begin_service caseid = 199 time =  13261 queue_length = 3
# End_service caseid = 195 time =  13270 queue_length = 2
# Begin_service caseid = 200 time =  13270 queue_length = 2
# End_service caseid = 200 time =  13330 queue_length = 1
# Begin_service caseid = 201 time =  13330 queue_length = 1
# End_service caseid = 199 time =  13359 queue_length = 0
# End_service caseid = 198 time =  13373 queue_length = 0
# Customer joins queue caseid = 202 time =  13489 queue_length = 1
# NEXT ARRIVAL TIME:  13557
# Begin_service caseid = 202 time =  13489 queue_length = 1
# Customer joins queue caseid = 203 time =  13557 queue_length = 1
# NEXT ARRIVAL TIME:  13573
# Begin_service caseid = 203 time =  13557 queue_length = 1
# Customer joins queue caseid = 204 time =  13573 queue_length = 1
# NEXT ARRIVAL TIME:  13692
# End_service caseid = 201 time =  13580 queue_length = 1
# Begin_service caseid = 204 time =  13580 queue_length = 1
# End_service caseid = 204 time =  13640 queue_length = 0
# End_service caseid = 202 time =  13655 queue_length = 0
# Customer joins queue caseid = 205 time =  13692 queue_length = 1
# NEXT ARRIVAL TIME:  13696
# Begin_service caseid = 205 time =  13692 queue_length = 1
# Customer joins queue caseid = 206 time =  13696 queue_length = 1
# NEXT ARRIVAL TIME:  13705
# Begin_service caseid = 206 time =  13696 queue_length = 1
# Customer joins queue caseid = 207 time =  13705 queue_length = 1
# NEXT ARRIVAL TIME:  13722
# End_service caseid = 203 time =  13713 queue_length = 1
# Begin_service caseid = 207 time =  13713 queue_length = 1
# Customer joins queue caseid = 208 time =  13722 queue_length = 1
# NEXT ARRIVAL TIME:  13823
# End_service caseid = 205 time =  13752 queue_length = 1
# Begin_service caseid = 208 time =  13752 queue_length = 1
# End_service caseid = 206 time =  13756 queue_length = 0
# End_service caseid = 208 time =  13812 queue_length = 0
# End_service caseid = 207 time =  13815 queue_length = 0
# Customer joins queue caseid = 209 time =  13823 queue_length = 1
# NEXT ARRIVAL TIME:  13827
# Begin_service caseid = 209 time =  13823 queue_length = 1
# Customer joins queue caseid = 210 time =  13827 queue_length = 1
# NEXT ARRIVAL TIME:  13905
# Begin_service caseid = 210 time =  13827 queue_length = 1
# End_service caseid = 209 time =  13883 queue_length = 0
# End_service caseid = 210 time =  13887 queue_length = 0
# Customer joins queue caseid = 211 time =  13905 queue_length = 1
# NEXT ARRIVAL TIME:  13974
# Begin_service caseid = 211 time =  13905 queue_length = 1
# Customer joins queue caseid = 212 time =  13974 queue_length = 1
# NEXT ARRIVAL TIME:  14083
# Begin_service caseid = 212 time =  13974 queue_length = 1
# End_service caseid = 211 time =  14082 queue_length = 0
# Customer joins queue caseid = 213 time =  14083 queue_length = 1
# NEXT ARRIVAL TIME:  14118
# Begin_service caseid = 213 time =  14083 queue_length = 1
# End_service caseid = 212 time =  14103 queue_length = 0
# Customer joins queue caseid = 214 time =  14118 queue_length = 1
# NEXT ARRIVAL TIME:  14144
# Begin_service caseid = 214 time =  14118 queue_length = 1
# Customer joins queue caseid = 215 time =  14144 queue_length = 1
# NEXT ARRIVAL TIME:  14287
# Begin_service caseid = 215 time =  14144 queue_length = 1
# End_service caseid = 214 time =  14178 queue_length = 0
# End_service caseid = 215 time =  14204 queue_length = 0
# Customer joins queue caseid = 216 time =  14287 queue_length = 1
# NEXT ARRIVAL TIME:  14488
# Begin_service caseid = 216 time =  14287 queue_length = 1
# End_service caseid = 213 time =  14294 queue_length = 0
# Customer joins queue caseid = 217 time =  14488 queue_length = 1
# NEXT ARRIVAL TIME:  14565
# Begin_service caseid = 217 time =  14488 queue_length = 1
# Customer joins queue caseid = 218 time =  14565 queue_length = 1
# NEXT ARRIVAL TIME:  14630
# Begin_service caseid = 218 time =  14565 queue_length = 1
# End_service caseid = 216 time =  14587 queue_length = 0
# End_service caseid = 217 time =  14612 queue_length = 0
# Customer joins queue caseid = 219 time =  14630 queue_length = 1
# NEXT ARRIVAL TIME:  14654
# Begin_service caseid = 219 time =  14630 queue_length = 1
# Customer joins queue caseid = 220 time =  14654 queue_length = 1
# NEXT ARRIVAL TIME:  14659
# Begin_service caseid = 220 time =  14654 queue_length = 1
# Customer joins queue caseid = 221 time =  14659 queue_length = 1
# NEXT ARRIVAL TIME:  14686
# Customer joins queue caseid = 222 time =  14686 queue_length = 2
# NEXT ARRIVAL TIME:  14758
# End_service caseid = 219 time =  14719 queue_length = 2
# Begin_service caseid = 221 time =  14719 queue_length = 2
# End_service caseid = 218 time =  14754 queue_length = 1
# Begin_service caseid = 222 time =  14754 queue_length = 1
# Customer joins queue caseid = 223 time =  14758 queue_length = 1
# NEXT ARRIVAL TIME:  14784
# Customer joins queue caseid = 224 time =  14784 queue_length = 2
# NEXT ARRIVAL TIME:  14804
# Customer joins queue caseid = 225 time =  14804 queue_length = 3
# NEXT ARRIVAL TIME:  14817
# End_service caseid = 222 time =  14814 queue_length = 3
# Begin_service caseid = 223 time =  14814 queue_length = 3
# Customer joins queue caseid = 226 time =  14817 queue_length = 3
# NEXT ARRIVAL TIME:  14860
# End_service caseid = 220 time =  14818 queue_length = 3
# Begin_service caseid = 224 time =  14818 queue_length = 3
# End_service caseid = 221 time =  14851 queue_length = 2
# Begin_service caseid = 225 time =  14851 queue_length = 2
# Customer joins queue caseid = 227 time =  14860 queue_length = 2
# NEXT ARRIVAL TIME:  14914
# End_service caseid = 223 time =  14874 queue_length = 2
# Begin_service caseid = 226 time =  14874 queue_length = 2
# End_service caseid = 224 time =  14878 queue_length = 1
# Begin_service caseid = 227 time =  14878 queue_length = 1
# Customer joins queue caseid = 228 time =  14914 queue_length = 1
# NEXT ARRIVAL TIME:  15067
# End_service caseid = 226 time =  14940 queue_length = 1
# Begin_service caseid = 228 time =  14940 queue_length = 1
# End_service caseid = 228 time =  15000 queue_length = 0
# End_service caseid = 225 time =  15033 queue_length = 0
# End_service caseid = 227 time =  15035 queue_length = 0
# Customer joins queue caseid = 229 time =  15067 queue_length = 1
# NEXT ARRIVAL TIME:  15091
# Begin_service caseid = 229 time =  15067 queue_length = 1
# Customer joins queue caseid = 230 time =  15091 queue_length = 1
# NEXT ARRIVAL TIME:  15167
# Begin_service caseid = 230 time =  15091 queue_length = 1
# End_service caseid = 229 time =  15127 queue_length = 0
# Customer joins queue caseid = 231 time =  15167 queue_length = 1
# NEXT ARRIVAL TIME:  15234
# Begin_service caseid = 231 time =  15167 queue_length = 1
# End_service caseid = 231 time =  15227 queue_length = 0
# Customer joins queue caseid = 232 time =  15234 queue_length = 1
# NEXT ARRIVAL TIME:  15347
# Begin_service caseid = 232 time =  15234 queue_length = 1
# End_service caseid = 232 time =  15312 queue_length = 0
# Customer joins queue caseid = 233 time =  15347 queue_length = 1
# NEXT ARRIVAL TIME:  15536
# Begin_service caseid = 233 time =  15347 queue_length = 1
# End_service caseid = 230 time =  15391 queue_length = 0
# End_service caseid = 233 time =  15407 queue_length = 0
# Customer joins queue caseid = 234 time =  15536 queue_length = 1
# NEXT ARRIVAL TIME:  15545
# Begin_service caseid = 234 time =  15536 queue_length = 1
# Customer joins queue caseid = 235 time =  15545 queue_length = 1
# NEXT ARRIVAL TIME:  15555
# Begin_service caseid = 235 time =  15545 queue_length = 1
# Customer joins queue caseid = 236 time =  15555 queue_length = 1
# NEXT ARRIVAL TIME:  15581
# Begin_service caseid = 236 time =  15555 queue_length = 1
# Customer joins queue caseid = 237 time =  15581 queue_length = 1
# NEXT ARRIVAL TIME:  15656
# End_service caseid = 235 time =  15605 queue_length = 1
# Begin_service caseid = 237 time =  15605 queue_length = 1
# End_service caseid = 236 time =  15637 queue_length = 0
# Customer joins queue caseid = 238 time =  15656 queue_length = 1
# NEXT ARRIVAL TIME:  15788
# Begin_service caseid = 238 time =  15656 queue_length = 1
# End_service caseid = 234 time =  15748 queue_length = 0
# End_service caseid = 238 time =  15754 queue_length = 0
# Customer joins queue caseid = 239 time =  15788 queue_length = 1
# NEXT ARRIVAL TIME:  15864
# Begin_service caseid = 239 time =  15788 queue_length = 1
# ...
# Begin_service caseid = 484 time =  30160 queue_length = 4
# End_service caseid = 482 time =  30162 queue_length = 3
# Begin_service caseid = 485 time =  30162 queue_length = 3
# Customer joins queue caseid = 488 time =  30183 queue_length = 3
# NEXT ARRIVAL TIME:  30235
# Customer joins queue caseid = 489 time =  30235 queue_length = 4
# NEXT ARRIVAL TIME:  30255
# Customer joins queue caseid = 490 time =  30255 queue_length = 5
# NEXT ARRIVAL TIME:  30325
# Customer joins queue caseid = 491 time =  30325 queue_length = 6
# NEXT ARRIVAL TIME:  30375
# End_service caseid = 484 time =  30335 queue_length = 6
# Begin_service caseid = 486 time =  30335 queue_length = 6
# Customer joins queue caseid = 492 time =  30375 queue_length = 6
# NEXT ARRIVAL TIME:  30503
# End_service caseid = 486 time =  30395 queue_length = 6
# Begin_service caseid = 487 time =  30395 queue_length = 6
# End_service caseid = 487 time =  30455 queue_length = 5
# Begin_service caseid = 488 time =  30455 queue_length = 5
# End_service caseid = 483 time =  30458 queue_length = 4
# Begin_service caseid = 489 time =  30458 queue_length = 4
# End_service caseid = 485 time =  30462 queue_length = 3
# Begin_service caseid = 490 time =  30462 queue_length = 3
# Customer joins queue caseid = 493 time =  30503 queue_length = 3
# NEXT ARRIVAL TIME:  30531
# End_service caseid = 489 time =  30518 queue_length = 3
# Begin_service caseid = 491 time =  30518 queue_length = 3
# End_service caseid = 490 time =  30522 queue_length = 2
# Begin_service caseid = 492 time =  30522 queue_length = 2
# Customer joins queue caseid = 494 time =  30531 queue_length = 2
# NEXT ARRIVAL TIME:  30533
# Customer joins queue caseid = 495 time =  30533 queue_length = 3
# NEXT ARRIVAL TIME:  30678
# End_service caseid = 491 time =  30578 queue_length = 3
# Begin_service caseid = 493 time =  30578 queue_length = 3
# End_service caseid = 488 time =  30590 queue_length = 2
# Begin_service caseid = 494 time =  30590 queue_length = 2
# End_service caseid = 492 time =  30647 queue_length = 1
# Begin_service caseid = 495 time =  30647 queue_length = 1
# Customer joins queue caseid = 496 time =  30678 queue_length = 1
# NEXT ARRIVAL TIME:  30708
# Customer joins queue caseid = 497 time =  30708 queue_length = 2
# NEXT ARRIVAL TIME:  30879
# End_service caseid = 494 time =  30777 queue_length = 2
# Begin_service caseid = 496 time =  30777 queue_length = 2
# End_service caseid = 493 time =  30789 queue_length = 1
# Begin_service caseid = 497 time =  30789 queue_length = 1
# End_service caseid = 495 time =  30862 queue_length = 0
# Customer joins queue caseid = 498 time =  30879 queue_length = 1
# NEXT ARRIVAL TIME:  30886
# Begin_service caseid = 498 time =  30879 queue_length = 1
# Customer joins queue caseid = 499 time =  30886 queue_length = 1
# NEXT ARRIVAL TIME:  30911
# Customer joins queue caseid = 500 time =  30911 queue_length = 2
# NEXT ARRIVAL TIME:  31063
# End_service caseid = 498 time =  30939 queue_length = 2
# Begin_service caseid = 499 time =  30939 queue_length = 2
# End_service caseid = 497 time =  30974 queue_length = 1
# Begin_service caseid = 500 time =  30974 queue_length = 1
# End_service caseid = 499 time =  30999 queue_length = 0
# End_service caseid = 500 time =  31034 queue_length = 0
# Customer joins queue caseid = 501 time =  31063 queue_length = 1
# NEXT ARRIVAL TIME:  31070
# Begin_service caseid = 501 time =  31063 queue_length = 1
# Customer joins queue caseid = 502 time =  31070 queue_length = 1
# NEXT ARRIVAL TIME:  31188
# Begin_service caseid = 502 time =  31070 queue_length = 1
# End_service caseid = 496 time =  31077 queue_length = 0
# Customer joins queue caseid = 503 time =  31188 queue_length = 1
# NEXT ARRIVAL TIME:  31195
# Begin_service caseid = 503 time =  31188 queue_length = 1
# End_service caseid = 502 time =  31193 queue_length = 0
# Customer joins queue caseid = 504 time =  31195 queue_length = 1
# NEXT ARRIVAL TIME:  31257
# Begin_service caseid = 504 time =  31195 queue_length = 1
# End_service caseid = 501 time =  31247 queue_length = 0
# Customer joins queue caseid = 505 time =  31257 queue_length = 1
# NEXT ARRIVAL TIME:  31420
# Begin_service caseid = 505 time =  31257 queue_length = 1
# End_service caseid = 503 time =  31262 queue_length = 0
# End_service caseid = 504 time =  31279 queue_length = 0
# Customer joins queue caseid = 506 time =  31420 queue_length = 1
# NEXT ARRIVAL TIME:  31590
# Begin_service caseid = 506 time =  31420 queue_length = 1
# End_service caseid = 506 time =  31480 queue_length = 0
# End_service caseid = 505 time =  31557 queue_length = 0
# Customer joins queue caseid = 507 time =  31590 queue_length = 1
# NEXT ARRIVAL TIME:  31659
# Begin_service caseid = 507 time =  31590 queue_length = 1
# End_service caseid = 507 time =  31650 queue_length = 0
# Customer joins queue caseid = 508 time =  31659 queue_length = 1
# NEXT ARRIVAL TIME:  31660
# Begin_service caseid = 508 time =  31659 queue_length = 1
# Customer joins queue caseid = 509 time =  31660 queue_length = 1
# NEXT ARRIVAL TIME:  31700
# Begin_service caseid = 509 time =  31660 queue_length = 1
# Customer joins queue caseid = 510 time =  31700 queue_length = 1
# NEXT ARRIVAL TIME:  31824
# Begin_service caseid = 510 time =  31700 queue_length = 1
# End_service caseid = 508 time =  31719 queue_length = 0
# End_service caseid = 509 time =  31720 queue_length = 0
# End_service caseid = 510 time =  31774 queue_length = 0
# Customer joins queue caseid = 511 time =  31824 queue_length = 1
# NEXT ARRIVAL TIME:  31874
# Begin_service caseid = 511 time =  31824 queue_length = 1
# Customer joins queue caseid = 512 time =  31874 queue_length = 1
# NEXT ARRIVAL TIME:  31959
# Begin_service caseid = 512 time =  31874 queue_length = 1
# End_service caseid = 511 time =  31884 queue_length = 0
# Customer joins queue caseid = 513 time =  31959 queue_length = 1
# NEXT ARRIVAL TIME:  31978
# Begin_service caseid = 513 time =  31959 queue_length = 1
# Customer joins queue caseid = 514 time =  31978 queue_length = 1
# NEXT ARRIVAL TIME:  31989
# Begin_service caseid = 514 time =  31978 queue_length = 1
# Customer joins queue caseid = 515 time =  31989 queue_length = 1
# NEXT ARRIVAL TIME:  32057
# End_service caseid = 513 time =  32019 queue_length = 1
# Begin_service caseid = 515 time =  32019 queue_length = 1
# End_service caseid = 512 time =  32057 queue_length = 0
# Customer joins queue caseid = 516 time =  32057 queue_length = 1
# NEXT ARRIVAL TIME:  32134
# Begin_service caseid = 516 time =  32057 queue_length = 1
# Customer joins queue caseid = 517 time =  32134 queue_length = 1
# NEXT ARRIVAL TIME:  32142
# End_service caseid = 516 time =  32140 queue_length = 1
# Begin_service caseid = 517 time =  32140 queue_length = 1
# Customer joins queue caseid = 518 time =  32142 queue_length = 1
# NEXT ARRIVAL TIME:  32362
# End_service caseid = 517 time =  32200 queue_length = 1
# Begin_service caseid = 518 time =  32200 queue_length = 1
# End_service caseid = 514 time =  32217 queue_length = 0
# End_service caseid = 515 time =  32319 queue_length = 0
# End_service caseid = 518 time =  32356 queue_length = 0
# Customer joins queue caseid = 519 time =  32362 queue_length = 1
# NEXT ARRIVAL TIME:  32413
# Begin_service caseid = 519 time =  32362 queue_length = 1
# Customer joins queue caseid = 520 time =  32413 queue_length = 1
# NEXT ARRIVAL TIME:  32548
# Begin_service caseid = 520 time =  32413 queue_length = 1
# End_service caseid = 520 time =  32473 queue_length = 0
# Customer joins queue caseid = 521 time =  32548 queue_length = 1
# NEXT ARRIVAL TIME:  32709
# Begin_service caseid = 521 time =  32548 queue_length = 1
# End_service caseid = 521 time =  32608 queue_length = 0
# End_service caseid = 519 time =  32657 queue_length = 0
# Customer joins queue caseid = 522 time =  32709 queue_length = 1
# NEXT ARRIVAL TIME:  32818
# Begin_service caseid = 522 time =  32709 queue_length = 1
# End_service caseid = 522 time =  32812 queue_length = 0
# Customer joins queue caseid = 523 time =  32818 queue_length = 1
# NEXT ARRIVAL TIME:  32891
# Begin_service caseid = 523 time =  32818 queue_length = 1
# End_service caseid = 523 time =  32878 queue_length = 0
# Customer joins queue caseid = 524 time =  32891 queue_length = 1
# NEXT ARRIVAL TIME:  32982
# Begin_service caseid = 524 time =  32891 queue_length = 1
# End_service caseid = 524 time =  32951 queue_length = 0
# Customer joins queue caseid = 525 time =  32982 queue_length = 1
# NEXT ARRIVAL TIME:  33064
# Begin_service caseid = 525 time =  32982 queue_length = 1
# Customer joins queue caseid = 526 time =  33064 queue_length = 1
# NEXT ARRIVAL TIME:  33103
# Begin_service caseid = 526 time =  33064 queue_length = 1
# Customer joins queue caseid = 527 time =  33103 queue_length = 1
# NEXT ARRIVAL TIME:  33117
# Begin_service caseid = 527 time =  33103 queue_length = 1
# Customer joins queue caseid = 528 time =  33117 queue_length = 1
# NEXT ARRIVAL TIME:  33172
# End_service caseid = 526 time =  33124 queue_length = 1
# Begin_service caseid = 528 time =  33124 queue_length = 1
# Customer joins queue caseid = 529 time =  33172 queue_length = 1
# NEXT ARRIVAL TIME:  33500
# End_service caseid = 528 time =  33184 queue_length = 1
# Begin_service caseid = 529 time =  33184 queue_length = 1
# End_service caseid = 525 time =  33216 queue_length = 0
# End_service caseid = 527 time =  33234 queue_length = 0
# End_service caseid = 529 time =  33392 queue_length = 0
# Customer joins queue caseid = 530 time =  33500 queue_length = 1
# NEXT ARRIVAL TIME:  33510
# Begin_service caseid = 530 time =  33500 queue_length = 1
# Customer joins queue caseid = 531 time =  33510 queue_length = 1
# NEXT ARRIVAL TIME:  34018
# Begin_service caseid = 531 time =  33510 queue_length = 1
# End_service caseid = 530 time =  33560 queue_length = 0
# End_service caseid = 531 time =  33628 queue_length = 0
# Customer joins queue caseid = 532 time =  34018 queue_length = 1
# NEXT ARRIVAL TIME:  34048
# Begin_service caseid = 532 time =  34018 queue_length = 1
# Customer joins queue caseid = 533 time =  34048 queue_length = 1
# NEXT ARRIVAL TIME:  34171
# Begin_service caseid = 533 time =  34048 queue_length = 1
# Customer joins queue caseid = 534 time =  34171 queue_length = 1
# NEXT ARRIVAL TIME:  34271
# Begin_service caseid = 534 time =  34171 queue_length = 1
# End_service caseid = 532 time =  34193 queue_length = 0
# End_service caseid = 533 time =  34239 queue_length = 0
# Customer joins queue caseid = 535 time =  34271 queue_length = 1
# NEXT ARRIVAL TIME:  34276
# Begin_service caseid = 535 time =  34271 queue_length = 1
# End_service caseid = 534 time =  34275 queue_length = 0
# Customer joins queue caseid = 536 time =  34276 queue_length = 1
# NEXT ARRIVAL TIME:  34276
# Begin_service caseid = 536 time =  34276 queue_length = 1
# Customer joins queue caseid = 537 time =  34276 queue_length = 1
# NEXT ARRIVAL TIME:  34337
# Begin_service caseid = 537 time =  34276 queue_length = 1
# End_service caseid = 536 time =  34336 queue_length = 0
# Customer joins queue caseid = 538 time =  34337 queue_length = 1
# NEXT ARRIVAL TIME:  34424
# Begin_service caseid = 538 time =  34337 queue_length = 1
# End_service caseid = 537 time =  34372 queue_length = 0
# End_service caseid = 538 time =  34397 queue_length = 0
# Customer joins queue caseid = 539 time =  34424 queue_length = 1
# NEXT ARRIVAL TIME:  34438
# Begin_service caseid = 539 time =  34424 queue_length = 1
# End_service caseid = 535 time =  34436 queue_length = 0
# Customer joins queue caseid = 540 time =  34438 queue_length = 1
# NEXT ARRIVAL TIME:  34457
# Begin_service caseid = 540 time =  34438 queue_length = 1
# Customer joins queue caseid = 541 time =  34457 queue_length = 1
# NEXT ARRIVAL TIME:  34504
# Begin_service caseid = 541 time =  34457 queue_length = 1
# End_service caseid = 539 time =  34484 queue_length = 0
# Customer joins queue caseid = 542 time =  34504 queue_length = 1
# NEXT ARRIVAL TIME:  34540
# Begin_service caseid = 542 time =  34504 queue_length = 1
# End_service caseid = 541 time =  34517 queue_length = 0
# Customer joins queue caseid = 543 time =  34540 queue_length = 1
# NEXT ARRIVAL TIME:  34630
# Begin_service caseid = 543 time =  34540 queue_length = 1
# End_service caseid = 543 time =  34630 queue_length = 0
# Customer joins queue caseid = 544 time =  34630 queue_length = 1
# NEXT ARRIVAL TIME:  34723
# Begin_service caseid = 544 time =  34630 queue_length = 1
# End_service caseid = 544 time =  34690 queue_length = 0
# Customer joins queue caseid = 545 time =  34723 queue_length = 1
# NEXT ARRIVAL TIME:  34994
# Begin_service caseid = 545 time =  34723 queue_length = 1
# End_service caseid = 540 time =  34738 queue_length = 0
# End_service caseid = 545 time =  34783 queue_length = 0
# End_service caseid = 542 time =  34804 queue_length = 0
# Customer joins queue caseid = 546 time =  34994 queue_length = 1
# NEXT ARRIVAL TIME:  35019
# Begin_service caseid = 546 time =  34994 queue_length = 1
# Customer joins queue caseid = 547 time =  35019 queue_length = 1
# NEXT ARRIVAL TIME:  35094
# Begin_service caseid = 547 time =  35019 queue_length = 1
# End_service caseid = 546 time =  35064 queue_length = 0
# End_service caseid = 547 time =  35079 queue_length = 0
# Customer joins queue caseid = 548 time =  35094 queue_length = 1
# NEXT ARRIVAL TIME:  35247
# Begin_service caseid = 548 time =  35094 queue_length = 1
# End_service caseid = 548 time =  35219 queue_length = 0
# Customer joins queue caseid = 549 time =  35247 queue_length = 1
# NEXT ARRIVAL TIME:  35259
# Begin_service caseid = 549 time =  35247 queue_length = 1
# Customer joins queue caseid = 550 time =  35259 queue_length = 1
# NEXT ARRIVAL TIME:  35353
# Begin_service caseid = 550 time =  35259 queue_length = 1
# End_service caseid = 549 time =  35307 queue_length = 0
# Customer joins queue caseid = 551 time =  35353 queue_length = 1
# NEXT ARRIVAL TIME:  35397
# Begin_service caseid = 551 time =  35353 queue_length = 1
# End_service caseid = 550 time =  35389 queue_length = 0
# Customer joins queue caseid = 552 time =  35397 queue_length = 1
# NEXT ARRIVAL TIME:  35484
# Begin_service caseid = 552 time =  35397 queue_length = 1
# End_service caseid = 552 time =  35479 queue_length = 0
# Customer joins queue caseid = 553 time =  35484 queue_length = 1
# NEXT ARRIVAL TIME:  35527
# Begin_service caseid = 553 time =  35484 queue_length = 1
# Customer joins queue caseid = 554 time =  35527 queue_length = 1
# NEXT ARRIVAL TIME:  35552
# Begin_service caseid = 554 time =  35527 queue_length = 1
# End_service caseid = 553 time =  35544 queue_length = 0
# End_service caseid = 551 time =  35550 queue_length = 0
# Customer joins queue caseid = 555 time =  35552 queue_length = 1
# NEXT ARRIVAL TIME:  35598
# Begin_service caseid = 555 time =  35552 queue_length = 1
# End_service caseid = 554 time =  35587 queue_length = 0
# Customer joins queue caseid = 556 time =  35598 queue_length = 1
# NEXT ARRIVAL TIME:  35607
# Begin_service caseid = 556 time =  35598 queue_length = 1
# Customer joins queue caseid = 557 time =  35607 queue_length = 1
# NEXT ARRIVAL TIME:  35686
# Begin_service caseid = 557 time =  35607 queue_length = 1
# End_service caseid = 555 time =  35612 queue_length = 0
# End_service caseid = 557 time =  35667 queue_length = 0
# Customer joins queue caseid = 558 time =  35686 queue_length = 1
# NEXT ARRIVAL TIME:  35743
# Begin_service caseid = 558 time =  35686 queue_length = 1
# End_service caseid = 556 time =  35689 queue_length = 0
# Customer joins queue caseid = 559 time =  35743 queue_length = 1
# NEXT ARRIVAL TIME:  35782
# Begin_service caseid = 559 time =  35743 queue_length = 1
# Customer joins queue caseid = 560 time =  35782 queue_length = 1
# NEXT ARRIVAL TIME:  35876
# Begin_service caseid = 560 time =  35782 queue_length = 1
# End_service caseid = 558 time =  35828 queue_length = 0
# End_service caseid = 560 time =  35842 queue_length = 0
# Customer joins queue caseid = 561 time =  35876 queue_length = 1
# NEXT ARRIVAL TIME:  35946
# Begin_service caseid = 561 time =  35876 queue_length = 1
# End_service caseid = 561 time =  35936 queue_length = 0
# Customer joins queue caseid = 562 time =  35946 queue_length = 1
# NEXT ARRIVAL TIME:  35946
# Begin_service caseid = 562 time =  35946 queue_length = 1
# Customer joins queue caseid = 563 time =  35946 queue_length = 1
# NEXT ARRIVAL TIME:  36017
# Begin_service caseid = 563 time =  35946 queue_length = 1

# %%
'''
-----------------------------------------------------------------
report simulation program results to data frame and files

the SimPy simulation trace file provides a trace of events 
that is saved to a text file in the form
  (simulation time, index number of event, <class 'type of event'>)
this can be useful in debugging simulation program logic

the event_log list of tuples is saved to a text file of the form
  (caseid, time, 'activity')
the event_log list of tuples is also unpacked and saved as a
pandas data frame and saved to a comma-delimited text file 

-----------------------------------------------------------------
'''

simulation_trace_file_name = 'simulation-program-trace-' + simulation_file_identifier + '.txt'
with open(simulation_trace_file_name, 'wt') as ftrace:
    for d in data:
        print(str(d), file = ftrace)
print()        
print('simulation program trace written to file:',simulation_trace_file_name)

# convert list of tuples to list of lists
event_log_list = [list(element) for element in event_log]

# convert to pandas data frame
caseid_list = []
time_list = []
activity_list = []
for d in event_log_list:
    if d[0] > 0:
        caseid_list.append(d[0])
        time_list.append(d[1])
        activity_list.append(d[2])
event_log_df = pd.DataFrame({'caseid':caseid_list,
                             'time':time_list,
                             'activity':activity_list})    
print()
print('event log stored as Pandas data frame: event_log_df')

# save event log to comma-delimited text file
event_log_file_name = 'simulation-event-log-' + simulation_file_identifier + '.csv'
event_log_df.to_csv(event_log_file_name, index = False)  
print()
print('event log written to file:',event_log_file_name)
# Out:
# simulation program trace written to file: simulation-program-trace-10-hours-3-1-2-5-1-10.txt
#
# event log stored as Pandas data frame: event_log_df
#
# event log written to file: simulation-event-log-10-hours-3-1-2-5-1-10.csv

# %%
# encapsulating the export simulation results to files in a function
# allows the simulation to be run multiple times

def export_simulation_results_to_files(i):
    
    simulation_trace_file_name = 'simulation-program-trace-' + simulation_file_identifier + '.txt'
    with open(simulation_trace_file_name, 'wt') as ftrace:
        for d in data:
            print(str(d), file = ftrace)
    print()        
    print('simulation program trace written to file:',simulation_trace_file_name)

    # convert list of tuples to list of lists
    event_log_list = [list(element) for element in event_log]

    # convert to pandas data frame
    caseid_list = []
    time_list = []
    activity_list = []
    for d in event_log_list:
        if d[0] > 0:
            caseid_list.append(d[0])
            time_list.append(d[1])
            activity_list.append(d[2])
    event_log_df = pd.DataFrame({'caseid':caseid_list,
                             'time':time_list,
                             'activity':activity_list})    
    print()
    print('event log stored as Pandas data frame: event_log_df')

    # save event log to comma-delimited text file
    event_log_file_name = 'simulation-event-log-' + simulation_file_identifier + '.csv'
    event_log_df.to_csv(event_log_file_name, index = False)  
    print()
    print('event log written to file:',event_log_file_name)

# %%
'''
-----------------------------------------------------------------
analyze simulation results 

here we report settings of simulation parameters and
compute summary statistics for the coffee shop

an additional output file provides a case-by-case listing
of all events in the event log

-----------------------------------------------------------------
'''
print()
print('Simulation parameter settings:')
print(baristas, 'baristas/servers')
print('  Service time settings (in minutes)')
print('    minimum:',minimum_service_time)
print('    mean:   ',mean_service_time)
print('    maximum:',maximum_service_time)
print('mean observed service times may deviate from the parameter setting')
print('due to censoring associated with the minimum and maxium')
print()
print('Customers set to arrive every', mean_inter_arrival_time, 'minute(s) on average')
print('Customers will not join the queue/waiting line if it has',balking_queue_length, 'customers in it (balking)')
print('The simulation is set to run for ', simulation_hours,' hours (',60*simulation_hours,' minutes)', sep ='')
print()
end_time = np.max(event_log_df["time"])
print('Results after ',end_time, ' seconds (', round(end_time/60, 2), ' minutes, ',round(end_time/(60*60),2),' hours):', sep = '')
caseid_list = pd.unique(event_log_df['caseid'])
print(len(caseid_list), 'unique customers arrived')
print(len(event_log_df['activity'][event_log_df['activity']=='join_queue']),'customers joined the queue for service')
print(len(event_log_df['activity'][event_log_df['activity']=='balk']),'customers balked (lost business)')
print(len(event_log_df['activity'][event_log_df['activity']=='begin_service']),'customers began service')
print(len(event_log_df['activity'][event_log_df['activity']=='end_service']),'customers ended service')
print(caseid_queue.qsize(),'customers were still in line at the end of the simulation')

# case-by-case logs are very useful for checking the logic of the simulation
case_by_case_event_file_name = 'simulation-program-case-by-case-events-' + simulation_file_identifier + '.txt'
with open(case_by_case_event_file_name, 'wt') as fcasedata:
    lastcase_arrival_time = 0  # initialize for use with first case
    # create lists for storing time interval data 
    inter_arrival_times = [] # computed across cases
    waiting_time = [] # computed within each case that has begun service
    service_time = [] # computed within each case that has ended service
    for thiscase in caseid_list:
        # select subset of rows for thiscase and use as a Pandas data frame
        thiscase_events = event_log_df[['caseid','time','activity']][event_log_df['caseid']==thiscase]
        print(file = fcasedata)
        print('events for caseid',thiscase, file = fcasedata)
        print(thiscase_events, file = fcasedata) 
        # compute inter-arrival times between cases
        thiscase_arrival_time = thiscase_events.loc[thiscase_events['activity']=='arrival', 'time'].values[0]
        inter_arrival_time = thiscase_arrival_time - lastcase_arrival_time
        inter_arrival_times.append(inter_arrival_time)
        print(file = fcasedata)
        print('time between arrivals (this case minus previous case):',inter_arrival_time, 'seconds', file = fcasedata)
        lastcase_arrival_time  = thiscase_arrival_time # save for next case in the for-loop
        # compute waiting times within this case (must have begin_service event/activity)
        if thiscase_events.loc[thiscase_events['activity']=='begin_service'].shape[0] == 1:
            thiscase_begin_service = thiscase_events.loc[thiscase_events['activity']=='begin_service', 'time'].values[0]
            thiscase_join_queue = thiscase_arrival_time = thiscase_events.loc[thiscase_events['activity']=='join_queue', 'time'].values[0]
            thiscase_waiting_time = thiscase_begin_service - thiscase_join_queue
            waiting_time.append(thiscase_waiting_time)
            print('waiting time for this case (time between joining queue and beginning service):',thiscase_waiting_time, 'seconds', file = fcasedata)
        # compute service time within this case (must have end_service event/activity)
        if thiscase_events.loc[thiscase_events['activity']=='end_service'].shape[0] == 1:
            thiscase_end_service = thiscase_events.loc[thiscase_events['activity']=='end_service', 'time'].values[0]
            thiscase_service_time = thiscase_end_service - thiscase_begin_service
            service_time.append(thiscase_service_time)
            print('service time for this case (time between beginning and ending service):',thiscase_service_time, 'seconds', file = fcasedata)
        
print()     
print('Summary statistics for customer inter-arrival times:')
print('  Minimum: ',round(np.min(inter_arrival_times),2), ' seconds (' ,round(np.min(inter_arrival_times)/60,2), ' minutes)',sep='')  
print('  Mean:    ',round(np.average(inter_arrival_times),2), ' seconds (' ,round(np.average(inter_arrival_times)/60,2), ' minutes)',sep='')  
print('  Maximum: ',round(np.max(inter_arrival_times),2), ' seconds (' ,round(np.max(inter_arrival_times)/60,2), ' minutes)',sep='')      
print()
print('Summary statistics for customer wait times:')
print('  Minimum: ',round(np.min(waiting_time),2), ' seconds (' ,round(np.min(waiting_time)/60,2), ' minutes)',sep='')  
print('  Mean:    ',round(np.average(waiting_time),2), ' seconds (' ,round(np.average(waiting_time)/60,2), ' minutes)',sep='')  
print('  Maximum: ',round(np.max(waiting_time),2), ' seconds (' ,round(np.max(waiting_time)/60,2), ' minutes)',sep='')  
print()
print('Summary statistics for service times:')
print('  Minimum: ',round(np.min(service_time),2), ' seconds (' ,round(np.min(service_time)/60,2), ' minutes)',sep='')  
print('  Mean:    ',round(np.average(service_time),2), ' seconds (' ,round(np.average(service_time)/60,2), ' minutes)',sep='')  
print('  Maximum: ',round(np.max(service_time),2), ' seconds (' ,round(np.max(service_time)/60,2), ' minutes)',sep='')  


print()        
print('simulation case-by-case event data written to file:',case_by_case_event_file_name)
print("this log is most useful in checking the logic of the simulation")

# Define output_table data frame for use within KNIME
# KNIME is a low-code platform for data science
output_string_key = []
output_string_value = []

output_string_key.append("Minimum inter-arrival_time")
output_string_value.append(str(round(np.min(inter_arrival_times),2)))
output_string_key.append("Average inter-arrival_time")
output_string_value.append(str(round(np.average(inter_arrival_times),2)))
output_string_key.append("Maximum inter-arrival_time")
output_string_value.append(str(round(np.max(inter_arrival_times),2)))

output_string_key.append("Mimimum waiting time")
output_string_value.append(str(round(np.min(waiting_time),2)))
output_string_key.append("Average waiting time")
output_string_value.append(str(round(np.average(waiting_time),2)))
output_string_key.append("Maximum waiting time")
output_string_value.append(str(round(np.max(waiting_time),2)))

output_string_key.append("Mimimum service time")
output_string_value.append(str(round(np.min(service_time),2)))
output_string_key.append("Average service time")
output_string_value.append(str(round(np.average(service_time),2)))
output_string_key.append("Maximum service time")
output_string_value.append(str(round(np.max(service_time),2)))

output_table = pd.DataFrame({"key":output_string_key, "value":output_string_value})
output_table.set_index(['key'])
# Out:
# Simulation parameter settings:
# 3 baristas/servers
#   Service time settings (in minutes)
#     minimum: 1
#     mean:    2
#     maximum: 5
# mean observed service times may deviate from the parameter setting
# due to censoring associated with the minimum and maxium
#
# Customers set to arrive every 1 minute(s) on average
# Customers will not join the queue/waiting line if it has 10 customers in it (balking)
# The simulation is set to run for 10 hours (600 minutes)
#
# Results after 35970 seconds (599.5 minutes, 9.99 hours):
# 613 unique customers arrived
# 613 customers joined the queue for service
# 0 customers balked (lost business)
# 613 customers began service
# 610 customers ended service
# 0 customers were still in line at the end of the simulation
#
# Summary statistics for customer inter-arrival times:
#   Minimum: 0 seconds (0.0 minutes)
#   Mean:    58.68 seconds (0.98 minutes)
#   Maximum: 437 seconds (7.28 minutes)
#
# Summary statistics for customer wait times:
#   Minimum: 0 seconds (0.0 minutes)
#   Mean:    24.51 seconds (0.41 minutes)
#   Maximum: 320 seconds (5.33 minutes)
#
# Summary statistics for service times:
#   Minimum: 60 seconds (1.0 minutes)
#   Mean:    114.83 seconds (1.91 minutes)
#   Maximum: 300 seconds (5.0 minutes)
#
# simulation case-by-case event data written to file: simulation-program-case-by-case-events-10-hours-3-1-2-5-1-10.txt
# this log is most useful in checking the logic of the simulation
#                              value
# key
# Minimum inter-arrival_time       0
# Average inter-arrival_time   58.68
# Maximum inter-arrival_time     437
# Mimimum waiting time             0
# Average waiting time         24.51
# Maximum waiting time           320
# Mimimum service time            60
# Average service time        114.83
# Maximum service time           300
